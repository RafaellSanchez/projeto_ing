# %%
import os
import json
import pandas as pd
import sqlite3
from datetime import datetime
import shutil

# %%
sub = 'teste2'
nome_arq = 'resultado_teste2_20240625_192812.txt'
sep = nome_arq[10:16]
print(sep)

sepsub = sub in nome_arq
print(sepsub)

string = nome_arq.find(sub)
print(string)

string_split = nome_arq.split('_')
print(string_split)

for item in string_split[1]:
    nm_tb = item
    print(nm_tb)
# Out:
# teste2
# True
# 10
# ['resultado', 'teste2', '20240625', '192812.txt']
# t
# e
# s
# t
# e
# 2

# %%
item = ['estrutura.json', 'tabela_teste.json', 'tabela_testeconf.json']
texto = 'resultado_testeconf_20240625_192812.txt'
parte_util = texto.split('_')[1][0:]
chave = 'tabela_teste2.json'

tabela = 'tabela_'

# item.index(chave)

for item_teste in item:
    dep = item_teste.split('.')[:1]
    print(f'resultado: {dep}')
    
print(parte_util)
    
for item_part in dep:
    print(f'resultado item: {item_part}')
    if item_part != parte_util:
        tab = tabela + parte_util
        print(f'resultado concat: {tab}')
    else:
        print('error')
        
    

    
    
   
# depara = f'tabela_{item_teste}.json'
# print(parte_util)
# Out:
# resultado: ['estrutura']
# resultado: ['tabela_teste']
# resultado: ['tabela_testeconf']
# testeconf
# resultado item: tabela_testeconf
# resultado concat: tabela_testeconf

# %%
import os
import json
import sqlite3
import pandas as pd
import shutil
import re
from datetime import datetime

timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
data_igtao = datetime.now().strftime('%Y-%m-%d')

caminho_backup = '/workspaces/projeto_ing/INGESTION/app/src/backp/'
ctrl_ing = "/workspaces/projeto_ing/INGESTION/app/src/archiving_ctrl/arquivo_controle.txt"
landing = '/workspaces/projeto_ing/INGESTION/app/src/landing/'
layouts = '/workspaces/projeto_ing/INGESTION/app/src/tmp/layouts/'

read_landing = os.listdir(landing)
print("Conteúdos do diretório 'landing':", read_landing)
read_layouts = os.listdir(layouts)
print("Conteúdos do diretório 'layouts':", read_layouts)
print('=====================')

for item in read_layouts:
    accept = os.path.join(layouts, item)
    if os.path.isdir(accept):
        print(f'{item} é uma pasta')
        subconteudos = os.listdir(accept)
        print(f'Conteúdos de {item}: {subconteudos}')

        caminho_estrutura_json = os.path.join(accept, 'estrutura.json')
        if os.path.exists(caminho_estrutura_json):
            print(f'Encontrado estrutura.json em {item}')

            with open(caminho_estrutura_json, 'r') as f:
                config_estrutura = json.load(f)
                print("Configuração estrutura:", config_estrutura)

            caminho_tabela_json = os.path.join(accept, f'tabela_{item}.json')
            with open(caminho_tabela_json, 'r') as f:
                config_colunas = json.load(f)
                print('Lendo estrutura de coluna json')
                print('==========================')
                print(config_colunas)
                
                for item_estrutura in config_estrutura['estrutura']:
                    key = item_estrutura['chave']['palavra_chave']
                    print(key)
                    
                    print(caminho_tabela_json)
                    if key == item:
                        print('======')
                        print('ok')
                        print(item)
                        print('======')
# Out:
# Conteúdos do diretório 'landing': ['resultado_teste2_20242306_215405.txt']
# Conteúdos do diretório 'layouts': ['teste']
# =====================
# teste é uma pasta
# Conteúdos de teste: ['estrutura.json', 'tabela_teste2.json', 'tabela_teste.json']
# Encontrado estrutura.json em teste
# Configuração estrutura: {'estrutura': [{'ing1': None, 'descricao': 'tabela teste', 'chave': {'palavra_chave': 'teste', 'nome_arquivo': 'resultado_teste_', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste'}}, {'ing2': None, 'descricao': 'tabela teste 2', 'chave': {'palavra_chave': 'teste2', 'nome_arquivo': 'resultado_teste2_', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste_2'}}]}
# Lendo estrutura de coluna json
# ==========================
# {'colunas': [{'nome': 'id', 'tipo': 'string'}, {'nome': 'nome', 'tipo': 'string'}]}
# teste
# /workspaces/projeto_ing/INGESTION/app/src/tmp/layouts/teste/tabela_teste.json
# ======
# ok
# teste
# ======
# teste2
# /workspaces/projeto_ing/INGESTION/app/src/tmp/layouts/teste/tabela_teste.json

# %%
caminho_completo = '/workspaces/projeto_ing/INGESTION/app/src/backp/resultado_teste2_20242306_215405.txt'
with open(caminho_completo, 'r') as f:
    config_colunas = json.load(f)
    print(config_colunas)
    print('Lendo estrutura de coluna json')
    print('==========================')


caminho_completo = '/workspaces/projeto_ing/INGESTION/app/src/backp/resultado_teste2_20242306_215405.txt'
item_teste = ['estrutura.json', 'tabela_teste2.json', 'tabela_teste.json']
texto = 'resultado_teste2_20240625_192812.txt'
teste_part = texto.split('_')[1][0:]
print(teste_part)
depara = f'tabela_{item_teste}.json'

if parte_util == depara:
    print(depara)
    # if caminho_completo.endswith('.txt'):
    #     df = pd.read_csv(caminho_completo, delimiter=';', skiprows=[0], names=[col['nome'] for col in config_colunas['colunas']])
    #     print(f'conteudo do arquivo txt: {df}')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 caminho_completo = '/workspaces/projeto_ing/INGESTION/app/src/backp/resultado_teste2_20242306_215405.txt'
# ----> 2 with open(caminho_completo, 'r') as f:
#       3     config_colunas = json.load(f)
#       4     print(config_colunas)
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/workspaces/projeto_ing/INGESTION/app/src/backp/resultado_teste2_20242306_215405.txt'

# %%
import os
import json
import sqlite3
import pandas as pd
import shutil
import re
from datetime import datetime

timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
data_igtao = datetime.now().strftime('%Y-%m-%d')

caminho_backup = '/workspaces/projeto_ing/INGESTION/app/src/backp/'
ctrl_ing = "/workspaces/projeto_ing/INGESTION/app/src/archiving_ctrl/arquivo_controle.txt"
landing = '/workspaces/projeto_ing/INGESTION/app/src/landing/'
layouts = '/workspaces/projeto_ing/INGESTION/app/src/tmp/layouts/'

read_landing = os.listdir(landing)
print("Conteúdos do diretório 'landing':", read_landing)
read_layouts = os.listdir(layouts)
print("Conteúdos do diretório 'layouts':", read_layouts)
print('=====================')



for item in read_layouts:
    accept = os.path.join(layouts, item)
    if os.path.isdir(accept):
        print(f'{item} é uma pasta')
        subconteudos = os.listdir(accept)
        print(f'Conteúdos de {item}: {subconteudos}')

        caminho_estrutura_json = os.path.join(accept, 'estrutura.json')
        if os.path.exists(caminho_estrutura_json):
            print(f'Encontrado estrutura.json em {item}')

            with open(caminho_estrutura_json, 'r') as f:
                config_estrutura = json.load(f)
                print("Configuração estrutura:", config_estrutura)
            
            for processo in config_estrutura['estrutura']:
                    key = processo['chave']['palavra_chave']
                    banco = processo['chave']['banco']
                    tabela = processo['chave']['tabela']
                    nm_arquivo = processo['chave']['nome_arquivo']
                    
                    parte_util = nm_arquivo.split('_')[1][0:]
                    print(parte_util)
                                  
            caminho_tabela_json = os.path.join(accept, f'tabela_{parte_util}.json')
            with open(caminho_tabela_json, 'r') as f:
                config_colunas = json.load(f)
                print('Lendo estrutura de coluna json')
                print('==========================')
                print(config_colunas)
                
                for cfg_col in config_colunas['colunas']:
                    print(cfg_col)
# Out:
# Conteúdos do diretório 'landing': ['resultado_teste2_20242306_215405.txt', 'resultado_teste_20242506_202032.txt']
# Conteúdos do diretório 'layouts': ['teste']
# =====================
# teste é uma pasta
# Conteúdos de teste: ['estrutura.json', 'tabela_teste2.json', 'tabela_teste.json']
# Encontrado estrutura.json em teste
# Configuração estrutura: {'estrutura': [{'ing1': None, 'descricao': 'tabela teste', 'chave': {'palavra_chave': 'teste', 'nome_arquivo': 'resultado_teste_', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste'}}, {'ing2': None, 'descricao': 'tabela teste 2', 'chave': {'palavra_chave': 'teste2', 'nome_arquivo': 'resultado_teste2_', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste_2'}}]}
# teste
# teste2
# Lendo estrutura de coluna json
# ==========================
# {'colunas': [{'nome': 'id', 'tipo': 'string'}, {'nome': 'nome', 'tipo': 'string'}, {'idade': 'idade', 'tipo': 'string'}]}
# {'nome': 'id', 'tipo': 'string'}
# {'nome': 'nome', 'tipo': 'string'}
# {'idade': 'idade', 'tipo': 'string'}

# %%
import os
import json
import sqlite3
import pandas as pd
import shutil
import re
from datetime import datetime

timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
data_igtao = datetime.now().strftime('%Y-%m-%d')

caminho_backup = '/workspaces/projeto_ing/INGESTION/app/src/backp/'
ctrl_ing = "/workspaces/projeto_ing/INGESTION/app/src/archiving_ctrl/arquivo_controle.txt"
landing = '/workspaces/projeto_ing/INGESTION/app/src/landing/'
layouts = '/workspaces/projeto_ing/INGESTION/app/src/tmp/layouts/'

read_landing = os.listdir(landing)
print("Conteúdos do diretório 'landing':", read_landing)
read_layouts = os.listdir(layouts)
print("Conteúdos do diretório 'layouts':", read_layouts)
print('=====================')


try:
    for item in read_layouts:
        accept = os.path.join(layouts, item)
        if os.path.isdir(accept):
            print(f'{item} é uma pasta')
            subconteudos = os.listdir(accept)
            print(f'Conteúdos de {item}: {subconteudos}')

            caminho_estrutura_json = os.path.join(accept, 'estrutura.json')
            if os.path.exists(caminho_estrutura_json):
                print(f'Encontrado estrutura.json em {item}')

                with open(caminho_estrutura_json, 'r') as f:
                    config_estrutura = json.load(f)
                    print("Configuração estrutura:", config_estrutura)

                caminho_tabela_json = os.path.join(accept, f'tabela_{item}.json')
                with open(caminho_tabela_json, 'r') as f:
                    config_colunas = json.load(f)
                    print('Lendo estrutura de coluna json')
                    print('==========================')
                    
                for processo in config_estrutura['estrutura']:
                    key = processo['chave']['palavra_chave']
                    banco = processo['chave']['banco']
                    tabela = processo['chave']['tabela']
                    nm_arquivo = processo['chave']['nome_arquivo']
                    
                    
                    with open(ctrl_ing, 'r+') as controle_ingestao:
                        conteudo_load = controle_ingestao.readlines()
                        print(f'Conteúdo do arquivo de controle de ingestão: {conteudo_load}')

                        for root, dirs, lista in os.walk(landing):
                            print(f'Procurando em {root}...')
                            for nome_arquivo in lista:
                                print(f'Verificando arquivo: {nome_arquivo}')
                                if key in nome_arquivo:
                                    caminho_completo = os.path.join(root, nome_arquivo)
                                    print(f'Arquivo contendo a chave encontrado: {caminho_completo}')
                                    sav = os.path.basename(caminho_completo)
                                    print(f'Conteúdo a gravar: {sav}')
                                    
                                    # teste = 'resultado_teste2_20240625_192812.txt'
                                    parte_util = sav.split('_')[1][0:]
                                    print(parte_util)
                                       

                                    if sav + '\n' not in conteudo_load:
                                        controle_ingestao.write(f"{sav}\n")
                                        print(f'Dado salvo: {sav}')
                                        controle_ingestao.flush()
                                        print('=================================')
                                        
                                        depara = f'tabela_{item}.json'
                                        
                                        if parte_util == depara:
                                            if caminho_completo.endswith('.txt'):
                                                df = pd.read_csv(caminho_completo, delimiter=';', skiprows=[0], names=[col['nome'] for col in config_colunas['colunas']])
                                                print(f'conteudo do arquivo txt: {df}')
                                            elif caminho_completo.endswith('.csv'):
                                                df = pd.read_csv(caminho_completo, skiprows=[0], names=[col['nome'] for col in config_colunas['colunas']])
                                                print(f'conteudo do arquivo csv: {df}')
                                            elif caminho_completo.endswith('.bin'):
                                                pass  # lógica para arquivos binários
                                            else:
                                                raise ValueError("Formato de arquivo não suportado")
                                    

                                        print('Convertendo tipos de dados')
                                        for col in config_colunas['colunas']:
                                            if col['tipo'] == 'int':
                                                df[col['nome']] = df[col['nome']].astype(int)
                                            elif col['tipo'] == 'float':
                                                df[col['nome']] = df[col['nome']].astype(float)
                                            elif col['tipo'] == 'data':
                                                df[col['nome']] = pd.to_datetime(df[col['nome']], format=col.get('formato', None))
                                        
                                        
                                        print('Conectando no banco de dados')
                                        banco_caminho = f'/workspaces/projeto_ing/INGESTION/database/{banco}'
                                        conn = sqlite3.connect(banco_caminho)
                                        print(f'Banco de dados: {banco_caminho}')
                                        print(f'Banco de dados criado se não existir: {banco}')
                                        print(f'Conectado!')
                                        print(f"====================================")

                                        cursor = conn.cursor()
                                        nm_tb = f'tabela_{parte_util}'
                                        # Criação dinâmica da tabela com base na chave extraída
                                        sql_create_table = f"CREATE TABLE IF NOT EXISTS {nm_tb} ("
                                        for col in config_colunas['colunas']:
                                            sql_create_table += f"{col['nome']} {col['tipo']}, "
                                        sql_create_table = sql_create_table[:-2] + ")"
                                        cursor.execute(sql_create_table)
                                        print(f'Tabela criada: {nm_tb}')
                                    
                                        print('Inserindo dados na tabela...')
                                        for index, row in df.iterrows():
                                            mapped_values = []
                                            for col in config_colunas['colunas']:
                                                mapped_values.append(row.get(col['nome'], None))
                                            print("Valores mapeados:", mapped_values)
                                            sql = f"INSERT INTO {nm_tb} ({', '.join([col['nome'] for col in config_colunas['colunas']])}) VALUES ({', '.join(['?' for _ in mapped_values])})"
                                            print("SQL:", sql)
                                            cursor.execute(sql, mapped_values)

                                        print('Commit e fechamento da conexão...')
                                        conn.commit()
                                        conn.close()
                                        print("Ingestão de dados concluída com sucesso!")

                                        print("========================================")
                                        print("Movimentando arquivos")
                                        shutil.move(caminho_completo, caminho_backup)
                                        print(f'Arquivo enviado para bckp: {caminho_completo}')
                                        print(f'Destino: {caminho_backup}')
                                        
                                        
except Exception as e:
    print(e)
# Out:
# Conteúdos do diretório 'landing': ['resultado_teste2_20242306_215405.txt', 'resultado_teste_20242506_202032.txt']
# Conteúdos do diretório 'layouts': ['teste']
# =====================
# teste é uma pasta
# Conteúdos de teste: ['estrutura.json', 'tabela_teste2.json', 'tabela_teste.json']
# Encontrado estrutura.json em teste
# Configuração estrutura: {'estrutura': [{'ing1': None, 'descricao': 'tabela teste', 'chave': {'palavra_chave': 'teste', 'nome_arquivo': 'resultado_teste_', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste'}}, {'ing2': None, 'descricao': 'tabela teste 2', 'chave': {'palavra_chave': 'teste2', 'nome_arquivo': 'resultado_teste2_', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste_2'}}]}
# Lendo estrutura de coluna json
# ==========================
# Conteúdo do arquivo de controle de ingestão: []
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Verificando arquivo: resultado_teste2_20242306_215405.txt
# Arquivo contendo a chave encontrado: /workspaces/projeto_ing/INGESTION/app/src/landing/resultado_teste2_20242306_215405.txt
# Conteúdo a gravar: resultado_teste2_20242306_215405.txt
# teste2
# Dado salvo: resultado_teste2_20242306_215405.txt
# =================================
# Convertendo tipos de dados
# Conectando no banco de dados
# Banco de dados: /workspaces/projeto_ing/INGESTION/database/banco_teste.db
# Banco de dados criado se não existir: banco_teste.db
# Conectado!
# ====================================
# Tabela criada: tabela_teste2
# Inserindo dados na tabela...
# Valores mapeados: [30.0, nan]
# SQL: INSERT INTO tabela_teste2 (id, nome) VALUES (?, ?)
# Valores mapeados: [28.0, nan]
# SQL: INSERT INTO tabela_teste2 (id, nome) VALUES (?, ?)
# Commit e fechamento da conexão...
# Ingestão de dados concluída com sucesso!
# ========================================
# Movimentando arquivos
# Arquivo enviado para bckp: /workspaces/projeto_ing/INGESTION/app/src/landing/resultado_teste2_20242306_215405.txt
# Destino: /workspaces/projeto_ing/INGESTION/app/src/backp/
# Verificando arquivo: resultado_teste_20242506_202032.txt
# Arquivo contendo a chave encontrado: /workspaces/projeto_ing/INGESTION/app/src/landing/resultado_teste_20242506_202032.txt
# Conteúdo a gravar: resultado_teste_20242506_202032.txt
# teste
# Dado salvo: resultado_teste_20242506_202032.txt
# =================================
# Convertendo tipos de dados
# Conectando no banco de dados
# Banco de dados: /workspaces/projeto_ing/INGESTION/database/banco_teste.db
# Banco de dados criado se não existir: banco_teste.db
# Conectado!
# ====================================
# Tabela criada: tabela_teste
# Inserindo dados na tabela...
# Valores mapeados: [30.0, nan]
# SQL: INSERT INTO tabela_teste (id, nome) VALUES (?, ?)
# Valores mapeados: [28.0, nan]
# SQL: INSERT INTO tabela_teste (id, nome) VALUES (?, ?)
# Commit e fechamento da conexão...
# Ingestão de dados concluída com sucesso!
# ========================================
# Movimentando arquivos
# Arquivo enviado para bckp: /workspaces/projeto_ing/INGESTION/app/src/landing/resultado_teste_20242506_202032.txt
# Destino: /workspaces/projeto_ing/INGESTION/app/src/backp/
# Conteúdo do arquivo de controle de ingestão: ['resultado_teste2_20242306_215405.txt\n', 'resultado_teste_20242506_202032.txt\n']
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...

# %%
banco = 'banco_teste.db'
banco_caminho = f'/workspaces/projeto_ing/INGESTION/database/{banco}'
conn = sqlite3.connect(banco_caminho)
cursor = conn.cursor()

query = 'select * from tabela_teste'

cursor.execute(query)

# Recuperando e imprimindo o resultado
tables = cursor.fetchall()

print("Tabelas no banco de dados:")
for table in tables:
    print(table)

# Fechando a conexão
conn.close()
# Out:
# Tabelas no banco de dados:
# (30, None)
# (28, None)

# %%
import os
import json
import sqlite3
import pandas as pd
import shutil
import re
from datetime import datetime

timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
data_igtao = datetime.now().strftime('%Y-%m-%d')

caminho_backup = '/workspaces/projeto_ing/INGESTION/app/src/backp/'
ctrl_ing = "/workspaces/projeto_ing/INGESTION/app/src/archiving_ctrl/arquivo_controle.txt"
landing = '/workspaces/projeto_ing/INGESTION/app/src/landing/'
layouts = '/workspaces/projeto_ing/INGESTION/app/src/tmp/layouts/'

read_landing = os.listdir(landing)
print("Conteúdos do diretório 'landing':", read_landing)
read_layouts = os.listdir(layouts)
print("Conteúdos do diretório 'layouts':", read_layouts)
print('=====================')

for item in read_layouts:
    accept = os.path.join(layouts, item)
    if os.path.isdir(accept):
        print(f'{item} é uma pasta')
        subconteudos = os.listdir(accept)
        print(f'Conteúdos de {item}: {subconteudos}')

        caminho_estrutura_json = os.path.join(accept, 'estrutura.json')
        if os.path.exists(caminho_estrutura_json):
            print(f'Encontrado estrutura.json em {item}')

            with open(caminho_estrutura_json, 'r') as f:
                config_estrutura = json.load(f)
                print("Configuração estrutura:", config_estrutura)

            caminho_tabela_json = os.path.join(accept, f'tabela_{item}.json')
            with open(caminho_tabela_json, 'r') as f:
                config_colunas = json.load(f)
                print('Lendo estrutura de coluna json')
                print('==========================')

            for processo in config_estrutura['estrutura']:
                key = processo['chave']['palavra_chave']
                arquivo = processo['chave']['nome_arquivo']
                banco = processo['chave']['banco']
                tabela = processo['chave']['tabela']
                regex_nome_arquivo = processo['chave'].get('regex_nome_arquivo', None)  # Busca o regex específico se estiver definido na estrutura
                print(f'estrutura json:{processo}')
                print("============================")
                print("resultado:")
                print(key)
                print(arquivo)
                print(banco)
                print(tabela)
                print(f"Regex do nome do arquivo: {regex_nome_arquivo}")
                print("============================")

                with open(ctrl_ing, 'r+') as controle_ingestao:
                    conteudo_load = controle_ingestao.readlines()
                    print(f'Conteúdo do arquivo de controle de ingestão: {conteudo_load}')

                    for root, dirs, lista in os.walk(landing):
                        print(f'Procurando em {root}...')
                        for nome_arquivo in lista:
                            print(f'Verificando arquivo: {nome_arquivo}')
                            
                            # Define o padrão regex com base no regex_nome_arquivo da estrutura
                            if regex_nome_arquivo:
                                padrao = regex_nome_arquivo
                            else:
                                padrao = r'resultado_(.*?)_\d+\.txt'  # Padrão padrão caso não seja especificado na estrutura

                            # Aplica o regex para extrair a chave do nome do arquivo
                            correspondencia = re.search(padrao, nome_arquivo)
                            
                            if correspondencia:
                                chave_extraida = correspondencia.group(1)
                                print(f'Chave extraída do nome do arquivo: {chave_extraida}')

                                if chave_extraida == key:
                                    caminho_completo = os.path.join(root, nome_arquivo)
                                    print(f'Arquivo contendo a chave encontrado: {caminho_completo}')
                                    sav = os.path.basename(caminho_completo)
                                    print(f'Conteúdo a gravar: {sav}')

                                    if sav + '\n' not in conteudo_load:
                                        controle_ingestao.write(f"{sav}\n")
                                        print(f'Dado salvo: {sav}')
                                        controle_ingestao.flush()
                                        print('=================================')

                                        # Leitura do arquivo e criação do DataFrame
                                        if caminho_completo.endswith('.txt'):
                                            df = pd.read_csv(caminho_completo, delimiter=';', skiprows=[0], names=[col['nome'] for col in config_colunas['colunas']])
                                        elif caminho_completo.endswith('.csv'):
                                            df = pd.read_csv(caminho_completo, skiprows=[0], names=[col['nome'] for col in config_colunas['colunas']])
                                        elif caminho_completo.endswith('.bin'):
                                            pass  # lógica para arquivos binários
                                        else:
                                            raise ValueError("Formato de arquivo não suportado")

                                        print('Convertendo tipos de dados')
                                        for col in config_colunas['colunas']:
                                            if col['tipo'] == 'int':
                                                df[col['nome']] = df[col['nome']].astype(int)
                                            elif col['tipo'] == 'float':
                                                df[col['nome']] = df[col['nome']].astype(float)
                                            elif col['tipo'] == 'data':
                                                df[col['nome']] = pd.to_datetime(df[col['nome']], format=col.get('formato', None))

                                        print('Conectando no banco de dados')
                                        banco_caminho = f'/workspaces/projeto_ing/INGESTION/database/{banco}'
                                        conn = sqlite3.connect(banco_caminho)
                                        print(f'Banco de dados: {banco_caminho}')
                                        print(f'Banco de dados criado se não existir: {banco}')
                                        print(f'Conectado!')
                                        print(f"====================================")

                                        cursor = conn.cursor()
                                        
                                        # Criação dinâmica da tabela com base na chave extraída
                                        sql_create_table = f"CREATE TABLE IF NOT EXISTS tabela_{chave_extraida} ("
                                        for col in config_colunas['colunas']:
                                            sql_create_table += f"{col['nome']} {col['tipo']}, "
                                        sql_create_table = sql_create_table[:-2] + ")"
                                        cursor.execute(sql_create_table)
                                        print(f'Tabela criada: tabela_{chave_extraida}')
                                    
                                        print('Inserindo dados na tabela...')
                                        for index, row in df.iterrows():
                                            mapped_values = []
                                            for col in config_colunas['colunas']:
                                                mapped_values.append(row.get(col['nome'], None))
                                            print("Valores mapeados:", mapped_values)
                                            sql = f"INSERT INTO tabela_{chave_extraida} ({', '.join([col['nome'] for col in config_colunas['colunas']])}) VALUES ({', '.join(['?' for _ in mapped_values])})"
                                            print("SQL:", sql)
                                            cursor.execute(sql, mapped_values)

                                        print('Commit e fechamento da conexão...')
                                        conn.commit()
                                        conn.close()
                                        print("Ingestão de dados concluída com sucesso!")

                                        print("========================================")
                                        print("Movimentando arquivos")
                                        shutil.move(caminho_completo, caminho_backup)
                                        print(f'Arquivo enviado para bckp: {caminho_completo}')
                                        print(f'Destino: {caminho_backup}')
                                    
                            
else:
    print("Palavra-chave não encontrada na estrutura configurada.")
# Out:
# Conteúdos do diretório 'landing': ['resultado_teste2_20242306_215405.txt']
# Conteúdos do diretório 'layouts': ['teste']
# =====================
# teste é uma pasta
# Conteúdos de teste: ['estrutura.json', 'tabela_teste2.json', 'tabela_teste.json']
# Encontrado estrutura.json em teste
# Configuração estrutura: {'estrutura': [{'ing1': None, 'descricao': 'tabela teste', 'chave': {'palavra_chave': 'teste', 'nome_arquivo': 'resultado_teste_', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste'}}, {'ing2': None, 'descricao': 'tabela teste 2', 'chave': {'palavra_chave': 'teste2', 'nome_arquivo': 'resultado_teste2_', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste_2'}}]}
# Lendo estrutura de coluna json
# ==========================
# estrutura json:{'ing1': None, 'descricao': 'tabela teste', 'chave': {'palavra_chave': 'teste', 'nome_arquivo': 'resultado_teste_', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste'}}
# ============================
# resultado:
# teste
# resultado_teste_
# banco_teste.db
# tabela_teste
# Regex do nome do arquivo: None
# ============================
# Conteúdo do arquivo de controle de ingestão: []
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Verificando arquivo: resultado_teste2_20242306_215405.txt
# Chave extraída do nome do arquivo: teste2_20242306
# estrutura json:{'ing2': None, 'descricao': 'tabela teste 2', 'chave': {'palavra_chave': 'teste2', 'nome_arquivo': 'resultado_teste2_', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste_2'}}
# ============================
# resultado:
# teste2
# resultado_teste2_
# banco_teste.db
# tabela_teste_2
# Regex do nome do arquivo: None
# ============================
# Conteúdo do arquivo de controle de ingestão: []
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Verificando arquivo: resultado_teste2_20242306_215405.txt
# Chave extraída do nome do arquivo: teste2_20242306
# Palavra-chave não encontrada na estrutura configurada.

# %%
import os
import json
import sqlite3
import pandas as pd
import shutil
import re
from datetime import datetime

timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
data_igtao = datetime.now().strftime('%Y-%m-%d')

caminho_backup = '/workspaces/projeto_ing/INGESTION/app/src/backp/'
ctrl_ing = "/workspaces/projeto_ing/INGESTION/app/src/archiving_ctrl/arquivo_controle.txt"
landing = '/workspaces/projeto_ing/INGESTION/app/src/landing/'
layouts = '/workspaces/projeto_ing/INGESTION/app/src/tmp/layouts/'

read_landing = os.listdir(landing)
print("Conteúdos do diretório 'landing':", read_landing)
read_layouts = os.listdir(layouts)
print("Conteúdos do diretório 'layouts':", read_layouts)
print('=====================')

for item in read_layouts:
    accept = os.path.join(layouts, item)
    if os.path.isdir(accept):
        print(f'{item} é uma pasta')
        subconteudos = os.listdir(accept)
        print(f'Conteúdos de {item}: {subconteudos}')

        caminho_estrutura_json = os.path.join(accept, 'estrutura.json')
        if os.path.exists(caminho_estrutura_json):
            print(f'Encontrado estrutura.json em {item}')

            with open(caminho_estrutura_json, 'r') as f:
                config_estrutura = json.load(f)
                print("Configuração estrutura:", config_estrutura)

            caminho_tabela_json = os.path.join(accept, f'tabela_{item}.json')
            with open(caminho_tabela_json, 'r') as f:
                config_colunas = json.load(f)
                print('Lendo estrutura de coluna json')
                print('==========================')

            for processo in config_estrutura['estrutura']:
                key = processo['chave']['palavra_chave']
                arquivo = processo['chave']['nome_arquivo']
                banco = processo['chave']['banco']
                tabela = processo['chave']['tabela']
                print(f'estrutura json:{processo}')
                print("============================")
                print("resultado:")
                print(key)
                print(arquivo)
                print(banco)
                print(tabela)
                print("============================")

                with open(ctrl_ing, 'r+') as controle_ingestao:
                    conteudo_load = controle_ingestao.readlines()
                    print(f'Conteúdo do arquivo de controle de ingestão: {conteudo_load}')

                    for root, dirs, lista in os.walk(landing):
                        print(f'Procurando em {root}...')
                        for nome_arquivo in lista:
                            print(f'Verificando arquivo: {nome_arquivo}')
                            
                            # Definindo o padrão regex para extrair a chave do nome do arquivo
                            padrao = r'resultado_(.*?)_\d+\.txt'
                            
                            # Aplicando o regex para extrair a chave do nome do arquivo
                            correspondencia = re.search(padrao, nome_arquivo)
                            
                            if correspondencia:
                                chave_extraida = correspondencia.group(1)
                                print(f'Chave extraída do nome do arquivo: {chave_extraida}')

                                if chave_extraida == key:
                                    caminho_completo = os.path.join(root, nome_arquivo)
                                    print(f'Arquivo contendo a chave encontrado: {caminho_completo}')
                                    sav = os.path.basename(caminho_completo)
                                    print(f'Conteúdo a gravar: {sav}')

                                    if sav + '\n' not in conteudo_load:
                                        controle_ingestao.write(f"{sav}\n")
                                        print(f'Dado salvo: {sav}')
                                        controle_ingestao.flush()
                                        print('=================================')

                                        # Leitura do arquivo e criação do DataFrame
                                        if caminho_completo.endswith('.txt'):
                                            df = pd.read_csv(caminho_completo, delimiter=';', skiprows=[0], names=[col['nome'] for col in config_colunas['colunas']])
                                        elif caminho_completo.endswith('.csv'):
                                            df = pd.read_csv(caminho_completo, skiprows=[0], names=[col['nome'] for col in config_colunas['colunas']])
                                        elif caminho_completo.endswith('.bin'):
                                            pass  # lógica para arquivos binários
                                        else:
                                            raise ValueError("Formato de arquivo não suportado")

                                        print('Convertendo tipos de dados')
                                        for col in config_colunas['colunas']:
                                            if col['tipo'] == 'int':
                                                df[col['nome']] = df[col['nome']].astype(int)
                                            elif col['tipo'] == 'float':
                                                df[col['nome']] = df[col['nome']].astype(float)
                                            elif col['tipo'] == 'data':
                                                df[col['nome']] = pd.to_datetime(df[col['nome']], format=col.get('formato', None))

                                        print('Conectando no banco de dados')
                                        banco_caminho = f'/workspaces/projeto_ing/INGESTION/database/{banco}'
                                        conn = sqlite3.connect(banco_caminho)
                                        print(f'Banco de dados: {banco_caminho}')
                                        print(f'Banco de dados criado se não existir: {banco}')
                                        print(f'Conectado!')
                                        print(f"====================================")

                                        cursor = conn.cursor()
                                        
                                        # Criação dinâmica da tabela com base na chave extraída
                                        sql_create_table = f"CREATE TABLE IF NOT EXISTS tabela_{chave_extraida} ("
                                        for col in config_colunas['colunas']:
                                            sql_create_table += f"{col['nome']} {col['tipo']}, "
                                        sql_create_table = sql_create_table[:-2] + ")"
                                        cursor.execute(sql_create_table)
                                        print(f'Tabela criada: tabela_{chave_extraida}')
                                    
                                        print('Inserindo dados na tabela...')
                                        for index, row in df.iterrows():
                                            mapped_values = []
                                            for col in config_colunas['colunas']:
                                                mapped_values.append(row.get(col['nome'], None))
                                            print("Valores mapeados:", mapped_values)
                                            sql = f"INSERT INTO tabela_{chave_extraida} ({', '.join([col['nome'] for col in config_colunas['colunas']])}) VALUES ({', '.join(['?' for _ in mapped_values])})"
                                            print("SQL:", sql)
                                            cursor.execute(sql, mapped_values)

                                        print('Commit e fechamento da conexão...')
                                        conn.commit()
                                        conn.close()
                                        print("Ingestão de dados concluída com sucesso!")

                                        print("========================================")
                                        print("Movimentando arquivos")
                                        shutil.move(caminho_completo, caminho_backup)
                                        print(f'Arquivo enviado para bckp: {caminho_completo}')
                                        print(f'Destino: {caminho_backup}')
                                    
                            
else:
    print("Palavra-chave não encontrada na estrutura configurada.")
# Out:
# Conteúdos do diretório 'landing': ['resultado_teste2_20242306_215405.txt']
# Conteúdos do diretório 'layouts': ['teste']
# =====================
# teste é uma pasta
# Conteúdos de teste: ['estrutura.json', 'tabela_teste2.json', 'tabela_teste.json']
# Encontrado estrutura.json em teste
# Configuração estrutura: {'estrutura': [{'ing1': None, 'descricao': 'tabela teste', 'chave': {'palavra_chave': 'teste', 'nome_arquivo': 'resultado_teste_', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste'}}, {'ing2': None, 'descricao': 'tabela teste 2', 'chave': {'palavra_chave': 'teste2', 'nome_arquivo': 'resultado_teste2_', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste_2'}}]}
# Lendo estrutura de coluna json
# ==========================
# estrutura json:{'ing1': None, 'descricao': 'tabela teste', 'chave': {'palavra_chave': 'teste', 'nome_arquivo': 'resultado_teste_', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste'}}
# ============================
# resultado:
# teste
# resultado_teste_
# banco_teste.db
# tabela_teste
# ============================
# Conteúdo do arquivo de controle de ingestão: []
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Verificando arquivo: resultado_teste2_20242306_215405.txt
# Chave extraída do nome do arquivo: teste2_20242306
# estrutura json:{'ing2': None, 'descricao': 'tabela teste 2', 'chave': {'palavra_chave': 'teste2', 'nome_arquivo': 'resultado_teste2_', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste_2'}}
# ============================
# resultado:
# teste2
# resultado_teste2_
# banco_teste.db
# tabela_teste_2
# ============================
# Conteúdo do arquivo de controle de ingestão: []
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Verificando arquivo: resultado_teste2_20242306_215405.txt
# Chave extraída do nome do arquivo: teste2_20242306
# Palavra-chave não encontrada na estrutura configurada.

# %%
import os
import json
import sqlite3
import pandas as pd
from datetime import datetime
import shutil

timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
data_igtao = datetime.now().strftime('%Y-%m-%d')

caminho_backup = '/workspaces/projeto_ing/INGESTION/app/src/backp/'
ctrl_ing = "/workspaces/projeto_ing/INGESTION/app/src/archiving_ctrl/arquivo_controle.txt"
landing = '/workspaces/projeto_ing/INGESTION/app/src/landing/'
layouts = '/workspaces/projeto_ing/INGESTION/app/src/tmp/layouts/'

read_landing = os.listdir(landing)
print("Conteúdos do diretório 'landing':", read_landing)
read_layouts = os.listdir(layouts)
print("Conteúdos do diretório 'layouts':", read_layouts)
print('=====================')

for item in read_layouts:
    accept = os.path.join(layouts, item)
    if os.path.isdir(accept):
        print(f'{item} é uma pasta')
        subconteudos = os.listdir(accept)
        print(f'Conteúdos de {item}: {subconteudos}')

        caminho_estrutura_json = os.path.join(accept, 'estrutura.json')
        if os.path.exists(caminho_estrutura_json):
            print(f'Encontrado estrutura.json em {item}')

            with open(caminho_estrutura_json, 'r') as f:
                config_estrutura = json.load(f)
                print("Configuração estrutura:", config_estrutura)

            caminho_tabela_json = os.path.join(accept, f'tabela_{item}.json')
            with open(caminho_tabela_json, 'r') as f:
                config_colunas = json.load(f)
                print('Lendo estrutura de coluna json')
                print('==========================')

            for processo in config_estrutura['estrutura']:
                key = processo['chave']['palavra_chave']
                arquivo = processo['chave']['nome_arquivo']
                banco = processo['chave']['banco']
                tabela = processo['chave']['tabela']
                print(f'estrutura json:{processo}')
                print("============================")
                print("resultado:")
                print(key)
                print(arquivo)
                print(banco)
                print(tabela)
                print("============================")

                with open(ctrl_ing, 'r+') as controle_ingestao:
                    conteudo_load = controle_ingestao.readlines()
                    print(f'Conteúdo do arquivo de controle de ingestão: {conteudo_load}')

                    for root, dirs, lista in os.walk(landing):
                        print(f'Procurando em {root}...')
                        for nome_arquivo in lista:
                            print(f'Verificando arquivo: {nome_arquivo}')
                            if key in nome_arquivo:
                                caminho_completo = os.path.join(root, nome_arquivo)
                                print(f'Arquivo contendo a chave encontrado: {caminho_completo}')
                                sav = os.path.basename(caminho_completo)
                                print(f'Conteúdo a gravar: {sav}')

                                if sav + '\n' not in conteudo_load:
                                    controle_ingestao.write(f"{sav}\n")
                                    print(f'Dado salvo: {sav}')
                                    controle_ingestao.flush()
                                    print('=================================')

                                    # Leitura do arquivo e criação do DataFrame
                                    if caminho_completo.endswith('.txt'):
                                        df = pd.read_csv(caminho_completo, delimiter=';', skiprows=[0], names=[col['nome'] for col in config_colunas['colunas']])
                                    elif caminho_completo.endswith('.csv'):
                                        df = pd.read_csv(caminho_completo, skiprows=[0], names=[col['nome'] for col in config_colunas['colunas']])
                                    elif caminho_completo.endswith('.bin'):
                                        pass  # lógica para arquivos binários
                                    else:
                                        raise ValueError("Formato de arquivo não suportado")

                                    print('Convertendo tipos de dados')
                                    for col in config_colunas['colunas']:
                                        if col['tipo'] == 'int':
                                            df[col['nome']] = df[col['nome']].astype(int)
                                        elif col['tipo'] == 'float':
                                            df[col['nome']] = df[col['nome']].astype(float)
                                        elif col['tipo'] == 'data':
                                            df[col['nome']] = pd.to_datetime(df[col['nome']], format=col.get('formato', None))

                                    print('Conectando no banco de dados')
                                    banco_caminho = f'/workspaces/projeto_ing/INGESTION/database/{banco}'
                                    conn = sqlite3.connect(banco_caminho)
                                    print(f'Banco de dados: {banco_caminho}')
                                    print(f'Banco de dados criado se não existir: {banco}')
                                    print(f'Conectado!')
                                    print(f"====================================")

                                    cursor = conn.cursor()
                                    # Verificação da palavra-chave antes de criar a tabela
                                    if key == processo['chave']['palavra_chave']:
                                        print(f'Criando tabela no banco de dados {tabela}...')
                                        sql_create_table = f"CREATE TABLE IF NOT EXISTS {tabela} ("
                                        for col in config_colunas['colunas']:
                                            sql_create_table += f"{col['nome']} {col['tipo']}, "
                                        sql_create_table = sql_create_table[:-2] + ")"
                                        cursor.execute(sql_create_table)
                                        print(f'Tabela criada: {tabela}')
                                    
                                        print('Inserindo dados na tabela...')
                                        for index, row in df.iterrows():
                                            mapped_values = []
                                            for col in config_colunas['colunas']:
                                                mapped_values.append(row.get(col['nome'], None))
                                            print("Valores mapeados:", mapped_values)
                                            sql = f"INSERT INTO {tabela} ({', '.join([col['nome'] for col in config_colunas['colunas']])}) VALUES ({', '.join(['?' for _ in mapped_values])})"
                                            print("SQL:", sql)
                                            cursor.execute(sql, mapped_values)

                                        print('Commit e fechamento da conexão...')
                                        conn.commit()
                                        conn.close()
                                        print("Ingestão de dados concluída com sucesso!")

                                        print("========================================")
                                        print("Movimentando arquivos")
                                        shutil.move(caminho_completo, caminho_backup)
                                        print(f'Arquivo enviado para bckp: {caminho_completo}')
                                        print(f'Destino: {caminho_backup}')
                                    
                            
else:
    print("Palavra-chave não encontrada:", key)
# Out:
# Conteúdos do diretório 'landing': ['resultado_teste2_20242306_215405.txt']
# Conteúdos do diretório 'layouts': ['teste']
# =====================
# teste é uma pasta
# Conteúdos de teste: ['estrutura.json', 'tabela_teste2.json', 'tabela_teste.json']
# Encontrado estrutura.json em teste
# Configuração estrutura: {'estrutura': [{'ing1': None, 'descricao': 'tabela teste', 'chave': {'palavra_chave': 'teste', 'nome_arquivo': 'resultado_teste_', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste'}}, {'ing2': None, 'descricao': 'tabela teste 2', 'chave': {'palavra_chave': 'teste2', 'nome_arquivo': 'resultado_teste2_', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste_2'}}]}
# Lendo estrutura de coluna json
# ==========================
# estrutura json:{'ing1': None, 'descricao': 'tabela teste', 'chave': {'palavra_chave': 'teste', 'nome_arquivo': 'resultado_teste_', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste'}}
# ============================
# resultado:
# teste
# resultado_teste_
# banco_teste.db
# tabela_teste
# ============================
# Conteúdo do arquivo de controle de ingestão: []
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Verificando arquivo: resultado_teste2_20242306_215405.txt
# Arquivo contendo a chave encontrado: /workspaces/projeto_ing/INGESTION/app/src/landing/resultado_teste2_20242306_215405.txt
# Conteúdo a gravar: resultado_teste2_20242306_215405.txt
# Dado salvo: resultado_teste2_20242306_215405.txt
# =================================
# Convertendo tipos de dados
# Conectando no banco de dados
# Banco de dados: /workspaces/projeto_ing/INGESTION/database/banco_teste.db
# Banco de dados criado se não existir: banco_teste.db
# Conectado!
# ====================================
# Criando tabela no banco de dados tabela_teste...
# Tabela criada: tabela_teste
# Inserindo dados na tabela...
# Valores mapeados: ['rafael', 30]
# SQL: INSERT INTO tabela_teste (id, nome) VALUES (?, ?)
# Valores mapeados: ['joyce', 28]
# SQL: INSERT INTO tabela_teste (id, nome) VALUES (?, ?)
# Commit e fechamento da conexão...
# Ingestão de dados concluída com sucesso!
# ========================================
# Movimentando arquivos
# Arquivo enviado para bckp: /workspaces/projeto_ing/INGESTION/app/src/landing/resultado_teste2_20242306_215405.txt
# Destino: /workspaces/projeto_ing/INGESTION/app/src/backp/
# estrutura json:{'ing2': None, 'descricao': 'tabela teste 2', 'chave': {'palavra_chave': 'teste2', 'nome_arquivo': 'resultado_teste2_', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste_2'}}
# ============================
# resultado:
# teste2
# resultado_teste2_
# banco_teste.db
# tabela_teste_2
# ============================
# Conteúdo do arquivo de controle de ingestão: ['resultado_teste2_20242306_215405.txt\n']
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Palavra-chave não encontrada: teste2

# %%
timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
data_igtao = datetime.now().strftime('%Y-%m-%d')

caminho_backup = '/workspaces/projeto_ing/INGESTION/app/src/backp/'
ctrl_ing = "/workspaces/projeto_ing/INGESTION/app/src/archiving_ctrl/arquivo_controle.txt"
landing = '/workspaces/projeto_ing/INGESTION/app/src/landing/'
layouts = '/workspaces/projeto_ing/INGESTION/app/src/tmp/layouts/'

read_landing = os.listdir(landing)
print("Conteúdos do diretório 'landing':", read_landing)
read_layouts = os.listdir(layouts)
print("Conteúdos do diretório 'layouts':", read_layouts)
print('=====================')
key = 'teste2'
for item in read_layouts:
    accept = os.path.join(layouts, item)
    if os.path.isdir(accept):
        print(f'{item} é uma pasta')
        subconteudos = os.listdir(accept)
        print(f'Conteúdos de {item}: {subconteudos}')

        caminho_estrutura_json = os.path.join(accept, 'estrutura.json')
        if os.path.exists(caminho_estrutura_json):
            print(f'Encontrado estrutura.json em {item}')

            with open(caminho_estrutura_json, 'r') as f:
                config_estrutura = json.load(f)
                print("Configuração estrutura:", config_estrutura)

            caminho_tabela_json = os.path.join(accept, f'tabela_{item}.json')
            with open(caminho_tabela_json, 'r') as f:
                config_colunas = json.load(f)
                print('Lendo estrutura de coluna json')
                print('==========================')
                
            for processo in config_estrutura['estrutura']:
                key = processo['chave']['palavra_chave']
                arquivo = processo['chave']['nome_arquivo']
                banco = processo['chave']['banco']
                tabela = processo['chave']['tabela']
                print(f'estrutura json:{processo}')
                print("============================")
                print("resultado:")
                print(key)
                print(arquivo)
                print(banco)
                print(tabela)
                print("============================")
                
                with open(ctrl_ing, 'r+') as controle_ingestao:
                        conteudo_load = controle_ingestao.readlines()
                        print(f'Conteúdo do arquivo de controle de ingestão: {conteudo_load}')

                        for root, dirs, lista in os.walk(landing):
                            print(f'Procurando em {root}...')
                            for nome_arquivo in lista:
                                print(f'Verificando arquivo: {nome_arquivo}')
                                if key in nome_arquivo:
                                    caminho_completo = os.path.join(root, nome_arquivo)
                                    print(f'Arquivo contendo a chave encontrado: {caminho_completo}')
                                    sav = os.path.basename(caminho_completo)
                                    print(f'Conteúdo a gravar: {sav}')

                                    if sav + '\n' not in conteudo_load:
                                        controle_ingestao.write(f"{sav}\n")
                                        print(f'Dado salvo: {sav}')
                                        controle_ingestao.flush()
                                        print('=================================')
                                        
                                        if caminho_completo.endswith('.txt'):
                                            df = pd.read_csv(caminho_completo, delimiter=';', skiprows=[0], names=[col['nome'] for col in config_colunas['colunas']])
                                        elif caminho_completo.endswith('.csv'):
                                            df = pd.read_csv(caminho_completo, skiprows=[0], names=[col['nome'] for col in config_colunas['colunas']])
                                        elif caminho_completo.endswith('.bin'):
                                            pass
                                        else:
                                            raise ValueError("Formato de arquivo não suportado")
                                        print('Convertendo tipos de dados')

                                        for col in config_colunas['colunas']:
                                            if col['tipo'] == 'int':
                                                df[col['nome']] = df[col['nome']].astype(int)
                                            elif col['tipo'] == 'float':
                                                df[col['nome']] = df[col['nome']].astype(float)
                                            elif col['tipo'] == 'data':
                                                df[col['nome']] = pd.to_datetime(df[col['nome']], format=col.get('formato', None))
                                            
                                            
                                                print('Conectando no banco de dados')
                                                banco_caminho = f'/workspaces/projeto_ing/INGESTION/database/{banco}'
                                                conn = sqlite3.connect(banco_caminho)
                                                print(f'Banco de dados: {banco_caminho}')
                                                print(f'Banco de dados criado se não existir: {banco}')
                                                print(f'Conectado!')
                                                print(f"====================================")
                                                cursor = conn.cursor()
                                                
                                                
                                                    print('Criando tabela no banco de dados...')
                                                    sql_create_table = f"CREATE TABLE IF NOT EXISTS {tabela} ("
                                                    for col in config_colunas['colunas']:
                                                        sql_create_table += f"{col['nome']} {col['tipo']}, "
                                                    sql_create_table = sql_create_table[:-2] + ")"
                                                    cursor.execute(sql_create_table)
                                                    print(f'tabela criada: {tabela}')
# Out:
# Conteúdos do diretório 'landing': ['resultado_teste2_20242306_215405.txt']
# Conteúdos do diretório 'layouts': ['teste']
# =====================
# teste é uma pasta
# Conteúdos de teste: ['estrutura.json', 'tabela_teste2.json', 'tabela_teste.json']
# Encontrado estrutura.json em teste
# Configuração estrutura: {'estrutura': [{'descricao': 'tabela teste', 'chave': {'palavra_chave': 'teste', 'nome_arquivo': 'resultado_teste_', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste'}, 'dados': {'ing1': None}}, {'descricao': 'tabela teste 2', 'chave': {'palavra_chave': 'teste2', 'nome_arquivo': 'resultado_teste2_', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste_2'}, 'dados': {'ing2': None}}]}
# Lendo estrutura de coluna json
# ==========================
# estrutura json:{'descricao': 'tabela teste', 'chave': {'palavra_chave': 'teste', 'nome_arquivo': 'resultado_teste_', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste'}, 'dados': {'ing1': None}}
# ============================
# resultado:
# teste
# resultado_teste_
# banco_teste.db
# tabela_teste
# ============================
# Conteúdo do arquivo de controle de ingestão: []
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Verificando arquivo: resultado_teste2_20242306_215405.txt
# Arquivo contendo a chave encontrado: /workspaces/projeto_ing/INGESTION/app/src/landing/resultado_teste2_20242306_215405.txt
# Conteúdo a gravar: resultado_teste2_20242306_215405.txt
# Dado salvo: resultado_teste2_20242306_215405.txt
# =================================
# Convertendo tipos de dados
# Conectando no banco de dados
# Banco de dados: /workspaces/projeto_ing/INGESTION/database/banco_teste.db
# Banco de dados criado se não existir: banco_teste.db
# Conectado!
# ====================================
# Conectando no banco de dados
# Banco de dados: /workspaces/projeto_ing/INGESTION/database/banco_teste.db
# Banco de dados criado se não existir: banco_teste.db
# Conectado!
# ====================================
# estrutura json:{'descricao': 'tabela teste 2', 'chave': {'palavra_chave': 'teste2', 'nome_arquivo': 'resultado_teste2_', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste_2'}, 'dados': {'ing2': None}}
# ============================
# resultado:
# teste2
# resultado_teste2_
# banco_teste.db
# tabela_teste_2
# ============================
# Conteúdo do arquivo de controle de ingestão: ['resultado_teste2_20242306_215405.txt\n']
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Verificando arquivo: resultado_teste2_20242306_215405.txt
# Arquivo contendo a chave encontrado: /workspaces/projeto_ing/INGESTION/app/src/landing/resultado_teste2_20242306_215405.txt
# Conteúdo a gravar: resultado_teste2_20242306_215405.txt

# %%
timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
data_igtao = datetime.now().strftime('%Y-%m-%d')

caminho_backup = '/workspaces/projeto_ing/INGESTION/app/src/backp/'
ctrl_ing = "/workspaces/projeto_ing/INGESTION/app/src/archiving_ctrl/arquivo_controle.txt"
landing = '/workspaces/projeto_ing/INGESTION/app/src/landing/'
layouts = '/workspaces/projeto_ing/INGESTION/app/src/tmp/layouts/'

read_landing = os.listdir(landing)
print("Conteúdos do diretório 'landing':", read_landing)
read_layouts = os.listdir(layouts)
print("Conteúdos do diretório 'layouts':", read_layouts)
print('=====================')

for item in read_layouts:
    accept = os.path.join(layouts, item)
    if os.path.isdir(accept):
        print(f'{item} é uma pasta')
        subconteudos = os.listdir(accept)
        print(f'Conteúdos de {item}: {subconteudos}')

        caminho_estrutura_json = os.path.join(accept, 'estrutura.json')
        if os.path.exists(caminho_estrutura_json):
            print(f'Encontrado estrutura.json em {item}')

            with open(caminho_estrutura_json, 'r') as f:
                config_estrutura = json.load(f)
                print("Configuração estrutura:", config_estrutura)

            caminho_tabela_json = os.path.join(accept, f'tabela_{item}.json')
            with open(caminho_tabela_json, 'r') as f:
                config_colunas = json.load(f)
                print('Lendo estrutura de coluna json')
                print('==========================')
            
            for processo in config_estrutura:
                key = processo['nomeArquivoChave']
                db = processo['banco']
                tabela = processo['tabela']
                print(f'chave unica: {key}')
                print(f'nome banco de dados: {db}')
                print(f'nome tabela: {tabela}')
                print(processo)
                print('==========================')
                
                with open(ctrl_ing, 'r+') as controle_ingestao:
                        conteudo_load = controle_ingestao.readlines()
                        print(f'Conteúdo do arquivo de controle de ingestão: {conteudo_load}')

                        for root, dirs, lista in os.walk(landing):
                            print(f'Procurando em {root}...')
                            for nome_arquivo in lista:
                                print(f'Verificando arquivo: {nome_arquivo}')
                                if key in nome_arquivo:
                                    caminho_completo = os.path.join(root, nome_arquivo)
                                    print(f'Arquivo contendo a chave encontrado: {caminho_completo}')
                                    sav = os.path.basename(caminho_completo)
                                    print(f'Conteúdo a gravar: {sav}')

                                    if sav + '\n' not in conteudo_load:
                                        controle_ingestao.write(f"{sav}\n")
                                        print(f'Dado salvo: {sav}')
                                        controle_ingestao.flush()
                                        print('=================================')
                                        
                                        if caminho_completo.endswith('.txt'):
                                            df = pd.read_csv(caminho_completo, delimiter=';', skiprows=[0], names=[col['nome'] for col in config_colunas['colunas']])
                                        elif caminho_completo.endswith('.csv'):
                                            df = pd.read_csv(caminho_completo, skiprows=[0], names=[col['nome'] for col in config_colunas['colunas']])
                                        elif caminho_completo.endswith('.bin'):
                                            pass
                                        else:
                                            raise ValueError("Formato de arquivo não suportado")
                                        print('Convertendo tipos de dados')

                                        for col in config_colunas['colunas']:
                                            if col['tipo'] == 'int':
                                                df[col['nome']] = df[col['nome']].astype(int)
                                            elif col['tipo'] == 'float':
                                                df[col['nome']] = df[col['nome']].astype(float)
                                            elif col['tipo'] == 'data':
                                                df[col['nome']] = pd.to_datetime(df[col['nome']], format=col.get('formato', None))
                                            
                                        
                                        if caminho_completo.endswith(key):
                                            print("######################")
                                            print(db)
                                            print("######################")
                                        
                                        
                                            # print('Conectando no banco de dados')
                                            # banco_caminho = f'/workspaces/projeto_ing/INGESTION/database/{db}'
                                            # conn = sqlite3.connect(banco_caminho)
                                            # print(f'Banco de dados: {banco_caminho}')
                                            # print(f'Banco de dados criado se não existir: {db}')
                                            # print(f'Conectado!')
                                            # print(f"====================================")
                                            # cursor = conn.cursor()
                                        
                                        
                                            # print(tabela)
                                            # print(key)
                                            # print("=====================================")
                                        # print('Criando tabela no banco de dados...')
                                        # sql_create_table = f"CREATE TABLE IF NOT EXISTS {tabela}"
                                        # print("##################################")
                                        # print(f'TABELA CRIADA: {sql_create_table}')
                                        # print("##################################")
                                            # for col in config_colunas['colunas']:
                                            #     sql_create_table += f"{col['nome']} {col['tipo']}, "
                                            # sql_create_table = sql_create_table[:-2] + ")"
                                            # cursor.execute(sql_create_table)

                                    #     print('Inserindo dados na tabela...')
                                    #     for index, row in df.iterrows():
                                    #         mapped_values = []
                                    #         for col in config_colunas['colunas']:
                                    #             mapped_values.append(row.get(col['nome'], None))
                                    #         print("Valores mapeados:", mapped_values)
                                    #         sql = f"INSERT INTO {tabela} ({', '.join([col['nome'] for col in config_colunas['colunas']])}) VALUES ({', '.join(['?' for _ in mapped_values])})"
                                    #         print("SQL:", sql)
                                    #         cursor.execute(sql, mapped_values)

                                    #     print('Commit e fechamento da conexão...')
                                    #     conn.commit()
                                    #     conn.close()
                                    #     print("Ingestão de dados concluída com sucesso!")

                                    #     print("========================================")
                                    #     print("Movimentando arquivos")
                                    #     shutil.move(caminho_completo, caminho_backup)
                                    #     print(f'Arquivo enviado para bckp: {caminho_completo}')
                                    #     print(f'Destino: {caminho_backup}')

                                    # else:
                                    #     print(f'Dados ignorados para o arquivo: {nome_arquivo}')

            # for processo in config_estrutura:            
            #     banco = processo.get('banco')
            #     nome_tabela = processo.get('tabela')
            #     nomeArquivoChave = processo.get('nomeArquivoChave')
            #     print(f'Nome banco de dados: {banco}')
            #     print(f'Nome chave: {nomeArquivoChave}')
            #     print(f'Nome tabela: {nome_tabela}')
            #     print(f'==============================')
# Out:
# Conteúdos do diretório 'landing': ['resultado_teste2_20242306_215405.txt']
# Conteúdos do diretório 'layouts': ['teste']
# =====================
# teste é uma pasta
# Conteúdos de teste: ['estrutura.json', 'tabela_teste2.json', 'tabela_teste.json']
# Encontrado estrutura.json em teste
# Configuração estrutura: [{'banco': 'banco_teste.db', 'tabela': 'tabela_teste', 'descricao': 'tabela teste', 'nomeArquivoChave': 'teste'}, {'banco': 'banco_teste.db', 'tabela': 'tabela_teste_2', 'descricao': 'tabela teste 2', 'nomeArquivoChave': 'teste2'}]
# Lendo estrutura de coluna json
# ==========================
# chave unica: teste
# nome banco de dados: banco_teste.db
# nome tabela: tabela_teste
# {'banco': 'banco_teste.db', 'tabela': 'tabela_teste', 'descricao': 'tabela teste', 'nomeArquivoChave': 'teste'}
# ==========================
# Conteúdo do arquivo de controle de ingestão: []
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Verificando arquivo: resultado_teste2_20242306_215405.txt
# Arquivo contendo a chave encontrado: /workspaces/projeto_ing/INGESTION/app/src/landing/resultado_teste2_20242306_215405.txt
# Conteúdo a gravar: resultado_teste2_20242306_215405.txt
# Dado salvo: resultado_teste2_20242306_215405.txt
# =================================
# Convertendo tipos de dados
# chave unica: teste2
# nome banco de dados: banco_teste.db
# nome tabela: tabela_teste_2
# {'banco': 'banco_teste.db', 'tabela': 'tabela_teste_2', 'descricao': 'tabela teste 2', 'nomeArquivoChave': 'teste2'}
# ==========================
# Conteúdo do arquivo de controle de ingestão: ['resultado_teste2_20242306_215405.txt\n']
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Verificando arquivo: resultado_teste2_20242306_215405.txt
# Arquivo contendo a chave encontrado: /workspaces/projeto_ing/INGESTION/app/src/landing/resultado_teste2_20242306_215405.txt
# Conteúdo a gravar: resultado_teste2_20242306_215405.txt

# %%
timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
data_igtao = datetime.now().strftime('%Y-%m-%d')

caminho_backup = '/workspaces/projeto_ing/INGESTION/app/src/backp/'
ctrl_ing = "/workspaces/projeto_ing/INGESTION/app/src/archiving_ctrl/arquivo_controle.txt"
landing = '/workspaces/projeto_ing/INGESTION/app/src/landing/'
layouts = '/workspaces/projeto_ing/INGESTION/app/src/tmp/layouts/'

read_landing = os.listdir(landing)
print("Conteúdos do diretório 'landing':", read_landing)
read_layouts = os.listdir(layouts)
print("Conteúdos do diretório 'layouts':", read_layouts)
print('=====================')

for item in read_layouts:
    accept = os.path.join(layouts, item)
    if os.path.isdir(accept):
        print(f'{item} é uma pasta')
        subconteudos = os.listdir(accept)
        print(f'Conteúdos de {item}: {subconteudos}')

        caminho_estrutura_json = os.path.join(accept, 'estrutura.json')
        if os.path.exists(caminho_estrutura_json):
            print(f'Encontrado estrutura.json em {item}')

            with open(caminho_estrutura_json, 'r') as f:
                config_estrutura = json.load(f)
                print("Configuração estrutura:", config_estrutura)

            caminho_tabela_json = os.path.join(accept, f'tabela_{item}.json')
            with open(caminho_tabela_json, 'r') as f:
                config_colunas = json.load(f)
                print('Lendo estrutura de coluna json')

            for processo in config_estrutura['processos']:
                try:
                    banco = processo.get('banco')
                    nome_tabela = processo.get('tabela')
                    nomeArquivoChave = processo.get('nomeArquivoChave')
                    print(f'Nome banco de dados: {banco}')
                    print(f'Nome chave: {nomeArquivoChave}')
                    print(f'Nome tabela: {nome_tabela}')
                    print(f'==============================')

                    with open(ctrl_ing, 'r+') as controle_ingestao:
                        conteudo_load = controle_ingestao.readlines()
                        print(f'Conteúdo do arquivo de controle de ingestão: {conteudo_load}')

                        for root, dirs, lista in os.walk(landing):
                            print(f'Procurando em {root}...')
                            for nome_arquivo in lista:
                                print(f'Verificando arquivo: {nome_arquivo}')
                                if nomeArquivoChave in nome_arquivo:
                                    caminho_completo = os.path.join(root, nome_arquivo)
                                    print(f'Arquivo contendo a chave encontrado: {caminho_completo}')
                                    sav = os.path.basename(caminho_completo)
                                    print(f'Conteúdo a gravar: {sav}')

                                    if sav + '\n' not in conteudo_load:
                                        controle_ingestao.write(f"{sav}\n")
                                        print(f'Dado salvo: {sav}')
                                        controle_ingestao.flush()
                                        print('=================================')

                                        if caminho_completo.endswith('.txt'):
                                            df = pd.read_csv(caminho_completo, delimiter=';', skiprows=[0], names=[col['nome'] for col in config_colunas['colunas']])
                                        elif caminho_completo.endswith('.csv'):
                                            df = pd.read_csv(caminho_completo, skiprows=[0], names=[col['nome'] for col in config_colunas['colunas']])
                                        elif caminho_completo.endswith('.bin'):
                                            pass
                                        else:
                                            raise ValueError("Formato de arquivo não suportado")
                                        print('Convertendo tipos de dados')

                                        for col in config_colunas['colunas']:
                                            if col['tipo'] == 'int':
                                                df[col['nome']] = df[col['nome']].astype(int)
                                            elif col['tipo'] == 'float':
                                                df[col['nome']] = df[col['nome']].astype(float)
                                            elif col['tipo'] == 'data':
                                                df[col['nome']] = pd.to_datetime(df[col['nome']], format=col.get('formato', None))

                                        print('Conectando no banco de dados')
                                        banco_caminho = f'/workspaces/projeto_ing/INGESTION/database/{banco}'
                                        conn = sqlite3.connect(banco_caminho)
                                        print(f'Banco de dados: {banco_caminho}')
                                        print(f'Conectado!')
                                        cursor = conn.cursor()

                                        print('Criando tabela no banco de dados...')
                                        sql_create_table = f"CREATE TABLE IF NOT EXISTS {nome_tabela} ("
                                        for col in config_colunas['colunas']:
                                            sql_create_table += f"{col['nome']} {col['tipo']}, "
                                        sql_create_table = sql_create_table[:-2] + ")"
                                        cursor.execute(sql_create_table)

                                        print('Inserindo dados na tabela...')
                                        for index, row in df.iterrows():
                                            mapped_values = []
                                            for col in config_colunas['colunas']:
                                                mapped_values.append(row.get(col['nome'], None))
                                            print("Valores mapeados:", mapped_values)
                                            sql = f"INSERT INTO {nome_tabela} ({', '.join([col['nome'] for col in config_colunas['colunas']])}) VALUES ({', '.join(['?' for _ in mapped_values])})"
                                            print("SQL:", sql)
                                            cursor.execute(sql, mapped_values)

                                        print('Commit e fechamento da conexão...')
                                        conn.commit()
                                        conn.close()
                                        print("Ingestão de dados concluída com sucesso!")

                                        print("========================================")
                                        print("Movimentando arquivos")
                                        shutil.move(caminho_completo, caminho_backup)
                                        print(f'Arquivo enviado para bckp: {caminho_completo}')
                                        print(f'Destino: {caminho_backup}')

                                    else:
                                        print(f'Dados ignorados para o arquivo: {nome_arquivo}')

                except Exception as e:
                    print(f"Erro ao processar tabela: {processo}")
                    print(e)
