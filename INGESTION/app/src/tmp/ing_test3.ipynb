# %%
import os
import json
import sqlite3
import pandas as pd
import shutil
from datetime import datetime

timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
data_igtao = datetime.now().strftime('%Y-%m-%d')

caminho_backup = '/workspaces/projeto_ing/INGESTION/app/src/backp/'
ctrl_ing = "/workspaces/projeto_ing/INGESTION/app/src/archiving_ctrl/arquivo_controle.txt"
landing = '/workspaces/projeto_ing/INGESTION/app/src/landing/'
layouts = '/workspaces/projeto_ing/INGESTION/app/src/tmp/layouts/'


try:
    read_landing = os.listdir(landing)
    print("Conteúdos do diretório 'landing':", read_landing)
    read_layouts = os.listdir(layouts)
    print("Conteúdos do diretório 'layouts':", read_layouts)
    print('===============================================')
    
    for item in read_layouts:
        accept = os.path.join(layouts, item)
        if os.path.isdir(accept):
            print('========================')
            print(f'item encontrado no diretório: {item}')
            subconteudos = os.listdir(accept)
            print('========================')
            print(f'conteudo: {subconteudos}')
            
            caminho_estrutura_json = os.path.join(accept, 'estrutura.json')
            if os.path.exists(caminho_estrutura_json):
                print(f'Encontrado estrutura.json em {item}')
                
                with open(ctrl_ing, 'r+') as controle_ingestao:
                    conteudo_load = controle_ingestao.readlines()
                    print(f'Conteúdo do arquivo de controle de ingestão: {conteudo_load}')
                    
                with open(caminho_estrutura_json, 'r') as f:
                    config_estrutura = json.load(f)
                    print("Configuração estrutura:", config_estrutura)
                    print("=======================")
                    print("Iniciando ingestão:")
                    print("=======================")
                    for estr in config_estrutura:
                        nm_arq = estr['nome_arquivo']
                        key = estr['chave']['palavra_chave']
                        banco = estr['chave']['banco']
                        tabela = estr['chave']['tabela']
                        print('=======================')
                        print(estr)
                        print(nm_arq)
                        print(key)
                        print(banco)
                        print(tabela)
                        print('=======================')
                                
                        for root, dirs, lista in os.walk(landing):
                            print(f'Procurando em {root}...')
                            for nome_arquivo in lista:
                                print(f'Verificando arquivo: {nome_arquivo}')
                                if key in nome_arquivo:
                                    caminho_completo = os.path.join(root, nome_arquivo)
                                    print(f'Arquivo contendo a chave encontrado: {caminho_completo}')
                                    
                                    sav = os.path.basename(caminho_completo)
                                    print(f'Conteúdo a gravar: {sav}')
                                    
                                    if sav + '\n' not in conteudo_load:
                                        with open(ctrl_ing, 'a') as controle_ingestao:
                                            controle_ingestao.write(f"{sav}\n")
                                            print(f'nomenclatura do arquivo salvo: {sav}')
                                            print('=================================')
                                    
                                    parte_util = sav.split('_')[1]
                                    if parte_util == key:
                                        print('Chave encontrada')
                                        print(f'Separando nome do arquivo: {parte_util}')
                                        caminho_tabela_json = os.path.join(accept, f'{tabela}.json')
                                        print(f'local para criar tabela: {caminho_tabela_json}')
                                        if os.path.exists(caminho_tabela_json):
                                            with open(caminho_tabela_json, 'r') as f:     
                                                config_colunas = json.load(f)
                                            print(config_colunas)
                                            print(f'resultado configuracao colunas: {config_colunas}')
                                            print('===============================')
                                            for j in config_colunas['colunas']:
                                                print(f'iterando config: {j}')
                                            
                                            if caminho_completo.endswith('.txt'):
                                                df = pd.read_csv(caminho_completo, delimiter=';', skiprows=[0], names=[col['nome'] for col in config_colunas['colunas'] if 'nome' in col])
                                                print(f'dados a carregar:{df}')
                                                print('estrutura de colunas txt:')
                                                print(df.columns)
                                                print('=====================')
                                            elif caminho_completo.endswith('.csv'):
                                                df = pd.read_csv(caminho_completo, skiprows=[0], names=[col['nome'] for col in config_colunas['colunas'] if 'nome' in col])
                                                print(f'dados a carregar:{df}')
                                                print('estrutura de colunas csv:')
                                                print(df.columns)
                                                print('=====================')
                                            elif caminho_completo.endswith('.bin'): 
                                                pass
                                            
                                            else:
                                                raise ValueError("Formato de arquivo não suportado")
                                            
                                            for col in config_colunas['colunas']:  
                                                if 'nome' in col and 'tipo' in col:
                                                    if col['tipo'] == 'int':
                                                        df[col['nome']] = df[col['nome']].astype(int)
                                                    elif col['tipo'] == 'float':
                                                        df[col['nome']] = df[col['nome']].astype(float)
                                                    elif col['tipo'] == 'data':
                                                        df[col['nome']] = pd.to_datetime(df[col['nome']], format=col.get('formato', None))
                                                        
                                            banco_caminho = f'/workspaces/projeto_ing/INGESTION/database/{banco}'
                                            conn = sqlite3.connect(banco_caminho)
                                            print(f'Banco de dados: {banco_caminho}')
                                            print(f'Banco de dados criado se não existir: {banco}')
                                            print(f'Conectado!')
                                            print(f"====================================")
                                            
                                            cursor = conn.cursor()
                                            nm_tb = f'tabela_{parte_util}'
                                            sql_create_table = f"CREATE TABLE IF NOT EXISTS {nm_tb} ("
                                            for col in config_colunas['colunas']:
                                                if 'nome' in col and 'tipo' in col:
                                                    sql_create_table += f"{col['nome']} {col['tipo']}, "
                                            sql_create_table = sql_create_table[:-2] + ")"
                                            cursor.execute(sql_create_table)
                                            print(f'Tabela criada: {nm_tb}')
                                            print(f'estrutura da tabela criada: {sql_create_table}')
                                            
                                            for index, row in df.iterrows():
                                                mapped_values = [row.get(col['nome'], None) for col in config_colunas['colunas'] if 'nome' in col]
                                                print("Valores mapeados:", mapped_values)
                                                sql = f"INSERT INTO {nm_tb} ({', '.join([col['nome'] for col in config_colunas['colunas'] if 'nome' in col])}) VALUES ({', '.join(['?' for _ in mapped_values])})"
                                                print("SQL:", sql)
                                                cursor.execute(sql, mapped_values)
                                        
                                            conn.commit()
                                            conn.close()
                                            print("Ingestão de dados concluída com sucesso!")
                                            print("====================================")
                                            
                                        shutil.move(caminho_completo, caminho_backup)
                                        print(f'Arquivo enviado para backup: {caminho_completo}')
                                        print(f'Destino: {caminho_backup}')
                                        print('==========================')
                                    else:
                                        print('Chave não encontrada no arquivo')
                                    break
except Exception as e:
    print(f"Erro: {e}")
# Out:
# Conteúdos do diretório 'landing': ['modelo_vw_20240719_140024.txt']
# Conteúdos do diretório 'layouts': ['teste', 'car']
# ===============================================
# ========================
# item encontrado no diretório: teste
# ========================
# conteudo: ['estrutura.json', 'tabela_teste2.json', 'tabela_teste.json']
# Encontrado estrutura.json em teste
# Conteúdo do arquivo de controle de ingestão: ['resultado_teste2_20242306_215405.txt\n', 'resultado_teste_20242506_202032.txt\n', 'resultado_cepavenidamairipora_20240711_121430.txt\n', 'dados_bank_20240713172538.txt\n', 'dados_geo_2024-07-14.txt\n', 'resultado_marcas_20240719_134627.txt\n', 'modelo_vw_20240719_140024.txt\n', 'resultado_calendario_20240719_145047.txt\n']
# Configuração estrutura: [{'nome_arquivo': 'resultado_teste_', 'descricao': 'tabela teste', 'chave': {'palavra_chave': 'teste', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste'}}, {'nome_arquivo': 'resultado_teste2_', 'descricao': 'tabela teste 2', 'chave': {'palavra_chave': 'teste2', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste2'}}]
# =======================
# Iniciando ingestão:
# =======================
# =======================
# {'nome_arquivo': 'resultado_teste_', 'descricao': 'tabela teste', 'chave': {'palavra_chave': 'teste', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste'}}
# resultado_teste_
# teste
# banco_teste.db
# tabela_teste
# =======================
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Verificando arquivo: modelo_vw_20240719_140024.txt
# =======================
# {'nome_arquivo': 'resultado_teste2_', 'descricao': 'tabela teste 2', 'chave': {'palavra_chave': 'teste2', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste2'}}
# resultado_teste2_
# teste2
# banco_teste.db
# tabela_teste2
# =======================
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Verificando arquivo: modelo_vw_20240719_140024.txt
# ========================
# item encontrado no diretório: car
# ========================
# conteudo: ['estrutura.json', 'tabela_vw.json', 'tabela_marcas.json']
# Encontrado estrutura.json em car
# Conteúdo do arquivo de controle de ingestão: ['resultado_teste2_20242306_215405.txt\n', 'resultado_teste_20242506_202032.txt\n', 'resultado_cepavenidamairipora_20240711_121430.txt\n', 'dados_bank_20240713172538.txt\n', 'dados_geo_2024-07-14.txt\n', 'resultado_marcas_20240719_134627.txt\n', 'modelo_vw_20240719_140024.txt\n', 'resultado_calendario_20240719_145047.txt\n']
# Configuração estrutura: [{'nome_arquivo': 'resultado_marcas_', 'descricao': 'tabela resultado de marcas de carros', 'chave': {'palavra_chave': 'marcas', 'banco': 'banco_car.db', 'tabela': 'tabela_marcas'}}, {'nome_arquivo': 'modelo_vw_', 'descricao': 'tabela resultado de modelos volkswagem', 'chave': {'palavra_chave': 'vw', 'banco': 'banco_car.db', 'tabela': 'tabela_vw'}}]
# =======================
# Iniciando ingestão:
# =======================
# =======================
# {'nome_arquivo': 'resultado_marcas_', 'descricao': 'tabela resultado de marcas de carros', 'chave': {'palavra_chave': 'marcas', 'banco': 'banco_car.db', 'tabela': 'tabela_marcas'}}
# resultado_marcas_
# marcas
# banco_car.db
# tabela_marcas
# =======================
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Verificando arquivo: modelo_vw_20240719_140024.txt
# =======================
# {'nome_arquivo': 'modelo_vw_', 'descricao': 'tabela resultado de modelos volkswagem', 'chave': {'palavra_chave': 'vw', 'banco': 'banco_car.db', 'tabela': 'tabela_vw'}}
# modelo_vw_
# vw
# banco_car.db
# tabela_vw
# =======================
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Verificando arquivo: modelo_vw_20240719_140024.txt
# Arquivo contendo a chave encontrado: /workspaces/projeto_ing/INGESTION/app/src/landing/modelo_vw_20240719_140024.txt
# Conteúdo a gravar: modelo_vw_20240719_140024.txt
# Chave encontrada
# Separando nome do arquivo: vw
# local para criar tabela: /workspaces/projeto_ing/INGESTION/app/src/tmp/layouts/car/tabela_vw.json
# {'colunas': [{'nome': 'codigo', 'tipo': 'string'}, {'nome': 'modelo', 'tipo': 'string'}]}
# resultado configuracao colunas: {'colunas': [{'nome': 'codigo', 'tipo': 'string'}, {'nome': 'modelo', 'tipo': 'string'}]}
# ===============================
# iterando config: {'nome': 'codigo', 'tipo': 'string'}
# iterando config: {'nome': 'modelo', 'tipo': 'string'}
# dados a carregar:     codigo                                    modelo
# 0      5585  AMAROK CD2.0 16V/S CD2.0 16V TDI 4x2 Die
# 1      5586  AMAROK CD2.0 16V/S CD2.0 16V TDI 4x4 Die
# 2      9895  AMAROK Comfor. 3.0 V6 TDI 4x4 Dies. Aut.
# 3      8531  AMAROK Comfor. CD 2.0 TDI 4x4 Dies. Aut.
# 4      5748  AMAROK CS2.0 16V/S2.0 16V TDI 4x2 Diesel
# ..      ...                                       ...
# 534    6672  VOYAGE SELEÇÃO 1.6 I MOTION T.Flex 8V 4p
# 535    6673       VOYAGE SELEÇÃO 1.6 Total Flex 8V 4p
# 536    4755      VOYAGE TREND 1.6 Mi Total Flex 8V 4p
# 537    7524        VOYAGE Trendline 1.0 T.Flex 12V 4p
# 538    6809         VOYAGE Trendline 1.6 T.Flex 8V 4p
#
# [539 rows x 2 columns]
# estrutura de colunas txt:
# Index(['codigo', 'modelo'], dtype='object')
# =====================
# Banco de dados: /workspaces/projeto_ing/INGESTION/database/banco_car.db
# Banco de dados criado se não existir: banco_car.db
# Conectado!
# ====================================
# Tabela criada: tabela_vw
# estrutura da tabela criada: CREATE TABLE IF NOT EXISTS tabela_vw (codigo string, modelo string)
# Valores mapeados: [5585, 'AMAROK CD2.0 16V/S CD2.0 16V TDI 4x2 Die']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5586, 'AMAROK CD2.0 16V/S CD2.0 16V TDI 4x4 Die']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [9895, 'AMAROK Comfor. 3.0 V6 TDI 4x4 Dies. Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8531, 'AMAROK Comfor. CD 2.0 TDI 4x4 Dies. Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5748, 'AMAROK CS2.0 16V/S2.0 16V TDI 4x2 Diesel']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5749, 'AMAROK CS2.0 16V/S2.0 16V TDI 4x4 Diesel']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8532, 'AMAROK Extreme CD 3.0 4x4 TB Dies. Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7854, 'AMAROK Hig. Extreme CD 2.0 4x4 Dies. Aut']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7674, 'AMAROK Hig.ULTIMATE CD 2.0 4x4 Dies. Aut']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5940, 'AMAROK High.CD 2.0 16V TDI 4x4 Dies. Aut']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5261, 'AMAROK Highline CD 2.0 16V TDI 4x4 Dies.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8183, 'AMAROK Highline CD 3.0 4x4 TB Dies. Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5476, 'AMAROK SE CD 2.0 16V TDI 4x4 Diesel']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7367, 'AMAROK T. Dark Label CD 2.0 4x4 Dies Aut']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5350, 'AMAROK Trendline CD 2.0 16V TDI 4x4 Dies']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6277, 'AMAROK Trendline CD 2.0 TDI 4X4 Dies Aut']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2359, 'Apolo GL 1.8']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2360, 'Apolo GLS/ Vip 1.8']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2362, 'Bora 2.0 8v Comfortline Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2363, 'Bora 2.0 8v Comfortline Mec.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2361, 'Bora 2.0/ 2.0 Flex 8v Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2364, 'Bora 2.0/ 2.0 Flex 8v Mec.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2365, 'Caravelle 2.4 Diesel']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2366, 'Corrado 2.0 Turbo']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2367, 'Corrado G-60 2.8']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7077, 'CROSSFOX  1.6 T. Flex 16V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7078, 'CROSSFOX  I MOTION 1.6 T. Flex 16V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2368, 'CROSSFOX 1.6 Mi Total Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5983, 'CROSSFOX I MOTION 1.6 Mi T. Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [10368, 'Delivery Express Turbo Diesel (E6)']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [10137, 'Delivery Express+ Turbo Diesel']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4857, 'EOS Cab. 2.0 Turbo FSI Tiptronic']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2369, 'Eurovan 2.4 Diesel']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5082, 'Fox 1.0 Mi Total Flex 8V 3p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5083, 'Fox 1.0 Mi Total Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5084, 'Fox 1.6 Mi I MOTION Total Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5085, 'Fox 1.6 Mi Total Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6548, 'Fox BLUEMOTION 1.0 Mi Total Flex 12V 3p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6549, 'Fox BLUEMOTION 1.0 Mi Total Flex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6039, 'Fox BlueMotion 1.6 Mi Total Flex 3p.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6040, 'Fox BlueMotion 1.6 Mi Total Flex 5p.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2370, 'Fox City 1.0 Mi/ 1.0Mi Total Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2371, 'Fox City 1.0Mi/ 1.0Mi Total Flex 8V 3p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7269, 'Fox Comfortline 1.0 Flex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6934, 'Fox Comfortline 1.0 Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6935, 'Fox Comfortline 1.6 Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6936, 'Fox Comfortline I Motion 1.6 Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8112, 'Fox Connect 1.6 Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8133, 'Fox Connect I Motion 1.6 Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4668, 'Fox extreme 1.6 Mi Total Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6937, 'Fox Highline I MOTION 1.6 Flex 16V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6938, 'Fox Highline1.6 Flex 16V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7172, 'Fox PEPPER 1.6 Flex 16V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7173, 'Fox PEPPER I MOTION 1.6 Flex 16V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2372, 'Fox Plus 1.0Mi/ 1.0Mi Total Flex 8V 3p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2373, 'Fox Plus 1.0Mi/ 1.0Mi Total Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2374, 'Fox Plus 1.6Mi/ 1.6Mi Total Flex 8V 3p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2375, 'Fox Plus 1.6Mi/ 1.6Mi Total Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5087, 'Fox PRIME/Hghi. IMOTION 1.6 T.Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5086, 'Fox PRIME/Higli. 1.6 Total Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5599, 'Fox Rock in Rio 1.6 Mi Total Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4349, 'Fox Route 1.0 Mi Total Flex 8V 3p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4350, 'Fox Route 1.0 Mi Total Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4351, 'Fox Route 1.6 Mi Total Flex 8V 3p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4352, 'Fox Route 1.6 Mi Total Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7637, 'Fox RUN 1.6 Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6667, 'Fox SELEÇÃO 1.0 Total Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6668, 'Fox SELEÇÃO 1.6 Total Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6784, 'Fox SELEÇÃO IMOTION 1.6 Mi T. Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2379, 'Fox Sportline/Sports 1.0 Tot.Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2376, 'Fox Sportline/Sports 1.0/1.0 Tot.Flex 3p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2377, 'Fox Sportline/Sports 1.6/1.6 Tot.Flex 3p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2378, 'Fox Sportline/Sports 1.6/1.6 Tot.Flex 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4928, 'Fox SUNRISE 1.0 Mi Total Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7410, 'Fox TRACK 1.0 Flex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7295, 'Fox Trendline 1.0 Flex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6939, 'Fox Trendline 1.0 Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6940, 'Fox Trendline 1.6 Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8113, 'Fox Xtreme 1.6 Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2380, 'Fusca']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7079, 'Fusca 2.0 R-Line TSI 16V Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6278, 'Fusca 2.0 TSI 16V Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6279, 'Fusca 2.0 TSI 16V Mec.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6280, 'Gol (novo) 1.0 Mi Total Flex 8V 2p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4689, 'Gol (novo) 1.0 Mi Total Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6281, 'Gol (novo) 1.6 Mi Total Flex 8V 2p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4691, 'Gol (novo) 1.6 Mi Total Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4690, 'Gol (novo) 1.6 Power/Highi T.Flex 8v 4P']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8323, 'Gol 1.0 Flex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2381, 'Gol 1.0 Mi FUN/ Highway/ Sport 16V  2/4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2382, 'Gol 1.0 Plus 16v 2p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2383, 'Gol 1.0 Plus 16v 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2384, 'Gol 1.0 Plus 8v 2p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2385, 'Gol 1.0 Plus 8v 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2386, 'Gol 1.0 Power 16v 76cv 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5941, 'Gol 1.0 Total Flex 8V 5p (25 Anos)']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2387, 'Gol 1.0 Trend/ Power 8V 2p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2388, 'Gol 1.0 Trend/ Power 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5114, 'Gol 1.6 I MOTI.Power/Highli T.Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6454, 'Gol 1.6 Mi I MOTION Total Flex 8V 3p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2389, 'Gol 1.6 Mi Plus Total Flex 8V 2p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2390, 'Gol 1.6 Mi Plus Total Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2391, 'Gol 1.6 Mi Power Total Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5404, 'Gol 1.6 Mi Rallye I MOTION T. Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2392, 'Gol 1.6 Mi Rallye Total Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2393, 'Gol 1.6 Mi/ 1.6i 2p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2394, 'Gol 1.6 Mi/ Power 1.6 Mi 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8463, 'Gol 1.6 MSI Flex 16V 5p Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8324, 'Gol 1.6 MSI Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2395, 'Gol 1.8 Mi']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2396, 'Gol 1.8 Mi 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2397, 'Gol 1.8 Mi Power Total Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2398, 'Gol 1.8 Mi Rallye Total Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2399, 'Gol 1000 (modelo antigo)']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2400, 'Gol 1000 Mi 16V 2p Turbo']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2401, 'Gol 1000 Mi 16V 4p Turbo']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2402, 'Gol 1000 Mi 16V/ Ouro  2p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2403, 'Gol 1000 Mi 16V/ Ouro 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2404, 'Gol 1000 Mi 2p  / 1000i']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2405, 'Gol 1000 Mi 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2406, 'Gol 1000 Mi Plus 16V 2p e 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2407, 'Gol 1000 Mi Plus 8v 2p e 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2408, 'Gol 1000i Plus 2p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2409, 'Gol 2.0 Mi 2p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2410, 'Gol 2.0 Mi 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5750, 'Gol BLACK 1.0 Mi Total Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2413, 'Gol City (Trend) 1.0 Mi Total Flex 8V 2p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [3832, 'Gol City (Trend) 1.6 Mi T. Flex 8V 2p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2417, 'Gol City (Trend) 1.6 Mi T.Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2414, 'Gol City (Trend)/Titan 1.0 T. Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2411, 'Gol City 1.0 Mi 8V 2p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2412, 'Gol City 1.0 Mi 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [9098, 'Gol City 1.0 Total Flex 12V 2p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8840, 'Gol City 1.0 Total Flex 12V 4P']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2415, 'Gol City 1.6 Mi 8V 2p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2416, 'Gol City 1.6 Mi 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2418, 'Gol CL 1.6 Mi 2p e 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2419, 'Gol CL 1.8 Mi 2p e 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2420, 'Gol CLi / CL 1.8']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2421, 'Gol CLi / CL/ Copa/ Stones 1.6']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6791, 'Gol Comfort. I MOTION 1.6 T. Flex 8V 3p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6792, 'Gol Comfort. I MOTION 1.6 T. Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7521, 'Gol Comfortline 1.0 T. Flex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6787, 'Gol Comfortline 1.0 T. Flex 8V 3p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6788, 'Gol Comfortline 1.0 T. Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6789, 'Gol Comfortline 1.6 T. Flex 8V 3p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6790, 'Gol Comfortline 1.6 T. Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [3958, 'Gol COPA 1.0 Mi Total Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [3959, 'Gol COPA 1.6 Mi Total Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5218, 'Gol ECOMOTION  1.0 Mi Total Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5219, 'Gol ECOMOTION 1.0 Mi Total Flex 8V 2p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2422, 'Gol Furgao 1.0 mi']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2423, 'Gol Furgão 1.6 Mi/ 1.6i/ 1.6']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2424, 'Gol GL 1.6 Mi/Star 1.6 e 1.8/Atlanta 1.6']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2425, 'Gol GL 1.8 Mi 2p e 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2426, 'Gol GLi / GL/ Atlanta 1.8']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2427, 'Gol GLS 2.0 Mi']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2428, 'Gol GT/GTS 1.8']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2429, 'Gol GTi 2.0']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2430, 'Gol GTi 2000 16V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5113, 'Gol I MOTION 1.6 Mi Total Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2431, 'Gol L 1.3/ L/ LS/ C/ S/ BX/ Plus 1.6']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [10166, 'Gol Last Edition 1.0 Flex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [3833, 'Gol Plus 1.0 Mi Total Flex 2p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [3834, 'Gol Plus 1.0 Mi Total Flex 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6795, 'Gol Rallye 1.6 T. Flex 16V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6793, 'Gol Rallye I MOTION 1.6 T. Flex 16V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5600, 'Gol Rock in Rio 1.0 Mi Total Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5220, 'Gol SELEÇÃO 1.0 Mi Total Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6669, 'Gol SELEÇÃO 1.6 I MOTION T.Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6670, 'Gol SELEÇÃO 1.6 Total Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2432, 'Gol Special 1.0 Mi 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7049, 'Gol Special 1.0 Total Flex 8V 3p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7050, 'Gol Special 1.0 Total Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2433, 'Gol Special 1.6 Mi 8V 99cv 2p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2434, 'Gol Special/ Special Xtreme 1.0 Mi 2p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4092, 'Gol TECH 1.0 Mi Total Flex 8V 2p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4093, 'Gol TECH 1.0 Mi Total Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6472, 'Gol TRACK 1.0 Mi Total Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7817, 'Gol TRACK 1.0 Total Flex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7638, 'Gol Trendline 1.0 T.Flex 12V 3p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7522, 'Gol Trendline 1.0 T.Flex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6785, 'Gol Trendline 1.0 T.Flex 8V 3p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6786, 'Gol Trendline 1.0 T.Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6977, 'Gol Trendline 1.6 T.Flex 8V 3p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6796, 'Gol Trendline 1.6 T.Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6976, 'Gol Trendline I Motion 1.6 T. Flex 8V 3p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6794, 'Gol Trendline I MOTION 1.6 T. Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2435, 'Gol TSi 1.8/ 1.8Mi']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2436, 'Gol TSi 2000 2p e 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5115, 'Golf  BLACK EDITON 2.0 Mi T. Flex 8V Tip']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4669, 'Golf  TECH 1.6 Mi Total Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4006, 'Golf 1.6 Mi Total Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2437, 'Golf 1.6 Mi Trip/ Sport 101cv 8V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2438, 'Golf 1.6Mi/ 1.6Mi Gener./Black & Silver']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2439, 'Golf 1.8 Mi Sport 150cv Turbo Mec/Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2440, 'Golf 2.0/ 2.0 Mi Flex Aut/Tiptronic.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2442, 'Golf 2.0/ 2.0 Mi Flex Comfortline Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2443, 'Golf 2.0/ 2.0 Mi Flex Comfortline/ Sport']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2441, 'Golf 2.0/2.0 T. Flex Mec.(Black & Silv)']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8369, 'Golf Comfort. 200 TSI 1.0 Flex 12V Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7781, 'Golf Comfortline 1.0 TSI Total Flex Mec.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6797, 'Golf Comfortline 1.4 TSI 140cv Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6798, 'Golf Comfortline 1.4 TSI 140cv Mec.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7460, 'Golf Comfortline 1.6 MSI Total Flex Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7461, 'Golf Comfortline 1.6 MSI Total Flex Mec.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [3914, 'Golf Flash 1.6 Mi/1.6 Mi Tot. Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2444, 'Golf GL 1.8/ 2.0i 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2445, 'Golf GLX 2.0 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4835, 'Golf GT 2.0 Mi T. Flex 8V 4p Tiptronic']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4703, 'Golf GT 2.0 Mi Total Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8943, 'Golf GTE TSI 1.4 16V Híbrido Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2446, 'Golf GTi 1.8 Mi 180/193cv Turbo 4p Mec.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2447, 'Golf GTi 1.8 Mi 180/193cv Turbo 4p Tip.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2448, 'Golf GTi 1.8 Mi 20V 2p Turbo Mec.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2449, 'Golf GTi 1.8 Mi 20V Turbo 2p Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2450, 'Golf GTi 1.8 Mi 20V Turbo 4p Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2451, 'Golf GTi 1.8 Mi 20V Turbo 4p Mec.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2452, 'Golf GTI 1.8 Turbo']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2453, 'Golf GTi 2.0']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6600, 'Golf GTi 2.0 TSI 220cv Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8370, 'Golf GTi 350 TSI 2.0 230cv 16V Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2454, 'Golf GTi Cabrio 2.0 Mi']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2455, 'Golf GTI VR6/ Golf 2.8 VR6']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6601, 'Golf Highline 1.4 TSI 140cv Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6602, 'Golf Highline 1.4 TSI 140cv Mec.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7462, 'Golf Highline 1.4 TSI Total Flex Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7463, 'Golf Highline 1.4 TSI Total Flex Mec.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8371, 'Golf Highline 250 TSI 1.4 Flex 16V Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5007, 'Golf SILVER EDIT. 2.0 Mi T.Flex 8v Mec.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5008, 'Golf SILVER EDIT. 2.0 Mi T.Flex 8V Tip.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4312, 'Golf Sportline 1.6 Mi Total Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5221, 'Golf Sportline 2.0 Mi Total F. 8V Tip.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8372, 'Golf Variant Comf. 250 1.4 TSI Flex Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7782, 'Golf Variant Comfort. 1.4 TSI T.Flex Aut']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7270, 'Golf Variant Comfortline 1.4 TSI  Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7464, 'Golf Variant Comfortline 1.4 TSI Mec.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8373, 'Golf Variant High. 250 1.4 TSI Flex Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7748, 'Golf Variant Highli. 1.4 TSI T.Flex Aut']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7271, 'Golf Variant Highline 1.4 TSI Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2456, 'Grand Saveiro Xtreme/Street  1.6/1.8/2.0']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2457, 'JETTA  GLX III 2.8 VR6']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4147, 'JETTA 2.5 20V 150/170cv Tiptronic']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8581, 'JETTA 250 TSI 1.4 flex 16v Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8487, 'JETTA Comfort. 250 TSI 1.4 Flex 16v Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5512, 'JETTA Comfortline  2.0 T.Flex 8V 4p Mec.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7493, 'JETTA Comfortline 1.4 TSI 16V 4p Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5513, 'JETTA Comfortline 2.0 T.Flex 8V 4p Tipt.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8717, 'JETTA GLI 350 TSI 2.0 16V 4p Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5514, 'JETTA Highline 2.0 TSI 16V 4p Tiptronic']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8488, 'JETTA R-Line 250 TSI 1.4 Flex 16V Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7494, 'JETTA Trendline 1.4 TSI 16V 4p  Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7495, 'JETTA Trendline 1.4 TSI 16V 4p Mec.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7216, 'JETTA Trendline 2.0 T.Flex 8V 4p Tip.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4649, 'JETTA Variant 2.5 20V 170cv Tiptronic']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2458, 'Kombi Carat']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2459, 'Kombi Escolar 1.6 MPi']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [3980, 'Kombi Escolar/50 anos 1.4 Mi Total Flex']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2460, 'Kombi Furgão']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [3915, 'Kombi Furgão 1.4 Mi Total Flex 8V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2461, 'Kombi Furgão Diesel']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6618, 'Kombi LAST EDITION 56 1.4 Mi Total Flex']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [3981, 'Kombi Lotação 1.4 Mi Total Flex 8V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2462, 'Kombi Lotação 1.6 MPi']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2463, 'Kombi Pick-Up']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2464, 'Kombi Pick-Up Diesel']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [3916, 'Kombi Standard 1.4 Mi Total Flex 8V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2465, 'Kombi Standard/ Luxo/ Série Prata']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2466, 'Logus 1.6 / CLi / CL/ GL']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2467, 'Logus 1.8 / CLi / CL']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2468, 'Logus GLi / GL 1.8']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2469, 'Logus GLS 1.8']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2470, 'Logus GLSi / GLS 2000']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2471, 'Logus Wolfsburg Edition 2000i']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2472, 'New Beetle 2.0 Mi Mec./Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [9150, 'Nivus Comfortline 1.0 200 TSI Flex Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [9151, 'Nivus Highline 1.0 200 TSI Flex Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [9152, 'Nivus Launching Ed. 1.0 200 TSI Flex Aut']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [11068, 'Nivus Sense 1.0 200 TSI Flex Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2473, 'Parati 1.0 Mi FUN/ SunSet 16V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2474, 'Parati 1.0 Mi Plus 16v 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2475, 'Parati 1.0 Mi Summer 16v 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2476, 'Parati 1.0 Mi Tour 16V 76cv 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2500, 'Parati 1.6 Mi Plus Total Flex  8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2477, 'Parati 1.6 Mi/ 1.6 Mi City']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2478, 'Parati 1.6Mi/1.6Mi City/T.Field T.Flex']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2479, 'Parati 1.8 Mi City Total Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2480, 'Parati 1.8 Mi CROSSOVER Total Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [3804, 'Parati 1.8 Mi Plus Total Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2481, 'Parati 1.8 Mi T. Field Total Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2482, 'Parati 1.8 Mi Tour 8V 99cv 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2483, 'Parati 1.8 Mi/ 1.8 Mi Plus']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2484, 'Parati 1000 Mi 16V 2p e 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2485, 'Parati 1000 Mi 16V 4p Turbo']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2486, 'Parati 2.0 Mi Tour 8V 112cv 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2487, 'Parati 2.0 Mi/ 2.0 Mi Track & Field']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2488, 'Parati C 1.6/ CL 1.6 Mi 2p e 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2489, 'Parati CL 1.8 Mi 2p e 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2490, 'Parati CLi / CL/ Atlanta 1.6']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2491, 'Parati CLi / CL/ Atlanta 1.8']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [3960, 'Parati COMFORTLINE 1.6 Mi Tot.Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [3805, 'Parati COMFORTLINE 1.8 Mi Tot.Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2492, 'Parati CROSSOVER 2.0 8V/ 1.0 16V TB 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2493, 'Parati Evidence 1.8 8V/ 1.0 16V TB 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2494, 'Parati GL 1.6 Mi/ 1.6/ GLS/ Club 1.6']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2495, 'Parati GL 1.8 Mi/ Club 1.8 Mi 2p e 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2496, 'Parati GLi / GL 1.8']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2497, 'Parati GLS 2.0 Mi 2/4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2498, 'Parati GLSi 2.0 / GLS/ Surf 1.8']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2499, 'Parati GTi 2.0 Mi 16V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2501, 'Parati Plus/ LS/ S']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4521, 'Parati SURF 1.6 Mi Total Flex']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4522, 'Parati SURF 1.8 Mi Total Flex']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4908, 'Parati TITAN 1.6 Mi Total Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2502, 'Parati Utility 1.8 8V/ 1.0 Turbo 16V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2503, 'Passat  L/LS/LSe/GL/GLS/TS/Fla/Vill/Plus']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2504, 'Passat 1.8 Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2505, 'Passat 1.8 Mec.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2506, 'Passat 1.8 Tiptronic']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2507, 'Passat 2.0']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [3806, 'Passat 2.0 FSI Tiptronic']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2508, 'Passat 2.8 V6 Mec.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2509, 'Passat 2.8 V6 Protect Tiptronic']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2510, 'Passat 2.8 V6 Tiptronic']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4322, 'Passat 3.2 V6 FSI 24V 250cv Tip.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6896, 'Passat CC 2.0 TSI 211cv Tiptronic']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4929, 'Passat CC 3.6 V6 FSI 300cv Tiptronic']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7465, 'Passat Comfortline 2.0 TSI 220cv Tip.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7466, 'Passat Highline 2.0 TSI 220cv Tip.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2511, 'Passat Pointer GTS']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7051, 'Passat R-Line TB 2.0 TSI Tiptronic 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4148, 'Passat TB 2.0 FSI/TSI 211cv Tiptronic 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2512, 'Passat Turbo 1.8 Mec.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2513, 'Passat Turbo 1.8 Tiptronic']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [3917, 'Passat Variant  2.0 FSI 150cv Tiptron.5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2514, 'Passat Variant 1.8 Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2515, 'Passat Variant 1.8 Mec.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2516, 'Passat Variant 2.0']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2517, 'Passat Variant 2.8 V6']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2518, 'Passat Variant 2.8 V6 Tiptronic']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4323, 'Passat Variant 3.2 V6 FSI 24V 250cv Tip.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7320, 'Passat Variant R-Line TB 2.0 TSI Tip. 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2519, 'Passat Variant Turbo 1.8']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2520, 'Passat Variant Turbo 1.8 Tiptronic']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4149, 'Passat Variant Turbo 2.0 FSI Tiptron. 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2521, 'Passat Variant VR6 2.8']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2522, 'Passat VR6 2.8']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2523, 'Pointer 1.8 / CLi']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2524, 'Pointer GLi 1.8']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2525, 'Pointer GLi 2.0']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2526, 'Pointer GTi 2.0']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8070, 'Polo 1.0 Flex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2527, 'Polo 1.0 Mi 79cv 16V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [10107, 'Polo 1.0 MPI Flex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [10108, 'Polo 1.0 TSI Flex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4930, 'Polo 1.6 E-Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2528, 'Polo 1.6 Mi/ S.Ouro 1.6Mi 101cv 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2529, 'Polo 1.6 Mi/S.Ouro 1.6 Mi Tot.Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8067, 'Polo 1.6 MSI Flex 16V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8426, 'Polo 1.6 MSI Total Flex 16V 5p Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2530, 'Polo 2.0 Mi 116cv 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4909, 'Polo BLUEMOTION 1.6 Total Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2531, 'Polo Classic 1.0 Mi 16v  65cv 4p']
# ...
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2558, 'Saveiro CL 1.6 Mi / CL/ C 1.6']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2559, 'Saveiro CL/ Summer 1.8 Mi e 1.8']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5195, 'Saveiro CROSS 1.6 Mi Total Flex 8V CE']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6801, 'Saveiro CROSS 1.6 T. Flex 16V CE']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6941, 'Saveiro CROSS 1.6 T.Flex 16V CD']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [3962, 'Saveiro CROSSOVER 1.6 Mi Total Flex 8V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2560, 'Saveiro CROSSOVER 1.8 Mi 8V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2561, 'Saveiro CROSSOVER 1.8 Mi Total Flex 8V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2562, 'Saveiro Diesel (todas)']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [10832, 'Saveiro Extreme 1.6 Flex 16V CD']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2563, 'Saveiro FUN 1.8 99cv/ City e S.Surf  1.6']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2564, 'Saveiro GL 1.8Mi e 1.6/GL/LS/S/ Sunset']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6942, 'Saveiro Highline 1.6 T. Flex 8V CD']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8026, 'Saveiro Pepper 1.6 Flex 8V CD']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8027, 'Saveiro Pepper 1.6 Flex 8V CE']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [10141, 'Saveiro Robust 1.6 Total Flex 16V ']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [10142, 'Saveiro Robust 1.6 Total Flex 16V CD']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7566, 'Saveiro Robust 1.6 Total Flex 8V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7960, 'Saveiro Robust 1.6 Total Flex 8V CD']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7272, 'Saveiro Rock in Rio 1.6 Total Flex 8V CD']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [3984, 'Saveiro SPORTLINE 1.6 Mi Total Flex 8V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [3807, 'Saveiro SPORTLINE 1.8 Mi Total Flex 8V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6802, 'Saveiro Startline 1.6 T.Flex 8V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2565, 'Saveiro Super Surf  1.8 Mi 8V 99cv']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2566, 'Saveiro Super Surf 1.6 Mi Total Flex 8V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2567, 'Saveiro Super Surf 1.8 Mi Total Flex 8V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4523, 'Saveiro SURF 1.6 Mi Total Flex 2p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4524, 'Saveiro SURF 1.8 Mi Total Flex 2p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4451, 'Saveiro TITAN  1.6 Mi Total Flex 2p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6799, 'Saveiro Trendline 1.6 T.Flex 8V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6943, 'Saveiro Trendline 1.6 T.Flex 8V CD']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6800, 'Saveiro Trendline 1.6 T.Flex 8V CE']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [9872, 'Saveiro Trendline 1.6 Total Flex 16V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5010, 'Saveiro TROOPER 1.6 Mi Total Flex 8V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5011, 'Saveiro TROOPER 1.6 Mi Total Flex 8V CE']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2568, 'Saveiro TSi 2.0 Mi']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7235, 'SpaceCross 1.6 Mi Total Flex 16V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5655, 'SpaceCross 1.6 Mi Total Flex 8V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7236, 'SpaceCross I MOTION 1.6 Mi T. Flex 16V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5656, 'SpaceCross I MOTION 1.6 Mi Total Flex 8V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4729, 'SPACEFOX  SPORTLINE/HIGHLINE 1.6 T.Flex']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5314, 'SPACEFOX  TREND I MOTION 1.6 T. Flex 8V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7321, 'SPACEFOX 1.6 Trendline I MOT. T.Flex 8V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7322, 'SPACEFOX 1.6 Trendline Total Flex 8v 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4007, 'SPACEFOX 1.6/ 1.6 Trend Total Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7217, 'SPACEFOX COMF. I MOTION 1.6 Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4008, 'SPACEFOX COMFORTLINE 1.6 Mi T.Flex 8V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7237, 'SPACEFOX HIGHLINE 1.6 T.Flex 16V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7238, 'SPACEFOX HIGHLINE I MOT. 1.6 T.Flex 16V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4836, 'SPACEFOX Route 1.6 Mi T.Flex 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5315, 'SPACEFOX SPORTLINE/HIGHLINE I MOTION 1.6']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [9529, 'TAOS Comfortline 1.4 250 TSI Flex Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [9530, 'TAOS Highline 1.4 250 TSI Flex Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [9531, 'TAOS Launching Ed. 1.4 250 TSI Flex Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8642, 'T-Cross 1.0 TSI Flex 12V 5p Mec.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [10373, 'T-Cross 200 TSI 1.0  Flex 12V 5p Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [10374, 'T-Cross Comfor. 200 TSI 1.0 Flex 5p Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [10375, 'T-Cross Hig. 250 TSI 1.4 Flex 16V 5p Aut']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [10376, 'T-Cross Sense 200 TSI 1.0 Flex 5p Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7860, 'TIGUAN 1.4 TSI 16V 150cv 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4931, 'TIGUAN 2.0 TSI 16V 200cv Tiptronic 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8300, 'TIGUAN Allspac 250 TSI 1.4 Flex']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8301, 'TIGUAN Allspac Comf 250 TSI 1.4 Flex']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [10892, 'TIGUAN Allspac R-Line 300 TSI 2.0 ']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8302, 'TIGUAN Allspac R-Line 350 TSI 2.0 4x4']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [3835, 'TOUAREG 3.2 24V V6 Tiptronic 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4442, 'TOUAREG 3.6 24V V6 280cv Tiptronic 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2569, 'TOUAREG 4.2 32V V8  Tiptronic 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7218, 'TOUAREG R-Line 4.2 V8 360cv Tiptronic 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8702, 'up! 1.0 Total Flex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6715, 'up! black/white/red 1.0 T. Flex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7323, 'up! black/white/red 1.0 TSI TFlex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6803, 'up! black/white/red I MOTION 1.0 Flex 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8703, 'up! Connect 1.0 TSI Total Flex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7047, 'up! cross 1.0 T. Flex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7324, 'up! cross 1.0 TSI Total Flex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7048, 'up! cross I MOTION 1.0 T.Flex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6716, 'up! high 1.0 Total Flex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7325, 'up! high 1.0 TSI Total Flex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6804, 'up! high I MOTION 1.0 T. Flex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6805, 'up! move 1.0 T. Flex 12V 3p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6717, 'up! move 1.0 Total Flex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7326, 'up! move 1.0 TSI Total Flex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6806, 'up! move I MOTION 1.0 T. Flex 12V 3p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6846, 'up! move I MOTION 1.0 T. Flex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8028, 'up! Pepper 1.0 TSI T.Flex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7639, 'up! Run 1.0 Total Flex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7640, 'up! Run I MOTION 1.0 Total Flex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7327, 'up! SPEED 1.0 TSI T. Flex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6807, 'up! take 1.0 T. Flex 12V 3p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6718, 'up! take 1.0 Total Flex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7818, 'up! track 1.0 Total Flex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8704, 'up! Xtreme 1.0 TSI Total Flex 12V 5p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2570, 'Van 1.6 Mi (furgão)']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8427, 'VIRTUS 1.6 MSI Flex 16V 4p Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8184, 'VIRTUS 1.6 MSI Flex 16V 5p Mec.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8185, 'VIRTUS Comfort. 200 TSI 1.0 Flex 12V Aut']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [10411, 'VIRTUS Exclusive 250TSI 1.4 Flex 16V Aut']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8997, 'VIRTUS GTS 1.4 TSI 16V Flex 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8186, 'VIRTUS Highline 200 TSI 1.0 Flex 12V Aut']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [9599, 'VIRTUS Sense 1.6 Flex 16V 5p Aut. ']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [10412, 'VIRTUS TSI 1.0 Flex 12V 4p Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [10413, 'VIRTUS TSI 1.0 Flex 12V 4p Mec.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6808, 'VOYAGE  Trendline 1.0 T.Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8325, 'VOYAGE 1.0 Flex 12V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4752, 'VOYAGE 1.0/1.0 City Mi Total Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8464, 'VOYAGE 1.6 MSI Flex 16V 4p Aut.']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [8326, 'VOYAGE 1.6 MSI Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4753, 'VOYAGE 1.6/1.6 City  Mi Total Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2571, 'VOYAGE C/CL/Fox 1.6']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2572, 'VOYAGE CL 1.8']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4754, 'VOYAGE COMF/Highli. 1.6 T.Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6810, 'VOYAGE Comfortline  1.0 T.Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7523, 'VOYAGE Comfortline 1.0 T.Flex 12V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6811, 'VOYAGE Evidence 1.6 Total Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2573, 'VOYAGE GL 1.8 4p (Argentino)']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2574, 'VOYAGE GL/ Special 1.6/ 1.8']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6812, 'VOYAGE I MOTION  Trendline 1.6 T.Flex 8V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5116, 'VOYAGE I MOTION 1.6 Mi Total Flex 8V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5117, 'VOYAGE I MOTION COMF/Hghli.1.6 T.Flex 8V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6813, 'VOYAGE I MOTION Evidence 1.6 T.Flex 8V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [5118, 'VOYAGE I MOTION TREND 1.6 Mi T. Flex 8V']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [2575, 'VOYAGE L/LS/Plus/GLS/S/Sport/Super L.Ang']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6671, 'VOYAGE SELEÇÃO 1.0 Mi Total Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6672, 'VOYAGE SELEÇÃO 1.6 I MOTION T.Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6673, 'VOYAGE SELEÇÃO 1.6 Total Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [4755, 'VOYAGE TREND 1.6 Mi Total Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [7524, 'VOYAGE Trendline 1.0 T.Flex 12V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Valores mapeados: [6809, 'VOYAGE Trendline 1.6 T.Flex 8V 4p']
# SQL: INSERT INTO tabela_vw (codigo, modelo) VALUES (?, ?)
# Ingestão de dados concluída com sucesso!
# ====================================
# Arquivo enviado para backup: /workspaces/projeto_ing/INGESTION/app/src/landing/modelo_vw_20240719_140024.txt
# Destino: /workspaces/projeto_ing/INGESTION/app/src/backp/
# ==========================
