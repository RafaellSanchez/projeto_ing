# %%
import requests
import datetime
from datetime import datetime


#chave para acessar
api_key = '7d345b55e9fbcf6989728ab565b60c59'
cidade = 'São Paulo'
# lat = ' -23.19.07'
# lon = '46.35.12'
# excl = ''
link = f"https://api.openweathermap.org/data/2.5/weather?q={cidade}&appid={api_key}&lang=pt_br"

requisicao = requests.get(link)
requisicao_js = requisicao.json()

requisicao_js['clouds']['probabilidade_de_chuva'] = requisicao_js['clouds'].pop('all')

descricao = requisicao_js['weather'][0]['description']
temperatura = requisicao_js['main']['temp'] - 273.15
data = requisicao_js['dt']
prob = requisicao_js['clouds']

timestamp = data
data_legivel = datetime.utcfromtimestamp(timestamp).strftime('%Y-%m-%d %H:%M:%S')
dt_atual = datetime.now().strftime('%Y%m%d')

print(f"Cidade: {cidade}, descição: {descricao}, Temperatura: {temperatura}ºC, data e hora: {data_legivel}")

nome_arquivo = f'tempo_{cidade}_{dt_atual}.txt'
local = '/workspaces/projeto_ing/apis/app/src/temp/'
destino = local + nome_arquivo

try:
    with open(destino, 'w') as arq:
        print("INFO DO TEMPO", file=arq)
        print("-------------", file=arq)
        print(f"Cidade: {cidade}", file=arq)
        print(f"descição: {descricao}", file=arq)
        print(f"Temperatura: {temperatura}ºC", file=arq)
        print(f"data e hora: {data_legivel}", file=arq)
        print(f'Chuva: {prob}', file=arq)
        print("------------", file=arq)
        print("            ", file=arq)
        for j in requisicao_js.items():
            print(f'Informações base: {j}', file=arq)
        print("------------", file=arq)
        # print(f"Informação base: {requisicao_js}\n", file=arq)
        # print(f"Cidade: {cidade}, descição: {descricao}, Temperatura: {temperatura}ºC, data e hora: {data_legivel}",file=arq)
        print('Arquivo salvo!')
        
except FileNotFoundError as error:
    print(f'Erro: {error}')
# Out:
# Cidade: São Paulo, descição: nublado, Temperatura: 20.700000000000045ºC, data e hora: 2024-09-28 16:33:20
# Arquivo salvo!

# %%
import requests
import datetime
from datetime import datetime


#chave para acessar
api_key = '7d345b55e9fbcf6989728ab565b60c59'
cidade = {'São Paulo', 'Rio de Janeiro', 'Mairiporã', 'Atibaia'}
# lat = ' -23.19.07'
# lon = '46.35.12'
# excl = ''
for cidades in cidade:
    link = f"https://api.openweathermap.org/data/2.5/weather?q={cidades}&appid={api_key}&lang=pt_br"
    requisicao = requests.get(link)
    requisicao_js = requisicao.json()
    requisicao_js['clouds']['probabilidade_de_chuva'] = requisicao_js['clouds'].pop('all')

    descricao = requisicao_js['weather'][0]['description']
    temperatura = requisicao_js['main']['temp'] - 273.15
    data = requisicao_js['dt']
    prob = requisicao_js['clouds']

    timestamp = data
    data_legivel = datetime.utcfromtimestamp(timestamp).strftime('%Y-%m-%d %H:%M:%S')
    dt_atual = datetime.now().strftime('%Y%m%d')
    print(f"Cidade: {cidades}, descição: {descricao}, Temperatura: {temperatura}ºC, data e hora: {data_legivel}")

    nome_arquivo = f'tempo_{cidades}_{dt_atual}.txt'
    local = '/workspaces/projeto_ing/apis/app/src/temp/'
    destino = local + nome_arquivo

    try:
        with open(destino, 'w') as arq:
            print("INFO DO TEMPO", file=arq)
            print("-------------", file=arq)
            print(f"Cidade: {cidades}", file=arq)
            print(f"descição: {descricao}", file=arq)
            print(f"Temperatura: {temperatura}ºC", file=arq)
            print(f"data e hora: {data_legivel}", file=arq)
            print(f'Chuva: {prob}', file=arq)
            print("------------", file=arq)
            print("            ", file=arq)
            for j in requisicao_js.items():
                print(f'Informações base: {j}', file=arq)
            print("------------", file=arq)
            # print(f"Informação base: {requisicao_js}\n", file=arq)
            # print(f"Cidade: {cidade}, descição: {descricao}, Temperatura: {temperatura}ºC, data e hora: {data_legivel}",file=arq)
            print('Arquivo salvo!')
            
    except FileNotFoundError as error:
        print(f'Erro: {error}')
# Out:
# Cidade: Atibaia, descição: algumas nuvens, Temperatura: 28.730000000000018ºC, data e hora: 2024-09-28 16:44:07
# Arquivo salvo!
# Cidade: Rio de Janeiro, descição: nublado, Temperatura: 23.760000000000048ºC, data e hora: 2024-09-28 16:41:25
# Arquivo salvo!
# Cidade: Mairiporã, descição: nublado, Temperatura: 20.99000000000001ºC, data e hora: 2024-09-28 16:40:21
# Arquivo salvo!
# Cidade: São Paulo, descição: nublado, Temperatura: 20.640000000000043ºC, data e hora: 2024-09-28 16:43:56
# Arquivo salvo!

# %%
import requests
import datetime
from datetime import datetime
import pandas as pd


#chave para acessar
api_key = '7d345b55e9fbcf6989728ab565b60c59'
cidade = 'São Paulo'
# lat = ' -23.19.07'
# lon = '46.35.12'
# excl = ''
lista = []

link = f"https://api.openweathermap.org/data/2.5/weather?q={cidade}&appid={api_key}&lang=pt_br"
requisicao = requests.get(link)
requisicao_js = requisicao.json()
requisicao_js['clouds']['probabilidade_de_chuva'] = requisicao_js['clouds'].pop('all')

descricao = requisicao_js['weather'][0]['description']
temperatura = requisicao_js['main']['temp'] - 273.15
data = requisicao_js['dt']
prob = requisicao_js['clouds']
nome = requisicao_js['name']
pais = requisicao_js['sys']['country']
temp_max = requisicao_js['main']['temp_max'] - 273.15
temp_min = requisicao_js['main']['temp_min'] - 273.15
umidade = requisicao_js['main']['humidity']


# timestamp = data
# data_legivel = datetime.utcfromtimestamp(timestamp).strftime('%Y-%m-%d %H:%M:%S')
# dt_atual = datetime.now().strftime('%Y%m%d')


for resultado in requisicao_js.items():
    print(resultado)
    lista.append({
        'cidade': nome,
        'pais': pais,
        'descricao':descricao,
        'temperatura': temperatura,
        'temp_max': temp_max,
        'temp_min': temp_min,
        'umidade': umidade,
        'probabilidade': prob
        })

df = pd.DataFrame(lista)
display(df)

# print(requisicao_js)
# print(requisicao_js['name'])
# print(requisicao_js['clouds'])
# print(requisicao_js['timezone'])

## SALVAR NA LISTA
# Out:
# ('coord', {'lon': -46.6361, 'lat': -23.5475})
# ('weather', [{'id': 804, 'main': 'Clouds', 'description': 'nublado', 'icon': '04d'}])
# ('base', 'stations')
# ('main', {'temp': 290.93, 'feels_like': 290.93, 'temp_min': 290.35, 'temp_max': 293.09, 'pressure': 1017, 'humidity': 83, 'sea_level': 1017, 'grnd_level': 928})
# ('visibility', 10000)
# ('wind', {'speed': 7.72, 'deg': 170})
# ('clouds', {'probabilidade_de_chuva': 100})
# ('dt', 1727547302)
# ('sys', {'type': 1, 'id': 8394, 'country': 'BR', 'sunrise': 1727513368, 'sunset': 1727557472})
# ('timezone', -10800)
# ('id', 3448439)
# ('name', 'São Paulo')
# ('cod', 200)
#        cidade pais descricao  temperatura  temp_max  temp_min  umidade  \
# 0   São Paulo   BR   nublado        17.78     19.94      17.2       83
# 1   São Paulo   BR   nublado        17.78     19.94      17.2       83
# 2   São Paulo   BR   nublado        17.78     19.94      17.2       83
# 3   São Paulo   BR   nublado        17.78     19.94      17.2       83
# 4   São Paulo   BR   nublado        17.78     19.94      17.2       83
# 5   São Paulo   BR   nublado        17.78     19.94      17.2       83
# 6   São Paulo   BR   nublado        17.78     19.94      17.2       83
# 7   São Paulo   BR   nublado        17.78     19.94      17.2       83
# 8   São Paulo   BR   nublado        17.78     19.94      17.2       83
# 9   São Paulo   BR   nublado        17.78     19.94      17.2       83
# 10  São Paulo   BR   nublado        17.78     19.94      17.2       83
# 11  São Paulo   BR   nublado        17.78     19.94      17.2       83
# 12  São Paulo   BR   nublado        17.78     19.94      17.2       83
#
#                       probabilidade
# 0   {'probabilidade_de_chuva': 100}
# 1   {'probabilidade_de_chuva': 100}
# 2   {'probabilidade_de_chuva': 100}
# 3   {'probabilidade_de_chuva': 100}
# 4   {'probabilidade_de_chuva': 100}
# 5   {'probabilidade_de_chuva': 100}
# 6   {'probabilidade_de_chuva': 100}
# 7   {'probabilidade_de_chuva': 100}
# 8   {'probabilidade_de_chuva': 100}
# 9   {'probabilidade_de_chuva': 100}
# 10  {'probabilidade_de_chuva': 100}
# 11  {'probabilidade_de_chuva': 100}
# 12  {'probabilidade_de_chuva': 100}

# %%
import requests
import datetime
from datetime import datetime
import pandas as pd


api_key = '7d345b55e9fbcf6989728ab565b60c59'
cidade = {'São Paulo', 'Rio de Janeiro', 'Mairiporã', 'Atibaia'}
# lat = ' -23.19.07'
# lon = '46.35.12'
# excl = ''
for cidades in cidade:
    link = f"https://api.openweathermap.org/data/2.5/weather?q={cidades}&appid={api_key}&lang=pt_br"
    requisicao = requests.get(link)
    requisicao_js = requisicao.json()
    requisicao_js['clouds']['probabilidade_de_chuva'] = requisicao_js['clouds'].pop('all')

    descricao = requisicao_js['weather'][0]['description']
    temperatura = requisicao_js['main']['temp'] - 273.15
    data = requisicao_js['dt']
    prob = requisicao_js['clouds']
    nome = requisicao_js['name']
    pais = requisicao_js['sys']['country']
    temp_max = requisicao_js['main']['temp_max'] - 273.15
    temp_min = requisicao_js['main']['temp_min'] - 273.15
    umidade = requisicao_js['main']['humidity']
    timestamp = data
    data_legivel = datetime.utcfromtimestamp(timestamp).strftime('%Y-%m-%d %H:%M:%S')
    dt_atual = datetime.now().strftime('%Y%m%d')


    for resultado in requisicao_js.items():
        print(resultado)
        lista.append({
            'cidade': nome,
            'pais': pais,
            'descricao':descricao,
            'temperatura': temperatura,
            'temp_max': temp_max,
            'temp_min': temp_min,
            'umidade': umidade,
            'probabilidade': prob
            })

    df = pd.DataFrame(lista)
    display(df)
# Out:
# ('coord', {'lon': -46.589, 'lat': -23.131})
# ('weather', [{'id': 800, 'main': 'Clear', 'description': 'céu limpo', 'icon': '01d'}])
# ('base', 'stations')
# ('main', {'temp': 301.45, 'feels_like': 300.94, 'temp_min': 301.45, 'temp_max': 301.45, 'pressure': 1014, 'humidity': 38, 'sea_level': 1014, 'grnd_level': 917})
# ('visibility', 10000)
# ('wind', {'speed': 4.8, 'deg': 142, 'gust': 3.2})
# ('clouds', {'probabilidade_de_chuva': 8})
# ('dt', 1727547880)
# ('sys', {'country': 'BR', 'sunrise': 1727513362, 'sunset': 1727557455})
# ('timezone', -10800)
# ('id', 6322114)
# ('name', 'Atibaia')
# ('cod', 200)
#        cidade pais  descricao  temperatura  temp_max  temp_min  umidade  \
# 0   São Paulo   BR    nublado        17.78     19.94      17.2       83
# 1   São Paulo   BR    nublado        17.78     19.94      17.2       83
# 2   São Paulo   BR    nublado        17.78     19.94      17.2       83
# 3   São Paulo   BR    nublado        17.78     19.94      17.2       83
# 4   São Paulo   BR    nublado        17.78     19.94      17.2       83
# 5   São Paulo   BR    nublado        17.78     19.94      17.2       83
# 6   São Paulo   BR    nublado        17.78     19.94      17.2       83
# 7   São Paulo   BR    nublado        17.78     19.94      17.2       83
# 8   São Paulo   BR    nublado        17.78     19.94      17.2       83
# 9   São Paulo   BR    nublado        17.78     19.94      17.2       83
# 10  São Paulo   BR    nublado        17.78     19.94      17.2       83
# 11  São Paulo   BR    nublado        17.78     19.94      17.2       83
# 12  São Paulo   BR    nublado        17.78     19.94      17.2       83
# 13    Atibaia   BR  céu limpo        28.30     28.30      28.3       38
# 14    Atibaia   BR  céu limpo        28.30     28.30      28.3       38
# 15    Atibaia   BR  céu limpo        28.30     28.30      28.3       38
# 16    Atibaia   BR  céu limpo        28.30     28.30      28.3       38
# 17    Atibaia   BR  céu limpo        28.30     28.30      28.3       38
# 18    Atibaia   BR  céu limpo        28.30     28.30      28.3       38
# 19    Atibaia   BR  céu limpo        28.30     28.30      28.3       38
# 20    Atibaia   BR  céu limpo        28.30     28.30      28.3       38
# 21    Atibaia   BR  céu limpo        28.30     28.30      28.3       38
# 22    Atibaia   BR  céu limpo        28.30     28.30      28.3       38
# 23    Atibaia   BR  céu limpo        28.30     28.30      28.3       38
# 24    Atibaia   BR  céu limpo        28.30     28.30      28.3       38
# 25    Atibaia   BR  céu limpo        28.30     28.30      28.3       38
#
#                       probabilidade
# 0   {'probabilidade_de_chuva': 100}
# 1   {'probabilidade_de_chuva': 100}
# 2   {'probabilidade_de_chuva': 100}
# 3   {'probabilidade_de_chuva': 100}
# 4   {'probabilidade_de_chuva': 100}
# 5   {'probabilidade_de_chuva': 100}
# 6   {'probabilidade_de_chuva': 100}
# 7   {'probabilidade_de_chuva': 100}
# 8   {'probabilidade_de_chuva': 100}
# 9   {'probabilidade_de_chuva': 100}
# 10  {'probabilidade_de_chuva': 100}
# 11  {'probabilidade_de_chuva': 100}
# 12  {'probabilidade_de_chuva': 100}
# 13    {'probabilidade_de_chuva': 8}
# 14    {'probabilidade_de_chuva': 8}
# 15    {'probabilidade_de_chuva': 8}
# 16    {'probabilidade_de_chuva': 8}
# 17    {'probabilidade_de_chuva': 8}
# 18    {'probabilidade_de_chuva': 8}
# 19    {'probabilidade_de_chuva': 8}
# 20    {'probabilidade_de_chuva': 8}
# 21    {'probabilidade_de_chuva': 8}
# 22    {'probabilidade_de_chuva': 8}
# 23    {'probabilidade_de_chuva': 8}
# 24    {'probabilidade_de_chuva': 8}
# 25    {'probabilidade_de_chuva': 8}
# ('coord', {'lon': -46.5867, 'lat': -23.3186})
# ('weather', [{'id': 804, 'main': 'Clouds', 'description': 'nublado', 'icon': '04d'}])
# ('base', 'stations')
# ('main', {'temp': 292.64, 'feels_like': 292.42, 'temp_min': 290.96, 'temp_max': 293.25, 'pressure': 1015, 'humidity': 68, 'sea_level': 1015, 'grnd_level': 917})
# ('visibility', 10000)
# ('wind', {'speed': 5.14, 'deg': 140})
# ('clouds', {'probabilidade_de_chuva': 100})
# ('dt', 1727547682)
# ('sys', {'type': 1, 'id': 8379, 'country': 'BR', 'sunrise': 1727513359, 'sunset': 1727557457})
# ('timezone', -10800)
# ('id', 3458131)
# ('name', 'Mairiporã')
# ('cod', 200)
#        cidade pais  descricao  temperatura  temp_max  temp_min  umidade  \
# 0   São Paulo   BR    nublado        17.78     19.94     17.20       83
# 1   São Paulo   BR    nublado        17.78     19.94     17.20       83
# 2   São Paulo   BR    nublado        17.78     19.94     17.20       83
# 3   São Paulo   BR    nublado        17.78     19.94     17.20       83
# 4   São Paulo   BR    nublado        17.78     19.94     17.20       83
# 5   São Paulo   BR    nublado        17.78     19.94     17.20       83
# 6   São Paulo   BR    nublado        17.78     19.94     17.20       83
# 7   São Paulo   BR    nublado        17.78     19.94     17.20       83
# 8   São Paulo   BR    nublado        17.78     19.94     17.20       83
# 9   São Paulo   BR    nublado        17.78     19.94     17.20       83
# 10  São Paulo   BR    nublado        17.78     19.94     17.20       83
# 11  São Paulo   BR    nublado        17.78     19.94     17.20       83
# 12  São Paulo   BR    nublado        17.78     19.94     17.20       83
# 13    Atibaia   BR  céu limpo        28.30     28.30     28.30       38
# 14    Atibaia   BR  céu limpo        28.30     28.30     28.30       38
# 15    Atibaia   BR  céu limpo        28.30     28.30     28.30       38
# 16    Atibaia   BR  céu limpo        28.30     28.30     28.30       38
# 17    Atibaia   BR  céu limpo        28.30     28.30     28.30       38
# 18    Atibaia   BR  céu limpo        28.30     28.30     28.30       38
# 19    Atibaia   BR  céu limpo        28.30     28.30     28.30       38
# 20    Atibaia   BR  céu limpo        28.30     28.30     28.30       38
# 21    Atibaia   BR  céu limpo        28.30     28.30     28.30       38
# 22    Atibaia   BR  céu limpo        28.30     28.30     28.30       38
# 23    Atibaia   BR  céu limpo        28.30     28.30     28.30       38
# 24    Atibaia   BR  céu limpo        28.30     28.30     28.30       38
# 25    Atibaia   BR  céu limpo        28.30     28.30     28.30       38
# 26  Mairiporã   BR    nublado        19.49     20.10     17.81       68
# 27  Mairiporã   BR    nublado        19.49     20.10     17.81       68
# 28  Mairiporã   BR    nublado        19.49     20.10     17.81       68
# 29  Mairiporã   BR    nublado        19.49     20.10     17.81       68
# 30  Mairiporã   BR    nublado        19.49     20.10     17.81       68
# 31  Mairiporã   BR    nublado        19.49     20.10     17.81       68
# 32  Mairiporã   BR    nublado        19.49     20.10     17.81       68
# 33  Mairiporã   BR    nublado        19.49     20.10     17.81       68
# 34  Mairiporã   BR    nublado        19.49     20.10     17.81       68
# 35  Mairiporã   BR    nublado        19.49     20.10     17.81       68
# 36  Mairiporã   BR    nublado        19.49     20.10     17.81       68
# 37  Mairiporã   BR    nublado        19.49     20.10     17.81       68
# 38  Mairiporã   BR    nublado        19.49     20.10     17.81       68
#
#                       probabilidade
# 0   {'probabilidade_de_chuva': 100}
# 1   {'probabilidade_de_chuva': 100}
# 2   {'probabilidade_de_chuva': 100}
# 3   {'probabilidade_de_chuva': 100}
# 4   {'probabilidade_de_chuva': 100}
# 5   {'probabilidade_de_chuva': 100}
# 6   {'probabilidade_de_chuva': 100}
# 7   {'probabilidade_de_chuva': 100}
# 8   {'probabilidade_de_chuva': 100}
# 9   {'probabilidade_de_chuva': 100}
# 10  {'probabilidade_de_chuva': 100}
# 11  {'probabilidade_de_chuva': 100}
# 12  {'probabilidade_de_chuva': 100}
# 13    {'probabilidade_de_chuva': 8}
# 14    {'probabilidade_de_chuva': 8}
# 15    {'probabilidade_de_chuva': 8}
# 16    {'probabilidade_de_chuva': 8}
# 17    {'probabilidade_de_chuva': 8}
# 18    {'probabilidade_de_chuva': 8}
# 19    {'probabilidade_de_chuva': 8}
# 20    {'probabilidade_de_chuva': 8}
# 21    {'probabilidade_de_chuva': 8}
# 22    {'probabilidade_de_chuva': 8}
# 23    {'probabilidade_de_chuva': 8}
# 24    {'probabilidade_de_chuva': 8}
# 25    {'probabilidade_de_chuva': 8}
# 26  {'probabilidade_de_chuva': 100}
# 27  {'probabilidade_de_chuva': 100}
# 28  {'probabilidade_de_chuva': 100}
# 29  {'probabilidade_de_chuva': 100}
# 30  {'probabilidade_de_chuva': 100}
# 31  {'probabilidade_de_chuva': 100}
# 32  {'probabilidade_de_chuva': 100}
# 33  {'probabilidade_de_chuva': 100}
# 34  {'probabilidade_de_chuva': 100}
# 35  {'probabilidade_de_chuva': 100}
# 36  {'probabilidade_de_chuva': 100}
# 37  {'probabilidade_de_chuva': 100}
# 38  {'probabilidade_de_chuva': 100}
# ('coord', {'lon': -46.6361, 'lat': -23.5475})
# ('weather', [{'id': 804, 'main': 'Clouds', 'description': 'nublado', 'icon': '04d'}])
# ('base', 'stations')
# ('main', {'temp': 290.93, 'feels_like': 290.93, 'temp_min': 290.35, 'temp_max': 293.09, 'pressure': 1017, 'humidity': 83, 'sea_level': 1017, 'grnd_level': 928})
# ('visibility', 10000)
# ('wind', {'speed': 7.72, 'deg': 170})
# ('clouds', {'probabilidade_de_chuva': 100})
# ('dt', 1727547302)
# ('sys', {'type': 1, 'id': 8394, 'country': 'BR', 'sunrise': 1727513368, 'sunset': 1727557472})
# ('timezone', -10800)
# ('id', 3448439)
# ('name', 'São Paulo')
# ('cod', 200)
#        cidade pais  descricao  temperatura  temp_max  temp_min  umidade  \
# 0   São Paulo   BR    nublado        17.78     19.94     17.20       83
# 1   São Paulo   BR    nublado        17.78     19.94     17.20       83
# 2   São Paulo   BR    nublado        17.78     19.94     17.20       83
# 3   São Paulo   BR    nublado        17.78     19.94     17.20       83
# 4   São Paulo   BR    nublado        17.78     19.94     17.20       83
# 5   São Paulo   BR    nublado        17.78     19.94     17.20       83
# 6   São Paulo   BR    nublado        17.78     19.94     17.20       83
# 7   São Paulo   BR    nublado        17.78     19.94     17.20       83
# 8   São Paulo   BR    nublado        17.78     19.94     17.20       83
# 9   São Paulo   BR    nublado        17.78     19.94     17.20       83
# 10  São Paulo   BR    nublado        17.78     19.94     17.20       83
# 11  São Paulo   BR    nublado        17.78     19.94     17.20       83
# 12  São Paulo   BR    nublado        17.78     19.94     17.20       83
# 13    Atibaia   BR  céu limpo        28.30     28.30     28.30       38
# 14    Atibaia   BR  céu limpo        28.30     28.30     28.30       38
# 15    Atibaia   BR  céu limpo        28.30     28.30     28.30       38
# 16    Atibaia   BR  céu limpo        28.30     28.30     28.30       38
# 17    Atibaia   BR  céu limpo        28.30     28.30     28.30       38
# 18    Atibaia   BR  céu limpo        28.30     28.30     28.30       38
# 19    Atibaia   BR  céu limpo        28.30     28.30     28.30       38
# 20    Atibaia   BR  céu limpo        28.30     28.30     28.30       38
# 21    Atibaia   BR  céu limpo        28.30     28.30     28.30       38
# 22    Atibaia   BR  céu limpo        28.30     28.30     28.30       38
# 23    Atibaia   BR  céu limpo        28.30     28.30     28.30       38
# 24    Atibaia   BR  céu limpo        28.30     28.30     28.30       38
# 25    Atibaia   BR  céu limpo        28.30     28.30     28.30       38
# 26  Mairiporã   BR    nublado        19.49     20.10     17.81       68
# 27  Mairiporã   BR    nublado        19.49     20.10     17.81       68
# 28  Mairiporã   BR    nublado        19.49     20.10     17.81       68
# 29  Mairiporã   BR    nublado        19.49     20.10     17.81       68
# 30  Mairiporã   BR    nublado        19.49     20.10     17.81       68
# 31  Mairiporã   BR    nublado        19.49     20.10     17.81       68
# 32  Mairiporã   BR    nublado        19.49     20.10     17.81       68
# 33  Mairiporã   BR    nublado        19.49     20.10     17.81       68
# 34  Mairiporã   BR    nublado        19.49     20.10     17.81       68
# 35  Mairiporã   BR    nublado        19.49     20.10     17.81       68
# 36  Mairiporã   BR    nublado        19.49     20.10     17.81       68
# 37  Mairiporã   BR    nublado        19.49     20.10     17.81       68
# 38  Mairiporã   BR    nublado        19.49     20.10     17.81       68
# 39  São Paulo   BR    nublado        17.78     19.94     17.20       83
# 40  São Paulo   BR    nublado        17.78     19.94     17.20       83
# 41  São Paulo   BR    nublado        17.78     19.94     17.20       83
# 42  São Paulo   BR    nublado        17.78     19.94     17.20       83
# 43  São Paulo   BR    nublado        17.78     19.94     17.20       83
# 44  São Paulo   BR    nublado        17.78     19.94     17.20       83
# 45  São Paulo   BR    nublado        17.78     19.94     17.20       83
# 46  São Paulo   BR    nublado        17.78     19.94     17.20       83
# 47  São Paulo   BR    nublado        17.78     19.94     17.20       83
# 48  São Paulo   BR    nublado        17.78     19.94     17.20       83
# 49  São Paulo   BR    nublado        17.78     19.94     17.20       83
# 50  São Paulo   BR    nublado        17.78     19.94     17.20       83
# 51  São Paulo   BR    nublado        17.78     19.94     17.20       83
#
#                       probabilidade
# 0   {'probabilidade_de_chuva': 100}
# 1   {'probabilidade_de_chuva': 100}
# 2   {'probabilidade_de_chuva': 100}
# 3   {'probabilidade_de_chuva': 100}
# 4   {'probabilidade_de_chuva': 100}
# 5   {'probabilidade_de_chuva': 100}
# 6   {'probabilidade_de_chuva': 100}
# 7   {'probabilidade_de_chuva': 100}
# 8   {'probabilidade_de_chuva': 100}
# 9   {'probabilidade_de_chuva': 100}
# 10  {'probabilidade_de_chuva': 100}
# 11  {'probabilidade_de_chuva': 100}
# 12  {'probabilidade_de_chuva': 100}
# 13    {'probabilidade_de_chuva': 8}
# 14    {'probabilidade_de_chuva': 8}
# 15    {'probabilidade_de_chuva': 8}
# 16    {'probabilidade_de_chuva': 8}
# 17    {'probabilidade_de_chuva': 8}
# 18    {'probabilidade_de_chuva': 8}
# 19    {'probabilidade_de_chuva': 8}
# 20    {'probabilidade_de_chuva': 8}
# 21    {'probabilidade_de_chuva': 8}
# 22    {'probabilidade_de_chuva': 8}
# 23    {'probabilidade_de_chuva': 8}
# 24    {'probabilidade_de_chuva': 8}
# 25    {'probabilidade_de_chuva': 8}
# 26  {'probabilidade_de_chuva': 100}
# 27  {'probabilidade_de_chuva': 100}
# 28  {'probabilidade_de_chuva': 100}
# 29  {'probabilidade_de_chuva': 100}
# 30  {'probabilidade_de_chuva': 100}
# 31  {'probabilidade_de_chuva': 100}
# 32  {'probabilidade_de_chuva': 100}
# 33  {'probabilidade_de_chuva': 100}
# 34  {'probabilidade_de_chuva': 100}
# 35  {'probabilidade_de_chuva': 100}
# 36  {'probabilidade_de_chuva': 100}
# 37  {'probabilidade_de_chuva': 100}
# 38  {'probabilidade_de_chuva': 100}
# 39  {'probabilidade_de_chuva': 100}
# 40  {'probabilidade_de_chuva': 100}
# 41  {'probabilidade_de_chuva': 100}
# 42  {'probabilidade_de_chuva': 100}
# 43  {'probabilidade_de_chuva': 100}
# 44  {'probabilidade_de_chuva': 100}
# 45  {'probabilidade_de_chuva': 100}
# 46  {'probabilidade_de_chuva': 100}
# 47  {'probabilidade_de_chuva': 100}
# 48  {'probabilidade_de_chuva': 100}
# 49  {'probabilidade_de_chuva': 100}
# 50  {'probabilidade_de_chuva': 100}
# 51  {'probabilidade_de_chuva': 100}
# ('coord', {'lon': -43.2075, 'lat': -22.9028})
# ('weather', [{'id': 804, 'main': 'Clouds', 'description': 'nublado', 'icon': '04d'}])
# ('base', 'stations')
# ('main', {'temp': 296.13, 'feels_like': 296.39, 'temp_min': 296.13, 'temp_max': 296.27, 'pressure': 1019, 'humidity': 73, 'sea_level': 1019, 'grnd_level': 1020})
# ('visibility', 10000)
# ('wind', {'speed': 5.14, 'deg': 180})
# ('clouds', {'probabilidade_de_chuva': 100})
# ('dt', 1727547827)
# ('sys', {'type': 1, 'id': 8429, 'country': 'BR', 'sunrise': 1727512554, 'sunset': 1727556640})
# ('timezone', -10800)
# ('id', 3451190)
# ('name', 'Rio de Janeiro')
# ('cod', 200)
#             cidade pais descricao  temperatura  temp_max  temp_min  umidade  \
# 0        São Paulo   BR   nublado        17.78     19.94     17.20       83
# 1        São Paulo   BR   nublado        17.78     19.94     17.20       83
# 2        São Paulo   BR   nublado        17.78     19.94     17.20       83
# 3        São Paulo   BR   nublado        17.78     19.94     17.20       83
# 4        São Paulo   BR   nublado        17.78     19.94     17.20       83
# ..             ...  ...       ...          ...       ...       ...      ...
# 60  Rio de Janeiro   BR   nublado        22.98     23.12     22.98       73
# 61  Rio de Janeiro   BR   nublado        22.98     23.12     22.98       73
# 62  Rio de Janeiro   BR   nublado        22.98     23.12     22.98       73
# 63  Rio de Janeiro   BR   nublado        22.98     23.12     22.98       73
# 64  Rio de Janeiro   BR   nublado        22.98     23.12     22.98       73
#
#                       probabilidade
# 0   {'probabilidade_de_chuva': 100}
# 1   {'probabilidade_de_chuva': 100}
# 2   {'probabilidade_de_chuva': 100}
# 3   {'probabilidade_de_chuva': 100}
# 4   {'probabilidade_de_chuva': 100}
# ..                              ...
# 60  {'probabilidade_de_chuva': 100}
# 61  {'probabilidade_de_chuva': 100}
# 62  {'probabilidade_de_chuva': 100}
# 63  {'probabilidade_de_chuva': 100}
# 64  {'probabilidade_de_chuva': 100}
#
# [65 rows x 8 columns]
