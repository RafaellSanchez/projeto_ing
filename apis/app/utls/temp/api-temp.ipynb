# %%
import requests
import datetime
from datetime import datetime


#chave para acessar
api_key = '7d345b55e9fbcf6989728ab565b60c59'
cidade = 'São Paulo'
# lat = ' -23.19.07'
# lon = '46.35.12'
# excl = ''
link = f"https://api.openweathermap.org/data/2.5/weather?q={cidade}&appid={api_key}&lang=pt_br"

requisicao = requests.get(link)
requisicao_js = requisicao.json()

requisicao_js['clouds']['probabilidade_de_chuva'] = requisicao_js['clouds'].pop('all')

descricao = requisicao_js['weather'][0]['description']
temperatura = requisicao_js['main']['temp'] - 273.15
data = requisicao_js['dt']
prob = requisicao_js['clouds']

timestamp = data
data_legivel = datetime.utcfromtimestamp(timestamp).strftime('%Y-%m-%d %H:%M:%S')
dt_atual = datetime.now().strftime('%Y%m%d')

print(f"Cidade: {cidade}, descição: {descricao}, Temperatura: {temperatura}ºC, data e hora: {data_legivel}")

nome_arquivo = f'tempo_{cidade}_{dt_atual}.txt'
local = '/workspaces/projeto_ing/apis/app/src/temp/'
destino = local + nome_arquivo

try:
    with open(destino, 'w') as arq:
        print("INFO DO TEMPO", file=arq)
        print("-------------", file=arq)
        print(f"Cidade: {cidade}", file=arq)
        print(f"descição: {descricao}", file=arq)
        print(f"Temperatura: {temperatura}ºC", file=arq)
        print(f"data e hora: {data_legivel}", file=arq)
        print(f'Chuva: {prob}', file=arq)
        print("------------", file=arq)
        print("            ", file=arq)
        for j in requisicao_js.items():
            print(f'Informações base: {j}', file=arq)
        print("------------", file=arq)
        # print(f"Informação base: {requisicao_js}\n", file=arq)
        # print(f"Cidade: {cidade}, descição: {descricao}, Temperatura: {temperatura}ºC, data e hora: {data_legivel}",file=arq)
        print('Arquivo salvo!')
        
except FileNotFoundError as error:
    print(f'Erro: {error}')
# Out:
# Cidade: São Paulo, descição: nublado, Temperatura: 20.700000000000045ºC, data e hora: 2024-09-28 16:33:20
# Arquivo salvo!

# %%
import requests
import datetime
from datetime import datetime


#chave para acessar
api_key = '7d345b55e9fbcf6989728ab565b60c59'
cidade = {'São Paulo', 'Rio de Janeiro', 'Mairiporã', 'Atibaia'}
# lat = ' -23.19.07'
# lon = '46.35.12'
# excl = ''
for cidades in cidade:
    link = f"https://api.openweathermap.org/data/2.5/weather?q={cidades}&appid={api_key}&lang=pt_br"
    requisicao = requests.get(link)
    requisicao_js = requisicao.json()
    requisicao_js['clouds']['probabilidade_de_chuva'] = requisicao_js['clouds'].pop('all')

    descricao = requisicao_js['weather'][0]['description']
    temperatura = requisicao_js['main']['temp'] - 273.15
    data = requisicao_js['dt']
    prob = requisicao_js['clouds']

    timestamp = data
    data_legivel = datetime.utcfromtimestamp(timestamp).strftime('%Y-%m-%d %H:%M:%S')
    dt_atual = datetime.now().strftime('%Y%m%d')
    print(f"Cidade: {cidades}, descição: {descricao}, Temperatura: {temperatura}ºC, data e hora: {data_legivel}")

    nome_arquivo = f'tempo_{cidades}_{dt_atual}.txt'
    local = '/workspaces/projeto_ing/apis/app/src/temp/'
    destino = local + nome_arquivo

    try:
        with open(destino, 'w') as arq:
            print("INFO DO TEMPO", file=arq)
            print("-------------", file=arq)
            print(f"Cidade: {cidades}", file=arq)
            print(f"descição: {descricao}", file=arq)
            print(f"Temperatura: {temperatura}ºC", file=arq)
            print(f"data e hora: {data_legivel}", file=arq)
            print(f'Chuva: {prob}', file=arq)
            print("------------", file=arq)
            print("            ", file=arq)
            for j in requisicao_js.items():
                print(f'Informações base: {j}', file=arq)
            print("------------", file=arq)
            # print(f"Informação base: {requisicao_js}\n", file=arq)
            # print(f"Cidade: {cidade}, descição: {descricao}, Temperatura: {temperatura}ºC, data e hora: {data_legivel}",file=arq)
            print('Arquivo salvo!')
            
    except FileNotFoundError as error:
        print(f'Erro: {error}')
# Out:
# Cidade: Atibaia, descição: algumas nuvens, Temperatura: 28.730000000000018ºC, data e hora: 2024-09-28 16:44:07
# Arquivo salvo!
# Cidade: Rio de Janeiro, descição: nublado, Temperatura: 23.760000000000048ºC, data e hora: 2024-09-28 16:41:25
# Arquivo salvo!
# Cidade: Mairiporã, descição: nublado, Temperatura: 20.99000000000001ºC, data e hora: 2024-09-28 16:40:21
# Arquivo salvo!
# Cidade: São Paulo, descição: nublado, Temperatura: 20.640000000000043ºC, data e hora: 2024-09-28 16:43:56
# Arquivo salvo!

# %%
import requests
import datetime
from datetime import datetime
import pandas as pd


#chave para acessar
api_key = '7d345b55e9fbcf6989728ab565b60c59'
cidade = 'São Paulo'
# lat = ' -23.19.07'
# lon = '46.35.12'
# excl = ''
lista = []

link = f"https://api.openweathermap.org/data/2.5/weather?q={cidade}&appid={api_key}&lang=pt_br"
requisicao = requests.get(link)
requisicao_js = requisicao.json()
requisicao_js['clouds']['probabilidade_de_chuva'] = requisicao_js['clouds'].pop('all')

descricao = requisicao_js['weather'][0]['description']
temperatura = requisicao_js['main']['temp'] - 273.15
data = requisicao_js['dt']
prob = requisicao_js['clouds']
nome = requisicao_js['name']
pais = requisicao_js['sys']['country']
temp_max = requisicao_js['main']['temp_max'] - 273.15
temp_min = requisicao_js['main']['temp_min'] - 273.15
umidade = requisicao_js['main']['humidity']


# timestamp = data
# data_legivel = datetime.utcfromtimestamp(timestamp).strftime('%Y-%m-%d %H:%M:%S')
# dt_atual = datetime.now().strftime('%Y%m%d')


for resultado in requisicao_js.items():
    print(resultado)
    lista.append({
        'cidade': nome,
        'pais': pais,
        'descricao':descricao,
        'temperatura': temperatura,
        'temp_max': temp_max,
        'temp_min': temp_min,
        'umidade': umidade,
        'probabilidade': prob
        })

df = pd.DataFrame(lista)
display(df)

# print(requisicao_js)
# print(requisicao_js['name'])
# print(requisicao_js['clouds'])
# print(requisicao_js['timezone'])

## SALVAR NA LISTA
# Out:
# ('coord', {'lon': -46.6361, 'lat': -23.5475})
# ('weather', [{'id': 804, 'main': 'Clouds', 'description': 'nublado', 'icon': '04d'}])
# ('base', 'stations')
# ('main', {'temp': 290.93, 'feels_like': 290.93, 'temp_min': 290.35, 'temp_max': 293.09, 'pressure': 1017, 'humidity': 83, 'sea_level': 1017, 'grnd_level': 928})
# ('visibility', 10000)
# ('wind', {'speed': 7.72, 'deg': 170})
# ('clouds', {'probabilidade_de_chuva': 100})
# ('dt', 1727547302)
# ('sys', {'type': 1, 'id': 8394, 'country': 'BR', 'sunrise': 1727513368, 'sunset': 1727557472})
# ('timezone', -10800)
# ('id', 3448439)
# ('name', 'São Paulo')
# ('cod', 200)
#        cidade pais descricao  temperatura  temp_max  temp_min  umidade  \
# 0   São Paulo   BR   nublado        17.78     19.94      17.2       83
# 1   São Paulo   BR   nublado        17.78     19.94      17.2       83
# 2   São Paulo   BR   nublado        17.78     19.94      17.2       83
# 3   São Paulo   BR   nublado        17.78     19.94      17.2       83
# 4   São Paulo   BR   nublado        17.78     19.94      17.2       83
# 5   São Paulo   BR   nublado        17.78     19.94      17.2       83
# 6   São Paulo   BR   nublado        17.78     19.94      17.2       83
# 7   São Paulo   BR   nublado        17.78     19.94      17.2       83
# 8   São Paulo   BR   nublado        17.78     19.94      17.2       83
# 9   São Paulo   BR   nublado        17.78     19.94      17.2       83
# 10  São Paulo   BR   nublado        17.78     19.94      17.2       83
# 11  São Paulo   BR   nublado        17.78     19.94      17.2       83
# 12  São Paulo   BR   nublado        17.78     19.94      17.2       83
#
#                       probabilidade
# 0   {'probabilidade_de_chuva': 100}
# 1   {'probabilidade_de_chuva': 100}
# 2   {'probabilidade_de_chuva': 100}
# 3   {'probabilidade_de_chuva': 100}
# 4   {'probabilidade_de_chuva': 100}
# 5   {'probabilidade_de_chuva': 100}
# 6   {'probabilidade_de_chuva': 100}
# 7   {'probabilidade_de_chuva': 100}
# 8   {'probabilidade_de_chuva': 100}
# 9   {'probabilidade_de_chuva': 100}
# 10  {'probabilidade_de_chuva': 100}
# 11  {'probabilidade_de_chuva': 100}
# 12  {'probabilidade_de_chuva': 100}

# %%
import requests
import datetime
from datetime import datetime
import pandas as pd


api_key = '7d345b55e9fbcf6989728ab565b60c59'
cidade = {'São Paulo', 'Rio de Janeiro', 'Mairiporã', 'Atibaia'}
# lat = ' -23.19.07'
# lon = '46.35.12'
# excl = ''
lista = []
for cidades in cidade:
    link = f"https://api.openweathermap.org/data/2.5/weather?q={cidades}&appid={api_key}&lang=pt_br"
    requisicao = requests.get(link)
    requisicao_js = requisicao.json()
    requisicao_js['clouds']['probabilidade_de_chuva'] = requisicao_js['clouds'].pop('all')

    descricao = requisicao_js['weather'][0]['description']
    temperatura = requisicao_js['main']['temp'] - 273.15
    data = requisicao_js['dt']
    prob = requisicao_js['clouds']
    nome = requisicao_js['name']
    pais = requisicao_js['sys']['country']
    temp_max = requisicao_js['main']['temp_max'] - 273.15
    temp_min = requisicao_js['main']['temp_min'] - 273.15
    umidade = requisicao_js['main']['humidity']
    timestamp = data
    data_legivel = datetime.utcfromtimestamp(timestamp).strftime('%Y-%m-%d %H:%M:%S')
    dt_atual = datetime.now().strftime('%Y%m%d')


    for resultado in requisicao_js.items():
        print(resultado)
        lista.append({
            'cidade': nome,
            'pais': pais,
            'descricao':descricao,
            'temperatura': temperatura,
            'temp_max': temp_max,
            'temp_min': temp_min,
            'umidade': umidade,
            'probabilidade': prob
            })


    df = pd.DataFrame(lista)
    display(df)
# Out:
# ('coord', {'lon': -43.2075, 'lat': -22.9028})
# ('weather', [{'id': 800, 'main': 'Clear', 'description': 'céu limpo', 'icon': '01n'}])
# ('base', 'stations')
# ('main', {'temp': 298.13, 'feels_like': 298.59, 'temp_min': 298.13, 'temp_max': 298.15, 'pressure': 1009, 'humidity': 73, 'sea_level': 1009, 'grnd_level': 1010})
# ('visibility', 10000)
# ('wind', {'speed': 4.12, 'deg': 270})
# ('clouds', {'probabilidade_de_chuva': 0})
# ('dt', 1727910510)
# ('sys', {'type': 1, 'id': 8429, 'country': 'BR', 'sunrise': 1727857915, 'sunset': 1727902318})
# ('timezone', -10800)
# ('id', 3451190)
# ('name', 'Rio de Janeiro')
# ('cod', 200)
#             cidade pais  descricao  temperatura  temp_max  temp_min  umidade  \
# 0   Rio de Janeiro   BR  céu limpo        24.98      25.0     24.98       73
# 1   Rio de Janeiro   BR  céu limpo        24.98      25.0     24.98       73
# 2   Rio de Janeiro   BR  céu limpo        24.98      25.0     24.98       73
# 3   Rio de Janeiro   BR  céu limpo        24.98      25.0     24.98       73
# 4   Rio de Janeiro   BR  céu limpo        24.98      25.0     24.98       73
# 5   Rio de Janeiro   BR  céu limpo        24.98      25.0     24.98       73
# 6   Rio de Janeiro   BR  céu limpo        24.98      25.0     24.98       73
# 7   Rio de Janeiro   BR  céu limpo        24.98      25.0     24.98       73
# 8   Rio de Janeiro   BR  céu limpo        24.98      25.0     24.98       73
# 9   Rio de Janeiro   BR  céu limpo        24.98      25.0     24.98       73
# 10  Rio de Janeiro   BR  céu limpo        24.98      25.0     24.98       73
# 11  Rio de Janeiro   BR  céu limpo        24.98      25.0     24.98       73
# 12  Rio de Janeiro   BR  céu limpo        24.98      25.0     24.98       73
#
#                     probabilidade
# 0   {'probabilidade_de_chuva': 0}
# 1   {'probabilidade_de_chuva': 0}
# 2   {'probabilidade_de_chuva': 0}
# 3   {'probabilidade_de_chuva': 0}
# 4   {'probabilidade_de_chuva': 0}
# 5   {'probabilidade_de_chuva': 0}
# 6   {'probabilidade_de_chuva': 0}
# 7   {'probabilidade_de_chuva': 0}
# 8   {'probabilidade_de_chuva': 0}
# 9   {'probabilidade_de_chuva': 0}
# 10  {'probabilidade_de_chuva': 0}
# 11  {'probabilidade_de_chuva': 0}
# 12  {'probabilidade_de_chuva': 0}
# ('coord', {'lon': -46.5867, 'lat': -23.3186})
# ('weather', [{'id': 803, 'main': 'Clouds', 'description': 'nublado', 'icon': '04n'}])
# ('base', 'stations')
# ('main', {'temp': 294.1, 'feels_like': 294.29, 'temp_min': 293.96, 'temp_max': 295.47, 'pressure': 1011, 'humidity': 78, 'sea_level': 1011, 'grnd_level': 913})
# ('visibility', 8000)
# ('wind', {'speed': 4.12, 'deg': 160})
# ('clouds', {'probabilidade_de_chuva': 75})
# ('dt', 1727911047)
# ('sys', {'type': 1, 'id': 8379, 'country': 'BR', 'sunrise': 1727858717, 'sunset': 1727903137})
# ('timezone', -10800)
# ('id', 3458131)
# ('name', 'Mairiporã')
# ('cod', 200)
#             cidade pais  descricao  temperatura  temp_max  temp_min  umidade  \
# 0   Rio de Janeiro   BR  céu limpo        24.98     25.00     24.98       73
# 1   Rio de Janeiro   BR  céu limpo        24.98     25.00     24.98       73
# 2   Rio de Janeiro   BR  céu limpo        24.98     25.00     24.98       73
# 3   Rio de Janeiro   BR  céu limpo        24.98     25.00     24.98       73
# 4   Rio de Janeiro   BR  céu limpo        24.98     25.00     24.98       73
# 5   Rio de Janeiro   BR  céu limpo        24.98     25.00     24.98       73
# 6   Rio de Janeiro   BR  céu limpo        24.98     25.00     24.98       73
# 7   Rio de Janeiro   BR  céu limpo        24.98     25.00     24.98       73
# 8   Rio de Janeiro   BR  céu limpo        24.98     25.00     24.98       73
# 9   Rio de Janeiro   BR  céu limpo        24.98     25.00     24.98       73
# 10  Rio de Janeiro   BR  céu limpo        24.98     25.00     24.98       73
# 11  Rio de Janeiro   BR  céu limpo        24.98     25.00     24.98       73
# 12  Rio de Janeiro   BR  céu limpo        24.98     25.00     24.98       73
# 13       Mairiporã   BR    nublado        20.95     22.32     20.81       78
# 14       Mairiporã   BR    nublado        20.95     22.32     20.81       78
# 15       Mairiporã   BR    nublado        20.95     22.32     20.81       78
# 16       Mairiporã   BR    nublado        20.95     22.32     20.81       78
# 17       Mairiporã   BR    nublado        20.95     22.32     20.81       78
# 18       Mairiporã   BR    nublado        20.95     22.32     20.81       78
# 19       Mairiporã   BR    nublado        20.95     22.32     20.81       78
# 20       Mairiporã   BR    nublado        20.95     22.32     20.81       78
# 21       Mairiporã   BR    nublado        20.95     22.32     20.81       78
# 22       Mairiporã   BR    nublado        20.95     22.32     20.81       78
# 23       Mairiporã   BR    nublado        20.95     22.32     20.81       78
# 24       Mairiporã   BR    nublado        20.95     22.32     20.81       78
# 25       Mairiporã   BR    nublado        20.95     22.32     20.81       78
#
#                      probabilidade
# 0    {'probabilidade_de_chuva': 0}
# 1    {'probabilidade_de_chuva': 0}
# 2    {'probabilidade_de_chuva': 0}
# 3    {'probabilidade_de_chuva': 0}
# 4    {'probabilidade_de_chuva': 0}
# 5    {'probabilidade_de_chuva': 0}
# 6    {'probabilidade_de_chuva': 0}
# 7    {'probabilidade_de_chuva': 0}
# 8    {'probabilidade_de_chuva': 0}
# 9    {'probabilidade_de_chuva': 0}
# 10   {'probabilidade_de_chuva': 0}
# 11   {'probabilidade_de_chuva': 0}
# 12   {'probabilidade_de_chuva': 0}
# 13  {'probabilidade_de_chuva': 75}
# 14  {'probabilidade_de_chuva': 75}
# 15  {'probabilidade_de_chuva': 75}
# 16  {'probabilidade_de_chuva': 75}
# 17  {'probabilidade_de_chuva': 75}
# 18  {'probabilidade_de_chuva': 75}
# 19  {'probabilidade_de_chuva': 75}
# 20  {'probabilidade_de_chuva': 75}
# 21  {'probabilidade_de_chuva': 75}
# 22  {'probabilidade_de_chuva': 75}
# 23  {'probabilidade_de_chuva': 75}
# 24  {'probabilidade_de_chuva': 75}
# 25  {'probabilidade_de_chuva': 75}
# ('coord', {'lon': -46.589, 'lat': -23.131})
# ('weather', [{'id': 802, 'main': 'Clouds', 'description': 'nuvens dispersas', 'icon': '03n'}])
# ('base', 'stations')
# ('main', {'temp': 296.86, 'feels_like': 296.67, 'temp_min': 296.86, 'temp_max': 296.86, 'pressure': 1010, 'humidity': 53, 'sea_level': 1010, 'grnd_level': 914})
# ('visibility', 10000)
# ('wind', {'speed': 3.71, 'deg': 163, 'gust': 8.31})
# ('clouds', {'probabilidade_de_chuva': 44})
# ('dt', 1727911076)
# ('sys', {'country': 'BR', 'sunrise': 1727858721, 'sunset': 1727903134})
# ('timezone', -10800)
# ('id', 6322114)
# ('name', 'Atibaia')
# ('cod', 200)
#             cidade pais         descricao  temperatura  temp_max  temp_min  \
# 0   Rio de Janeiro   BR         céu limpo        24.98     25.00     24.98
# 1   Rio de Janeiro   BR         céu limpo        24.98     25.00     24.98
# 2   Rio de Janeiro   BR         céu limpo        24.98     25.00     24.98
# 3   Rio de Janeiro   BR         céu limpo        24.98     25.00     24.98
# 4   Rio de Janeiro   BR         céu limpo        24.98     25.00     24.98
# 5   Rio de Janeiro   BR         céu limpo        24.98     25.00     24.98
# 6   Rio de Janeiro   BR         céu limpo        24.98     25.00     24.98
# 7   Rio de Janeiro   BR         céu limpo        24.98     25.00     24.98
# 8   Rio de Janeiro   BR         céu limpo        24.98     25.00     24.98
# 9   Rio de Janeiro   BR         céu limpo        24.98     25.00     24.98
# 10  Rio de Janeiro   BR         céu limpo        24.98     25.00     24.98
# 11  Rio de Janeiro   BR         céu limpo        24.98     25.00     24.98
# 12  Rio de Janeiro   BR         céu limpo        24.98     25.00     24.98
# 13       Mairiporã   BR           nublado        20.95     22.32     20.81
# 14       Mairiporã   BR           nublado        20.95     22.32     20.81
# 15       Mairiporã   BR           nublado        20.95     22.32     20.81
# 16       Mairiporã   BR           nublado        20.95     22.32     20.81
# 17       Mairiporã   BR           nublado        20.95     22.32     20.81
# 18       Mairiporã   BR           nublado        20.95     22.32     20.81
# 19       Mairiporã   BR           nublado        20.95     22.32     20.81
# 20       Mairiporã   BR           nublado        20.95     22.32     20.81
# 21       Mairiporã   BR           nublado        20.95     22.32     20.81
# 22       Mairiporã   BR           nublado        20.95     22.32     20.81
# 23       Mairiporã   BR           nublado        20.95     22.32     20.81
# 24       Mairiporã   BR           nublado        20.95     22.32     20.81
# 25       Mairiporã   BR           nublado        20.95     22.32     20.81
# 26         Atibaia   BR  nuvens dispersas        23.71     23.71     23.71
# 27         Atibaia   BR  nuvens dispersas        23.71     23.71     23.71
# 28         Atibaia   BR  nuvens dispersas        23.71     23.71     23.71
# 29         Atibaia   BR  nuvens dispersas        23.71     23.71     23.71
# 30         Atibaia   BR  nuvens dispersas        23.71     23.71     23.71
# 31         Atibaia   BR  nuvens dispersas        23.71     23.71     23.71
# 32         Atibaia   BR  nuvens dispersas        23.71     23.71     23.71
# 33         Atibaia   BR  nuvens dispersas        23.71     23.71     23.71
# 34         Atibaia   BR  nuvens dispersas        23.71     23.71     23.71
# 35         Atibaia   BR  nuvens dispersas        23.71     23.71     23.71
# 36         Atibaia   BR  nuvens dispersas        23.71     23.71     23.71
# 37         Atibaia   BR  nuvens dispersas        23.71     23.71     23.71
# 38         Atibaia   BR  nuvens dispersas        23.71     23.71     23.71
#
#     umidade                   probabilidade
# 0        73   {'probabilidade_de_chuva': 0}
# 1        73   {'probabilidade_de_chuva': 0}
# 2        73   {'probabilidade_de_chuva': 0}
# 3        73   {'probabilidade_de_chuva': 0}
# 4        73   {'probabilidade_de_chuva': 0}
# 5        73   {'probabilidade_de_chuva': 0}
# 6        73   {'probabilidade_de_chuva': 0}
# 7        73   {'probabilidade_de_chuva': 0}
# 8        73   {'probabilidade_de_chuva': 0}
# 9        73   {'probabilidade_de_chuva': 0}
# 10       73   {'probabilidade_de_chuva': 0}
# 11       73   {'probabilidade_de_chuva': 0}
# 12       73   {'probabilidade_de_chuva': 0}
# 13       78  {'probabilidade_de_chuva': 75}
# 14       78  {'probabilidade_de_chuva': 75}
# 15       78  {'probabilidade_de_chuva': 75}
# 16       78  {'probabilidade_de_chuva': 75}
# 17       78  {'probabilidade_de_chuva': 75}
# 18       78  {'probabilidade_de_chuva': 75}
# 19       78  {'probabilidade_de_chuva': 75}
# 20       78  {'probabilidade_de_chuva': 75}
# 21       78  {'probabilidade_de_chuva': 75}
# 22       78  {'probabilidade_de_chuva': 75}
# 23       78  {'probabilidade_de_chuva': 75}
# 24       78  {'probabilidade_de_chuva': 75}
# 25       78  {'probabilidade_de_chuva': 75}
# 26       53  {'probabilidade_de_chuva': 44}
# 27       53  {'probabilidade_de_chuva': 44}
# 28       53  {'probabilidade_de_chuva': 44}
# 29       53  {'probabilidade_de_chuva': 44}
# 30       53  {'probabilidade_de_chuva': 44}
# 31       53  {'probabilidade_de_chuva': 44}
# 32       53  {'probabilidade_de_chuva': 44}
# 33       53  {'probabilidade_de_chuva': 44}
# 34       53  {'probabilidade_de_chuva': 44}
# 35       53  {'probabilidade_de_chuva': 44}
# 36       53  {'probabilidade_de_chuva': 44}
# 37       53  {'probabilidade_de_chuva': 44}
# 38       53  {'probabilidade_de_chuva': 44}
# ('coord', {'lon': -46.6361, 'lat': -23.5475})
# ('weather', [{'id': 803, 'main': 'Clouds', 'description': 'nublado', 'icon': '04n'}])
# ('base', 'stations')
# ('main', {'temp': 293.89, 'feels_like': 294.13, 'temp_min': 293.4, 'temp_max': 294.35, 'pressure': 1012, 'humidity': 81, 'sea_level': 1012, 'grnd_level': 923})
# ('visibility', 8000)
# ('wind', {'speed': 6.69, 'deg': 180})
# ('clouds', {'probabilidade_de_chuva': 75})
# ('dt', 1727910970)
# ('sys', {'type': 1, 'id': 8394, 'country': 'BR', 'sunrise': 1727858724, 'sunset': 1727903154})
# ('timezone', -10800)
# ('id', 3448439)
# ('name', 'São Paulo')
# ('cod', 200)
#             cidade pais         descricao  temperatura  temp_max  temp_min  \
# 0   Rio de Janeiro   BR         céu limpo        24.98     25.00     24.98
# 1   Rio de Janeiro   BR         céu limpo        24.98     25.00     24.98
# 2   Rio de Janeiro   BR         céu limpo        24.98     25.00     24.98
# 3   Rio de Janeiro   BR         céu limpo        24.98     25.00     24.98
# 4   Rio de Janeiro   BR         céu limpo        24.98     25.00     24.98
# 5   Rio de Janeiro   BR         céu limpo        24.98     25.00     24.98
# 6   Rio de Janeiro   BR         céu limpo        24.98     25.00     24.98
# 7   Rio de Janeiro   BR         céu limpo        24.98     25.00     24.98
# 8   Rio de Janeiro   BR         céu limpo        24.98     25.00     24.98
# 9   Rio de Janeiro   BR         céu limpo        24.98     25.00     24.98
# 10  Rio de Janeiro   BR         céu limpo        24.98     25.00     24.98
# 11  Rio de Janeiro   BR         céu limpo        24.98     25.00     24.98
# 12  Rio de Janeiro   BR         céu limpo        24.98     25.00     24.98
# 13       Mairiporã   BR           nublado        20.95     22.32     20.81
# 14       Mairiporã   BR           nublado        20.95     22.32     20.81
# 15       Mairiporã   BR           nublado        20.95     22.32     20.81
# 16       Mairiporã   BR           nublado        20.95     22.32     20.81
# 17       Mairiporã   BR           nublado        20.95     22.32     20.81
# 18       Mairiporã   BR           nublado        20.95     22.32     20.81
# 19       Mairiporã   BR           nublado        20.95     22.32     20.81
# 20       Mairiporã   BR           nublado        20.95     22.32     20.81
# 21       Mairiporã   BR           nublado        20.95     22.32     20.81
# 22       Mairiporã   BR           nublado        20.95     22.32     20.81
# 23       Mairiporã   BR           nublado        20.95     22.32     20.81
# 24       Mairiporã   BR           nublado        20.95     22.32     20.81
# 25       Mairiporã   BR           nublado        20.95     22.32     20.81
# 26         Atibaia   BR  nuvens dispersas        23.71     23.71     23.71
# 27         Atibaia   BR  nuvens dispersas        23.71     23.71     23.71
# 28         Atibaia   BR  nuvens dispersas        23.71     23.71     23.71
# 29         Atibaia   BR  nuvens dispersas        23.71     23.71     23.71
# 30         Atibaia   BR  nuvens dispersas        23.71     23.71     23.71
# 31         Atibaia   BR  nuvens dispersas        23.71     23.71     23.71
# 32         Atibaia   BR  nuvens dispersas        23.71     23.71     23.71
# 33         Atibaia   BR  nuvens dispersas        23.71     23.71     23.71
# 34         Atibaia   BR  nuvens dispersas        23.71     23.71     23.71
# 35         Atibaia   BR  nuvens dispersas        23.71     23.71     23.71
# 36         Atibaia   BR  nuvens dispersas        23.71     23.71     23.71
# 37         Atibaia   BR  nuvens dispersas        23.71     23.71     23.71
# 38         Atibaia   BR  nuvens dispersas        23.71     23.71     23.71
# 39       São Paulo   BR           nublado        20.74     21.20     20.25
# 40       São Paulo   BR           nublado        20.74     21.20     20.25
# 41       São Paulo   BR           nublado        20.74     21.20     20.25
# 42       São Paulo   BR           nublado        20.74     21.20     20.25
# 43       São Paulo   BR           nublado        20.74     21.20     20.25
# 44       São Paulo   BR           nublado        20.74     21.20     20.25
# 45       São Paulo   BR           nublado        20.74     21.20     20.25
# 46       São Paulo   BR           nublado        20.74     21.20     20.25
# 47       São Paulo   BR           nublado        20.74     21.20     20.25
# 48       São Paulo   BR           nublado        20.74     21.20     20.25
# 49       São Paulo   BR           nublado        20.74     21.20     20.25
# 50       São Paulo   BR           nublado        20.74     21.20     20.25
# 51       São Paulo   BR           nublado        20.74     21.20     20.25
#
#     umidade                   probabilidade
# 0        73   {'probabilidade_de_chuva': 0}
# 1        73   {'probabilidade_de_chuva': 0}
# 2        73   {'probabilidade_de_chuva': 0}
# 3        73   {'probabilidade_de_chuva': 0}
# 4        73   {'probabilidade_de_chuva': 0}
# 5        73   {'probabilidade_de_chuva': 0}
# 6        73   {'probabilidade_de_chuva': 0}
# 7        73   {'probabilidade_de_chuva': 0}
# 8        73   {'probabilidade_de_chuva': 0}
# 9        73   {'probabilidade_de_chuva': 0}
# 10       73   {'probabilidade_de_chuva': 0}
# 11       73   {'probabilidade_de_chuva': 0}
# 12       73   {'probabilidade_de_chuva': 0}
# 13       78  {'probabilidade_de_chuva': 75}
# 14       78  {'probabilidade_de_chuva': 75}
# 15       78  {'probabilidade_de_chuva': 75}
# 16       78  {'probabilidade_de_chuva': 75}
# 17       78  {'probabilidade_de_chuva': 75}
# 18       78  {'probabilidade_de_chuva': 75}
# 19       78  {'probabilidade_de_chuva': 75}
# 20       78  {'probabilidade_de_chuva': 75}
# 21       78  {'probabilidade_de_chuva': 75}
# 22       78  {'probabilidade_de_chuva': 75}
# 23       78  {'probabilidade_de_chuva': 75}
# 24       78  {'probabilidade_de_chuva': 75}
# 25       78  {'probabilidade_de_chuva': 75}
# 26       53  {'probabilidade_de_chuva': 44}
# 27       53  {'probabilidade_de_chuva': 44}
# 28       53  {'probabilidade_de_chuva': 44}
# 29       53  {'probabilidade_de_chuva': 44}
# 30       53  {'probabilidade_de_chuva': 44}
# 31       53  {'probabilidade_de_chuva': 44}
# 32       53  {'probabilidade_de_chuva': 44}
# 33       53  {'probabilidade_de_chuva': 44}
# 34       53  {'probabilidade_de_chuva': 44}
# 35       53  {'probabilidade_de_chuva': 44}
# 36       53  {'probabilidade_de_chuva': 44}
# 37       53  {'probabilidade_de_chuva': 44}
# 38       53  {'probabilidade_de_chuva': 44}
# 39       81  {'probabilidade_de_chuva': 75}
# 40       81  {'probabilidade_de_chuva': 75}
# 41       81  {'probabilidade_de_chuva': 75}
# 42       81  {'probabilidade_de_chuva': 75}
# 43       81  {'probabilidade_de_chuva': 75}
# 44       81  {'probabilidade_de_chuva': 75}
# 45       81  {'probabilidade_de_chuva': 75}
# 46       81  {'probabilidade_de_chuva': 75}
# 47       81  {'probabilidade_de_chuva': 75}
# 48       81  {'probabilidade_de_chuva': 75}
# 49       81  {'probabilidade_de_chuva': 75}
# 50       81  {'probabilidade_de_chuva': 75}
# 51       81  {'probabilidade_de_chuva': 75}

# %%
import requests
import datetime
from datetime import datetime
import pandas as pd
import re


api_key = '7d345b55e9fbcf6989728ab565b60c59'
cidade = {
    'São Paulo', 
    'Rio de Janeiro', 
    'Mairiporã', 
    'Atibaia',
    'Franco da Rocha',
    'Curitiba',
    'Belo Horizonte',
    'Osasco',
    'Guarulhos',
    'Barueri',
    'Alphaville',
    'Caieiras',
    'Bragança Paulista',
    'Praia Grande',
    'Santos'
    }
# lat = ' -23.19.07'
# lon = '46.35.12'
# excl = ''
lista = []
for cidades in cidade:
    link = f"https://api.openweathermap.org/data/2.5/weather?q={cidades}&appid={api_key}&lang=pt_br"
    requisicao = requests.get(link)
    requisicao_js = requisicao.json()
    # requisicao_js['clouds']['probabilidade_de_chuva'] = requisicao_js['clouds'].pop('all')
   

    descricao = requisicao_js['weather'][0]['description']
    temperatura = requisicao_js['main']['temp'] - 273.15
    data = requisicao_js['dt']
    prob = requisicao_js['clouds']
    nome = requisicao_js['name']
    pais = requisicao_js['sys']['country']
    temp_max = requisicao_js['main']['temp_max'] - 273.15
    temp_min = requisicao_js['main']['temp_min'] - 273.15
    umidade = requisicao_js['main']['humidity']
    timestamp = data
    data_legivel = datetime.utcfromtimestamp(timestamp).strftime('%Y-%m-%d %H:%M:%S')
    dt_atual = datetime.now().strftime('%Y-%m-%d')
    latitude = requisicao_js['coord']['lat']
    longitude = requisicao_js['coord']['lon']
    descricao = requisicao_js['weather']
    desc = requisicao_js['weather'][0]['description']
    probabilidade = requisicao_js['clouds']['all']


    for resultado in requisicao_js.items():
        print(resultado)
        
    lista.append({
        'cidade': nome,
        'pais': pais,
        'temperatura': temperatura,
        'temp_max': temp_max,
        'temp_min': temp_min,
        'umidade': umidade,
        'prob_chuva': probabilidade,
        'data': dt_atual,
        'latitude': latitude,
        'longitude': longitude,
        'tempo': desc,
        })


df = pd.DataFrame(lista)
display(df)


save = '/workspaces/projeto_ing/apis/app/src/temp/'
arq = 'arquivo_teste_temp.txt'

df.to_csv(f'{save}{arq}', sep=';', index=False)
print(f'df salvo no caminho: {save}')
# Out:
# ('coord', {'lon': -46.589, 'lat': -23.131})
# ('weather', [{'id': 803, 'main': 'Clouds', 'description': 'nublado', 'icon': '04n'}])
# ('base', 'stations')
# ('main', {'temp': 295.34, 'feels_like': 295.36, 'temp_min': 295.34, 'temp_max': 295.34, 'pressure': 1012, 'humidity': 67, 'sea_level': 1012, 'grnd_level': 915})
# ('visibility', 10000)
# ('wind', {'speed': 3.93, 'deg': 167, 'gust': 9.81})
# ('clouds', {'all': 54})
# ('dt', 1727914884)
# ('sys', {'country': 'BR', 'sunrise': 1727858721, 'sunset': 1727903134})
# ('timezone', -10800)
# ('id', 6322114)
# ('name', 'Atibaia')
# ('cod', 200)
# ('coord', {'lon': -46.6361, 'lat': -23.5475})
# ('weather', [{'id': 803, 'main': 'Clouds', 'description': 'nublado', 'icon': '04n'}])
# ('base', 'stations')
# ('main', {'temp': 294.03, 'feels_like': 294.24, 'temp_min': 293.09, 'temp_max': 295.07, 'pressure': 1013, 'humidity': 79, 'sea_level': 1013, 'grnd_level': 924})
# ('visibility', 8000)
# ('wind', {'speed': 7.2, 'deg': 150})
# ('clouds', {'all': 75})
# ('dt', 1727914680)
# ('sys', {'type': 1, 'id': 8394, 'country': 'BR', 'sunrise': 1727858724, 'sunset': 1727903154})
# ('timezone', -10800)
# ('id', 3448439)
# ('name', 'São Paulo')
# ('cod', 200)
# ('coord', {'lon': -46.7406, 'lat': -23.3642})
# ('weather', [{'id': 803, 'main': 'Clouds', 'description': 'nublado', 'icon': '04n'}])
# ('base', 'stations')
# ('main', {'temp': 294.78, 'feels_like': 294.9, 'temp_min': 292.99, 'temp_max': 294.97, 'pressure': 1012, 'humidity': 73, 'sea_level': 1012, 'grnd_level': 921})
# ('visibility', 10000)
# ('wind', {'speed': 4.51, 'deg': 135, 'gust': 8.65})
# ('clouds', {'all': 79})
# ('dt', 1727914398)
# ('sys', {'type': 2, 'id': 2082654, 'country': 'BR', 'sunrise': 1727858753, 'sunset': 1727903175})
# ('timezone', -10800)
# ('id', 3468215)
# ('name', 'Caieiras')
# ('cod', 200)
# ('coord', {'lon': -46.8761, 'lat': -23.5106})
# ('weather', [{'id': 803, 'main': 'Clouds', 'description': 'nublado', 'icon': '04n'}])
# ('base', 'stations')
# ('main', {'temp': 295.16, 'feels_like': 295.69, 'temp_min': 293.57, 'temp_max': 295.29, 'pressure': 1012, 'humidity': 87, 'sea_level': 1012, 'grnd_level': 921})
# ('visibility', 10000)
# ('wind', {'speed': 4.83, 'deg': 147, 'gust': 8.61})
# ('clouds', {'all': 75})
# ('dt', 1727914633)
# ('sys', {'type': 2, 'id': 2041565, 'country': 'BR', 'sunrise': 1727858782, 'sunset': 1727903211})
# ('timezone', -10800)
# ('id', 3470353)
# ('name', 'Barueri')
# ('cod', 200)
# ('coord', {'lon': -46.5867, 'lat': -23.3186})
# ('weather', [{'id': 803, 'main': 'Clouds', 'description': 'nublado', 'icon': '04n'}])
# ('base', 'stations')
# ('main', {'temp': 293.33, 'feels_like': 293.7, 'temp_min': 293.14, 'temp_max': 294.92, 'pressure': 1013, 'humidity': 88, 'sea_level': 1013, 'grnd_level': 914})
# ('visibility', 10000)
# ('wind', {'speed': 2.57, 'deg': 150})
# ('clouds', {'all': 75})
# ('dt', 1727914884)
# ('sys', {'type': 1, 'id': 8379, 'country': 'BR', 'sunrise': 1727858717, 'sunset': 1727903137})
# ('timezone', -10800)
# ('id', 3458131)
# ('name', 'Mairiporã')
# ('cod', 200)
# ('coord', {'lon': -51.1863, 'lat': -23.3479})
# ('weather', [{'id': 803, 'main': 'Clouds', 'description': 'nublado', 'icon': '04n'}])
# ('base', 'stations')
# ('main', {'temp': 299.06, 'feels_like': 299.3, 'temp_min': 299.06, 'temp_max': 299.06, 'pressure': 1008, 'humidity': 61, 'sea_level': 1008, 'grnd_level': 948})
# ('visibility', 7000)
# ('wind', {'speed': 5.66, 'deg': 180})
# ('clouds', {'all': 66})
# ('dt', 1727914633)
# ('sys', {'type': 1, 'id': 8399, 'country': 'BR', 'sunrise': 1727859819, 'sunset': 1727904242})
# ('timezone', -10800)
# ('id', 3458449)
# ('name', 'Alphaville')
# ('cod', 200)
# ('coord', {'lon': -49.2908, 'lat': -25.504})
# ('weather', [{'id': 804, 'main': 'Clouds', 'description': 'nublado', 'icon': '04n'}])
# ('base', 'stations')
# ('main', {'temp': 289.98, 'feels_like': 289.49, 'temp_min': 289.06, 'temp_max': 290.74, 'pressure': 1015, 'humidity': 68, 'sea_level': 1015, 'grnd_level': 914})
# ('visibility', 8000)
# ('wind', {'speed': 3.09, 'deg': 20})
# ('clouds', {'all': 100})
# ('dt', 1727914354)
# ('sys', {'type': 2, 'id': 67576, 'country': 'BR', 'sunrise': 1727859320, 'sunset': 1727903832})
# ('timezone', -10800)
# ('id', 6322752)
# ('name', 'Curitiba')
# ('cod', 200)
# ('coord', {'lon': -46.5333, 'lat': -23.4628})
# ('weather', [{'id': 803, 'main': 'Clouds', 'description': 'nublado', 'icon': '04n'}])
# ('base', 'stations')
# ('main', {'temp': 293.46, 'feels_like': 293.64, 'temp_min': 293.03, 'temp_max': 295.01, 'pressure': 1013, 'humidity': 80, 'sea_level': 1013, 'grnd_level': 923})
# ('visibility', 10000)
# ('wind', {'speed': 5.14, 'deg': 130})
# ('clouds', {'all': 75})
# ('dt', 1727914633)
# ('sys', {'type': 1, 'id': 8379, 'country': 'BR', 'sunrise': 1727858701, 'sunset': 1727903128})
# ('timezone', -10800)
# ('id', 3461786)
# ('name', 'Guarulhos')
# ('cod', 200)
# ('coord', {'lon': -46.4028, 'lat': -24.0058})
# ('weather', [{'id': 804, 'main': 'Clouds', 'description': 'nublado', 'icon': '04n'}])
# ('base', 'stations')
# ('main', {'temp': 295.34, 'feels_like': 294.29, 'temp_min': 295.34, 'temp_max': 295.34, 'pressure': 1013, 'humidity': 26, 'sea_level': 1013, 'grnd_level': 996})
# ('visibility', 10000)
# ('wind', {'speed': 2.96, 'deg': 225, 'gust': 6.84})
# ('clouds', {'all': 89})
# ('dt', 1727914484)
# ('sys', {'type': 2, 'id': 2089715, 'country': 'BR', 'sunrise': 1727858659, 'sunset': 1727903108})
# ('timezone', -10800)
# ('id', 3452465)
# ('name', 'Praia Grande')
# ('cod', 200)
# ('coord', {'lon': -46.3336, 'lat': -23.9608})
# ('weather', [{'id': 804, 'main': 'Clouds', 'description': 'nublado', 'icon': '04n'}])
# ('base', 'stations')
# ('main', {'temp': 295.34, 'feels_like': 294.29, 'temp_min': 295.34, 'temp_max': 295.34, 'pressure': 1013, 'humidity': 26, 'sea_level': 1013, 'grnd_level': 996})
# ('visibility', 10000)
# ('wind', {'speed': 3.25, 'deg': 228, 'gust': 7.39})
# ('clouds', {'all': 85})
# ('dt', 1727914523)
# ('sys', {'type': 2, 'id': 2089715, 'country': 'BR', 'sunrise': 1727858643, 'sunset': 1727903090})
# ('timezone', -10800)
# ('id', 3449433)
# ('name', 'Santos')
# ('cod', 200)
# ('coord', {'lon': -46.7269, 'lat': -23.3217})
# ('weather', [{'id': 803, 'main': 'Clouds', 'description': 'nublado', 'icon': '04n'}])
# ('base', 'stations')
# ('main', {'temp': 294.37, 'feels_like': 294.3, 'temp_min': 293.21, 'temp_max': 295, 'pressure': 1012, 'humidity': 67, 'sea_level': 1012, 'grnd_level': 920})
# ('visibility', 10000)
# ('wind', {'speed': 4.35, 'deg': 138, 'gust': 9.09})
# ('clouds', {'all': 80})
# ('dt', 1727914884)
# ('sys', {'type': 1, 'id': 8394, 'country': 'BR', 'sunrise': 1727858750, 'sunset': 1727903171})
# ('timezone', -10800)
# ('id', 3462964)
# ('name', 'Franco da Rocha')
# ('cod', 200)
# ('coord', {'lon': -43.9378, 'lat': -19.9208})
# ('weather', [{'id': 800, 'main': 'Clear', 'description': 'céu limpo', 'icon': '01n'}])
# ('base', 'stations')
# ('main', {'temp': 299.59, 'feels_like': 299.59, 'temp_min': 299.59, 'temp_max': 299.59, 'pressure': 1012, 'humidity': 39, 'sea_level': 1012, 'grnd_level': 904})
# ('visibility', 10000)
# ('wind', {'speed': 3.6, 'deg': 100})
# ('clouds', {'all': 0})
# ('dt', 1727914568)
# ('sys', {'type': 1, 'id': 8329, 'country': 'BR', 'sunrise': 1727858149, 'sunset': 1727902434})
# ('timezone', -10800)
# ('id', 3470127)
# ('name', 'Belo Horizonte')
# ('cod', 200)
# ('coord', {'lon': -46.7917, 'lat': -23.5325})
# ('weather', [{'id': 803, 'main': 'Clouds', 'description': 'nublado', 'icon': '04n'}])
# ('base', 'stations')
# ('main', {'temp': 295.01, 'feels_like': 295.47, 'temp_min': 293.44, 'temp_max': 295.15, 'pressure': 1012, 'humidity': 85, 'sea_level': 1012, 'grnd_level': 922})
# ('visibility', 8000)
# ('wind', {'speed': 7.2, 'deg': 150})
# ('clouds', {'all': 75})
# ('dt', 1727914634)
# ('sys', {'type': 2, 'id': 2041565, 'country': 'BR', 'sunrise': 1727858762, 'sunset': 1727903191})
# ('timezone', -10800)
# ('id', 3455775)
# ('name', 'Osasco')
# ('cod', 200)
# ('coord', {'lon': -43.2075, 'lat': -22.9028})
# ('weather', [{'id': 800, 'main': 'Clear', 'description': 'céu limpo', 'icon': '01n'}])
# ('base', 'stations')
# ('main', {'temp': 298.13, 'feels_like': 298.64, 'temp_min': 297.12, 'temp_max': 298.15, 'pressure': 1009, 'humidity': 75, 'sea_level': 1009, 'grnd_level': 1011})
# ('visibility', 10000)
# ('wind', {'speed': 4.12, 'deg': 280})
# ('clouds', {'all': 0})
# ('dt', 1727914586)
# ('sys', {'type': 1, 'id': 8429, 'country': 'BR', 'sunrise': 1727857915, 'sunset': 1727902318})
# ('timezone', -10800)
# ('id', 3451190)
# ('name', 'Rio de Janeiro')
# ('cod', 200)
# ('coord', {'lon': -46.5556, 'lat': -22.94})
# ('weather', [{'id': 802, 'main': 'Clouds', 'description': 'nuvens dispersas', 'icon': '03n'}])
# ('base', 'stations')
# ('main', {'temp': 296.96, 'feels_like': 296.75, 'temp_min': 296.96, 'temp_max': 296.96, 'pressure': 1012, 'humidity': 52, 'sea_level': 1012, 'grnd_level': 914})
# ('visibility', 10000)
# ('wind', {'speed': 3.8, 'deg': 175, 'gust': 9.57})
# ('clouds', {'all': 42})
# ('dt', 1727914481)
# ('sys', {'country': 'BR', 'sunrise': 1727858717, 'sunset': 1727903122})
# ('timezone', -10800)
# ('id', 6322152)
# ('name', 'Bragança Paulista')
# ('cod', 200)
#                cidade pais  temperatura  temp_max  temp_min  umidade  \
# 0             Atibaia   BR        22.19     22.19     22.19       67
# 1           São Paulo   BR        20.88     21.92     19.94       79
# 2            Caieiras   BR        21.63     21.82     19.84       73
# 3             Barueri   BR        22.01     22.14     20.42       87
# 4           Mairiporã   BR        20.18     21.77     19.99       88
# 5          Alphaville   BR        25.91     25.91     25.91       61
# 6            Curitiba   BR        16.83     17.59     15.91       68
# 7           Guarulhos   BR        20.31     21.86     19.88       80
# 8        Praia Grande   BR        22.19     22.19     22.19       26
# 9              Santos   BR        22.19     22.19     22.19       26
# 10    Franco da Rocha   BR        21.22     21.85     20.06       67
# 11     Belo Horizonte   BR        26.44     26.44     26.44       39
# 12             Osasco   BR        21.86     22.00     20.29       85
# 13     Rio de Janeiro   BR        24.98     25.00     23.97       75
# 14  Bragança Paulista   BR        23.81     23.81     23.81       52
#
#     prob_chuva        data  latitude  longitude             tempo
# 0           54  2024-10-03  -23.1310   -46.5890           nublado
# 1           75  2024-10-03  -23.5475   -46.6361           nublado
# 2           79  2024-10-03  -23.3642   -46.7406           nublado
# 3           75  2024-10-03  -23.5106   -46.8761           nublado
# 4           75  2024-10-03  -23.3186   -46.5867           nublado
# 5           66  2024-10-03  -23.3479   -51.1863           nublado
# 6          100  2024-10-03  -25.5040   -49.2908           nublado
# 7           75  2024-10-03  -23.4628   -46.5333           nublado
# 8           89  2024-10-03  -24.0058   -46.4028           nublado
# 9           85  2024-10-03  -23.9608   -46.3336           nublado
# 10          80  2024-10-03  -23.3217   -46.7269           nublado
# 11           0  2024-10-03  -19.9208   -43.9378         céu limpo
# 12          75  2024-10-03  -23.5325   -46.7917           nublado
# 13           0  2024-10-03  -22.9028   -43.2075         céu limpo
# 14          42  2024-10-03  -22.9400   -46.5556  nuvens dispersas
# df salvo no caminho: /workspaces/projeto_ing/apis/app/src/temp/
