# %%
import pandas as pd 
import sqlite3

# %%
banco = '/workspaces/projeto_ing/database/sqlite/silver/localizacao.db'
bronze = '/workspaces/projeto_ing/database/sqlite/bronze/banco_geo.db'
conn = sqlite3.connect(bronze)
cursor = conn.cursor()

# %%
# Consulta SQL para listar todas as tabelas no banco de dados
show_tables_query = "SELECT name FROM sqlite_master WHERE type='table';"
cursor.execute(show_tables_query)

# Recuperar o resultado da consulta e imprimir as tabelas
tables = cursor.fetchall()
print("Tabelas no banco de dados:")
for table in tables:
    print(table[0])
# Out:
# Tabelas no banco de dados:
# tabela_geo
# slvr_geo

# %%
query = 'select * from tb_slvr_geo'

cursor.execute(query)

tables = cursor.fetchall()

for resultado in tables:
    print(resultado)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[6], line 3
#       1 query = 'select * from tb_brnz_geo'
# ----> 3 cursor.execute(query)
#       5 tables = cursor.fetchall()
#       7 for resultado in tables:
#
# OperationalError: no such table: tb_brnz_geo

# %%
bronze = '/workspaces/projeto_ing/database/sqlite/bronze/banco_geo.db'
conn = sqlite3.connect(bronze)
cursor = conn.cursor()

query_geo = 'select * from tabela_geo'

cursor.execute(query_geo)

tables = cursor.fetchall()
for resultado in tables:
    print(resultado)
# Out:
# (291790410, 'Abadia', 2917904, 'Jandaíra', 2904, 'Nordeste Baiano', 29, 'Bahia', 'BA', 2, 'Nordeste', 'NE', '2024-07-14')
# (311350310, 'Abadia de Carbonita', 3113503, 'Carbonita', 3103, 'Jequitinhonha', 31, 'Minas Gerais', 'MG', 3, 'Sudeste', 'SE', '2024-07-14')
# (520005005, 'Abadia de Goiás', 5200050, 'Abadia de Goiás', 5203, 'Centro Goiano', 52, 'Goiás', 'GO', 5, 'Centro-Oeste', 'CO', '2024-07-14')
# (310010405, 'Abadia dos Dourados', 3100104, 'Abadia dos Dourados', 3105, 'Triângulo Mineiro/Alto Paranaíba', 31, 'Minas Gerais', 'MG', 3, 'Sudeste', 'SE', '2024-07-14')
# (520010005, 'Abadiânia', 5200100, 'Abadiânia', 5204, 'Leste Goiano', 52, 'Goiás', 'GO', 5, 'Centro-Oeste', 'CO', '2024-07-14')
# (310020305, 'Abaeté', 3100203, 'Abaeté', 3106, 'Central Mineira', 31, 'Minas Gerais', 'MG', 3, 'Sudeste', 'SE', '2024-07-14')
# (315550410, 'Abaeté dos Mendes', 3155504, 'Rio Paranaíba', 3105, 'Triângulo Mineiro/Alto Paranaíba', 31, 'Minas Gerais', 'MG', 3, 'Sudeste', 'SE', '2024-07-14')
# ...
