# %%
import requests
import pandas as pd
from datetime import datetime

# %%
timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
data = datetime.now().strftime('%Y-%m-%d')

# url = 'https://parallelum.com.br/fipe/api/v1/carros/marcas/21/modelos/'
url = 'https://parallelum.com.br/fipe/api/v1/carros/marcas/21/modelos'
response = requests.get(url)

dados = response.json()

data_list = []

if dados:
    modelos = dados['modelos']
    for modelo in modelos:
        codigo = modelo['codigo']
        nome = modelo['nome']
        print(f"codigo: {codigo}")
        print(f"nome: {nome}")
        
        data_list.append({
            'codigo':codigo,
            'modelo':nome
        })
df = pd.DataFrame(data_list)
print(df)

# file = f'modelo_vw_{timestamp}.txt'
# path = '/workspaces/projeto_ing/API/app/src/car/'

# df.to_csv(f'{path}{file}', sep=';', index=False)
# print(f'Arquivo salvo: {file}')
# print(f'Caminho: {path}')
# Out:
# codigo: 437
# nome: 147 C/ CL
# codigo: 438
# nome: 147 Furgão (todos)
# codigo: 439
# nome: 147 Pick-Up (todas)
# codigo: 7097
# nome: 500 ABARTH MULTIAIR 1.4 TB 16V 3p
# codigo: 6885
# nome: 500 Cabrio Dualogic Flex 1.4 8V
# codigo: 6886
# nome: 500 Cabrio Flex 1.4 8V Mec.
# codigo: 6262
# nome: 500 Cabrio/500 Coupe Gucci/Flex 1.4 Aut.
# codigo: 5613
# nome: 500 Cult 1.4 Flex 8V EVO Dualogic
# codigo: 5614
# nome: 500 Cult 1.4 Flex 8V EVO Mec.
# codigo: 5059
# nome: 500 LOUNGE 1.4 16V 100cv  Mec.
# codigo: 5060
# nome: 500 LOUNGE 1.4 16V 100cv Dualogic
# codigo: 5615
# nome: 500 Lounge Air 1.4/ 1.4 Flex 16V Aut.
# codigo: 5061
# nome: 500 SPORT 1.4 16V 100cv  Dualogic
# codigo: 5062
# nome: 500 SPORT 1.4 16V 100cv Mec.
# codigo: 5616
# nome: 500 Sport Air 1.4 16V/1.4 Flex 16V Aut.
# codigo: 5617
# nome: 500 Sport Air 1.4 16V/1.4 Flex Mec.
# codigo: 9584
# nome: 500e ICON (Elétrico)
# codigo: 8315
# nome: ARGO 1.0 6V Flex.
# codigo: 7965
# nome: ARGO DRIVE 1.0 6V Flex
# ...

# %%
import requests
url = 'https://parallelum.com.br/fipe/api/v1/carros/marcas/21/modelos/437/anos/'
response = requests.get(url)

dados = response.json()
print(dados)

for resultado in dados:
    print(resultado)
    ano = resultado['codigo']
    comb = resultado['nome']
    print(f'ano: {ano}')
    print(f'combustivel: {comb}')
# Out:
# {'error': 'rate limit exceeded. Please visit https://fipe.online to get a token'}
# error
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 10
#       8 for resultado in dados:
#       9     print(resultado)
# ---> 10     ano = resultado['codigo']
#      11     comb = resultado['nome']
#      12     print(f'ano: {ano}')
#
# TypeError: string indices must be integers

# %%
import requests
import json
import pandas as pd
from datetime import datetime


url = 'https://parallelum.com.br/fipe/api/v1/carros/marcas/59/modelos'
response = requests.get(url)

dados = response.json()

data_list = []

if dados:
    modelos = dados['modelos']
    for modelo in modelos:
        codigo = modelo['codigo']
        nome = modelo['nome']
        print(f"codigo: {codigo}")
        print(f"nome: {nome}")
        
        # data_list.append({
        #     'codigo':codigo,
        #     'modelo':nome
        # })
        
        # url_mod = f'https://parallelum.com.br/fipe/api/v1/carros/marcas/59/modelos/{codigo}/anos/'
        # resp = requests.get(url_mod)
        # mod_ano = resp.json()
        
        # for resultado in mod_ano:
        #     ano = resultado['codigo']
        #     comb = resultado['nome']
        #     print(f'ano do veiculo: {ano}')
        #     print(f'combustivel: {comb}')
            
        #     data_list.append({
        #         'codigo': codigo,
        #         'modelo': nome,
        #         'ano': ano,
        #         'combustivel':comb
        #     })
            

            # df = pd.DataFrame(data_list)

            # file = f'modelovw_infos_{timestamp}.txt'
            # path = '/workspaces/projeto_ing/API/app/src/car/'

            # df.to_csv(f'{path}{file}', sep=';', index=False)
            # print(f'Arquivo salvo: {file}')
            # print(f'Caminho: {path}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 15
#      12 data_list = []
#      14 if dados:
# ---> 15     modelos = dados['modelos']
#      16     for modelo in modelos:
#      17         codigo = modelo['codigo']
#
# KeyError: 'modelos'
