# %%
import os
import json
import sqlite3
import pandas as pd
import shutil
from datetime import datetime

timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
data_igtao = datetime.now().strftime('%Y-%m-%d')

caminho_backup = '/workspaces/projeto_ing/INGESTION/app/src/backp/'
ctrl_ing = "/workspaces/projeto_ing/INGESTION/app/src/archiving_ctrl/arquivo_controle.txt"
landing = '/workspaces/projeto_ing/INGESTION/app/src/landing/'
layouts = '/workspaces/projeto_ing/INGESTION/app/src/layouts/'

read_landing = os.listdir(landing)
print("Conteúdos do diretório 'landing':", read_landing)
read_layouts = os.listdir(layouts)
print("Conteúdos do diretório 'layouts':", read_layouts)
print('===============================================')

try:
    for item in read_layouts:
        accept = os.path.join(layouts, item)
        if os.path.isdir(accept):
            print('========================')
            print(f'item encontrado no diretório: {item}')
            subconteudos = os.listdir(accept)
            print('========================')
            print(f'conteudo: {subconteudos}')
            
            caminho_estrutura_json = os.path.join(accept, 'estrutura.json')
            if os.path.exists(caminho_estrutura_json):
                print(f'Encontrado estrutura.json em {item}')
                
                with open(ctrl_ing, 'r+') as controle_ingestao:
                    conteudo_load = controle_ingestao.readlines()
                    print(f'Conteúdo do arquivo de controle de ingestão: {conteudo_load}')
                    
                with open(caminho_estrutura_json, 'r') as f:
                    config_estrutura = json.load(f)
                    print("Configuração estrutura:", config_estrutura)
                    print("=======================")
                    print("Iniciando ingestão:")
                    print("=======================")
                    for estr in config_estrutura:
                        nm_arq = estr['nome_arquivo']
                        key = estr['chave']['palavra_chave']
                        banco = estr['chave']['banco']
                        tabela = estr['chave']['tabela']
                        print('=======================')
                        print(estr)
                        print(nm_arq)
                        print(key)
                        print(banco)
                        print(tabela)
                        print('=======================')
                                
                        for root, dirs, lista in os.walk(landing):
                            print(f'Procurando em {root}...')
                            for nome_arquivo in lista:
                                print(f'Verificando arquivo: {nome_arquivo}')
                                if key in nome_arquivo:
                                    caminho_completo = os.path.join(root, nome_arquivo)
                                    print(f'Arquivo contendo a chave encontrado: {caminho_completo}')
                                    
                                    sav = os.path.basename(caminho_completo)
                                    print(f'Conteúdo a gravar: {sav}')
                                    
                                    if sav + '\n' not in conteudo_load:
                                        with open(ctrl_ing, 'a') as controle_ingestao:
                                            controle_ingestao.write(f"{sav}\n")
                                            print(f'nomenclatura do arquivo salvo: {sav}')
                                            print('=================================')
                                    
                                    parte_util = sav.split('_')[1]
                                    if parte_util == key:
                                        print('Chave encontrada')
                                        print(f'Separando nome do arquivo: {parte_util}')
                                        caminho_tabela_json = os.path.join(accept, f'{tabela}.json')
                                        print(f'local para criar tabela: {caminho_tabela_json}')
                                        if os.path.exists(caminho_tabela_json):
                                            with open(caminho_tabela_json, 'r') as f:     
                                                config_colunas = json.load(f)
                                            print(config_colunas)
                                            print(f'resultado configuracao colunas: {config_colunas}')
                                            print('===============================')
                                            for j in config_colunas['colunas']:
                                                print(f'iterando config: {j}')
                                            
                                            if caminho_completo.endswith('.txt'):
                                                df = pd.read_csv(caminho_completo, delimiter=';', skiprows=[0], names=[col['nome'] for col in config_colunas['colunas'] if 'nome' in col])
                                                print(f'dados a carregar:{df}')
                                                print('estrutura de colunas txt:')
                                                print(df.columns)
                                                print('=====================')
                                            elif caminho_completo.endswith('.csv'):
                                                df = pd.read_csv(caminho_completo, skiprows=[0], names=[col['nome'] for col in config_colunas['colunas'] if 'nome' in col])
                                                print(f'dados a carregar:{df}')
                                                print('estrutura de colunas csv:')
                                                print(df.columns)
                                                print('=====================')
                                            elif caminho_completo.endswith('.bin'): 
                                                pass
                                            
                                            else:
                                                raise ValueError("Formato de arquivo não suportado")
                                            
                                            for col in config_colunas['colunas']:  
                                                if 'nome' in col and 'tipo' in col:
                                                    if col['tipo'] == 'int':
                                                        df[col['nome']] = df[col['nome']].astype(int)
                                                    elif col['tipo'] == 'float':
                                                        df[col['nome']] = df[col['nome']].astype(float)
                                                    elif col['tipo'] == 'data':
                                                        df[col['nome']] = pd.to_datetime(df[col['nome']], format=col.get('formato', None))
                                                        
                                            banco_caminho = f'/workspaces/projeto_ing/INGESTION/database/{banco}'
                                            conn = sqlite3.connect(banco_caminho)
                                            print(f'Banco de dados: {banco_caminho}')
                                            print(f'Banco de dados criado se não existir: {banco}')
                                            print(f'Conectado!')
                                            print(f"====================================")
                                            
                                            cursor = conn.cursor()
                                            nm_tb = f'tabela_{parte_util}'
                                            sql_create_table = f"CREATE TABLE IF NOT EXISTS {nm_tb} ("
                                            for col in config_colunas['colunas']:
                                                if 'nome' in col and 'tipo' in col:
                                                    sql_create_table += f"{col['nome']} {col['tipo']}, "
                                            sql_create_table = sql_create_table[:-2] + ")"
                                            cursor.execute(sql_create_table)
                                            print(f'Tabela criada: {nm_tb}')
                                            print(f'estrutura da tabela criada: {sql_create_table}')
                                            
                                            for index, row in df.iterrows():
                                                mapped_values = [row.get(col['nome'], None) for col in config_colunas['colunas'] if 'nome' in col]
                                                print("Valores mapeados:", mapped_values)
                                                sql = f"INSERT INTO {nm_tb} ({', '.join([col['nome'] for col in config_colunas['colunas'] if 'nome' in col])}) VALUES ({', '.join(['?' for _ in mapped_values])})"
                                                print("SQL:", sql)
                                                cursor.execute(sql, mapped_values)
                                        
                                            conn.commit()
                                            conn.close()
                                            print("Ingestão de dados concluída com sucesso!")
                                            print("====================================")
                                            
                                        shutil.move(caminho_completo, caminho_backup)
                                        print(f'Arquivo enviado para backup: {caminho_completo}')
                                        print(f'Destino: {caminho_backup}')
                                        print('==========================')
                                    else:
                                        print('Chave não encontrada no arquivo')
                                    break
except Exception as e:
    print(f"Erro: {e}")
# Out:
# Conteúdos do diretório 'landing': ['resultado_cepavenidamairipora_20240711_121430.txt']
# Conteúdos do diretório 'layouts': ['teste', 'cep']
# ===============================================
# ========================
# item encontrado no diretório: teste
# ========================
# conteudo: ['estrutura.json', 'tabela_teste2.json', 'tabela_teste.json']
# Encontrado estrutura.json em teste
# Conteúdo do arquivo de controle de ingestão: ['resultado_teste2_20242306_215405.txt\n', 'resultado_teste_20242506_202032.txt\n']
# Configuração estrutura: [{'nome_arquivo': 'resultado_teste_', 'descricao': 'tabela teste', 'chave': {'palavra_chave': 'teste', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste'}}, {'nome_arquivo': 'resultado_teste2_', 'descricao': 'tabela teste 2', 'chave': {'palavra_chave': 'teste2', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste2'}}]
# =======================
# Iniciando ingestão:
# =======================
# =======================
# {'nome_arquivo': 'resultado_teste_', 'descricao': 'tabela teste', 'chave': {'palavra_chave': 'teste', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste'}}
# resultado_teste_
# teste
# banco_teste.db
# tabela_teste
# =======================
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Verificando arquivo: resultado_cepavenidamairipora_20240711_121430.txt
# =======================
# {'nome_arquivo': 'resultado_teste2_', 'descricao': 'tabela teste 2', 'chave': {'palavra_chave': 'teste2', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste2'}}
# resultado_teste2_
# teste2
# banco_teste.db
# tabela_teste2
# =======================
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Verificando arquivo: resultado_cepavenidamairipora_20240711_121430.txt
# ========================
# item encontrado no diretório: cep
# ========================
# conteudo: ['estrutura.json', 'tabela_cep.json', 'tabela_cepavenidamairipora.json']
# Encontrado estrutura.json em cep
# Conteúdo do arquivo de controle de ingestão: ['resultado_teste2_20242306_215405.txt\n', 'resultado_teste_20242506_202032.txt\n']
# Configuração estrutura: [{'nome_arquivo': 'resultado_cepavenidamairipora_', 'descricao': 'descricao do cep avenida mairipora', 'chave': {'palavra_chave': 'cepavenidamairipora', 'banco': 'banco_cep.db', 'tabela': 'tabela_cepavenidamairipora'}}]
# =======================
# Iniciando ingestão:
# =======================
# =======================
# {'nome_arquivo': 'resultado_cepavenidamairipora_', 'descricao': 'descricao do cep avenida mairipora', 'chave': {'palavra_chave': 'cepavenidamairipora', 'banco': 'banco_cep.db', 'tabela': 'tabela_cepavenidamairipora'}}
# resultado_cepavenidamairipora_
# cepavenidamairipora
# banco_cep.db
# tabela_cepavenidamairipora
# =======================
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Verificando arquivo: resultado_cepavenidamairipora_20240711_121430.txt
# Arquivo contendo a chave encontrado: /workspaces/projeto_ing/INGESTION/app/src/landing/resultado_cepavenidamairipora_20240711_121430.txt
# Conteúdo a gravar: resultado_cepavenidamairipora_20240711_121430.txt
# nomenclatura do arquivo salvo: resultado_cepavenidamairipora_20240711_121430.txt
# =================================
# Chave encontrada
# Separando nome do arquivo: cepavenidamairipora
# local para criar tabela: /workspaces/projeto_ing/INGESTION/app/src/layouts/cep/tabela_cepavenidamairipora.json
# {'colunas': [{'nome': 'cep', 'tipo': 'string'}, {'nome': 'logradouro', 'tipo': 'string'}, {'nome': 'bairro', 'tipo': 'string'}, {'nome': 'localidade', 'tipo': 'string'}, {'nome': 'uf', 'tipo': 'string'}, {'nome': 'ibge', 'tipo': 'string'}, {'nome': 'gia', 'tipo': 'string'}, {'nome': 'ddd', 'tipo': 'string'}, {'nome': 'siafi', 'tipo': 'string'}]}
# resultado configuracao colunas: {'colunas': [{'nome': 'cep', 'tipo': 'string'}, {'nome': 'logradouro', 'tipo': 'string'}, {'nome': 'bairro', 'tipo': 'string'}, {'nome': 'localidade', 'tipo': 'string'}, {'nome': 'uf', 'tipo': 'string'}, {'nome': 'ibge', 'tipo': 'string'}, {'nome': 'gia', 'tipo': 'string'}, {'nome': 'ddd', 'tipo': 'string'}, {'nome': 'siafi', 'tipo': 'string'}]}
# ===============================
# iterando config: {'nome': 'cep', 'tipo': 'string'}
# iterando config: {'nome': 'logradouro', 'tipo': 'string'}
# iterando config: {'nome': 'bairro', 'tipo': 'string'}
# iterando config: {'nome': 'localidade', 'tipo': 'string'}
# iterando config: {'nome': 'uf', 'tipo': 'string'}
# iterando config: {'nome': 'ibge', 'tipo': 'string'}
# iterando config: {'nome': 'gia', 'tipo': 'string'}
# iterando config: {'nome': 'ddd', 'tipo': 'string'}
# iterando config: {'nome': 'siafi', 'tipo': 'string'}
# dados a carregar:          cep            logradouro                      bairro localidade  \
# 0   07601-345           Avenida Hum                 Olho D'Água  Mairiporã
# 1   07613-690          Avenida Rubi                 Mantiqueira  Mairiporã
# 2   07613-655          Avenida Ouro                 Mantiqueira  Mairiporã
# 3   07627-160         Avenida Berna               Luiz Fagundes  Mairiporã
# 4   07657-210         Avenida Alpes                 Mato Dentro  Mairiporã
# 5   07613-680        Avenida Safira                 Mantiqueira  Mairiporã
# 6   07631-320        Avenida Sandra                   Rio acima  Mairiporã
# 7   07634-020        Avenida Brasil                      Lavras  Mairiporã
# 8   07617-005        Avenida Acesso               Juqueri Mirim  Mairiporã
# 9   07631-570        Avenida do Sol                   Rio acima  Mairiporã
# 10  07663-080        Avenida Brasil  Jundiaizinho (Terra Preta)  Mairiporã
# 11  07613-705        Avenida Galena                 Mantiqueira  Mairiporã
# 12  07601-330        Avenida Suécia                 Olho D'Água  Mairiporã
# 13  07611-390       Avenida da Mata                    Barreiro  Mairiporã
# 14  07613-710       Avenida Quartzo                 Mantiqueira  Mairiporã
# 15  07619-028       Avenida Mariana                     Roseira  Mairiporã
# 16  07613-715        Avenida Pérola                 Mantiqueira  Mairiporã
# 17  07627-260       Avenida Zuriqui               Luiz Fagundes  Mairiporã
# 18  07657-205       Avenida Everest                 Mato Dentro  Mairiporã
# 19  07613-720       Avenida Bauxita                 Mantiqueira  Mairiporã
# 20  07602-280      Avenida Montreal                 Olho D'Água  Mairiporã
# 21  07607-515      Avenida Marginal                 São Vicente  Mairiporã
# 22  07612-860       Avenida Colônia                   Boa Vista  Mairiporã
# 23  07666-180      Avenida Nebraska       Corumbá (Terra Preta)  Mairiporã
# 24  07632-200      Avenida Marginal                   Rio acima  Mairiporã
# 25  07657-180      Avenida Himalaia                 Mato Dentro  Mairiporã
# 26  07606-090      Avenida Marginal                  Rio abaixo  Mairiporã
# 27  07664-050     Avenida das Rosas  Jundiaizinho (Terra Preta)  Mairiporã
# 28  07621-885     Avenida das Rosas                   Caraguatá  Mairiporã
# 29  07663-090      Avenida Brasília  Jundiaizinho (Terra Preta)  Mairiporã
# 30  07604-605     Avenida Maranduba                      Caceia  Mairiporã
# 31  07619-188     Avenida dos Rubis                     Roseira  Mairiporã
# 32  07664-110     Avenida Espraiada  Jundiaizinho (Terra Preta)  Mairiporã
# 33  07613-660     Avenida Esmeralda                 Mantiqueira  Mairiporã
# 34  07625-480     Avenida Cancelata               Luiz Fagundes  Mairiporã
# 35  07664-495    Avenida Flamboyant  Jundiaizinho (Terra Preta)  Mairiporã
# 36  07618-862     Avenida São Paulo                     Roseira  Mairiporã
# 37  07619-200    Avenida dos Cedros                     Roseira  Mairiporã
# 38  07619-236    Avenida Pau Marfim                     Roseira  Mairiporã
# 39  07601-050    Avenida Beira Lago                 Olho D'Água  Mairiporã
# 40  07619-024    Avenida Ouro Preto                     Roseira  Mairiporã
# 41  07619-444    Avenida dos Bambus                     Roseira  Mairiporã
# 42  07620-120     Avenida Caraguatá                     Cumbari  Mairiporã
# 43  07620-100    Avenida Campo Baio                     Cumbari  Mairiporã
# 44  07664-070    Avenida dos Cravos  Jundiaizinho (Terra Preta)  Mairiporã
# 45  07664-083   Avenida das Tulipas  Jundiaizinho (Terra Preta)  Mairiporã
# 46  07629-004   Avenida Neli Ladeia                  Capoavinha  Mairiporã
# 47  07619-224   Avenida dos Angicos                     Roseira  Mairiporã
# 48  07619-460  Avenida das Caviunas                     Roseira  Mairiporã
# 49  07611-015  Avenida Serra Morena                    Barreiro  Mairiporã
#
#     uf     ibge   gia  ddd  siafi
# 0   SP  3528502  4339   11   6671
# 1   SP  3528502  4339   11   6671
# 2   SP  3528502  4339   11   6671
# 3   SP  3528502  4339   11   6671
# 4   SP  3528502  4339   11   6671
# 5   SP  3528502  4339   11   6671
# 6   SP  3528502  4339   11   6671
# 7   SP  3528502  4339   11   6671
# 8   SP  3528502  4339   11   6671
# 9   SP  3528502  4339   11   6671
# 10  SP  3528502  4339   11   6671
# 11  SP  3528502  4339   11   6671
# 12  SP  3528502  4339   11   6671
# 13  SP  3528502  4339   11   6671
# 14  SP  3528502  4339   11   6671
# 15  SP  3528502  4339   11   6671
# 16  SP  3528502  4339   11   6671
# 17  SP  3528502  4339   11   6671
# 18  SP  3528502  4339   11   6671
# 19  SP  3528502  4339   11   6671
# 20  SP  3528502  4339   11   6671
# 21  SP  3528502  4339   11   6671
# 22  SP  3528502  4339   11   6671
# 23  SP  3528502  4339   11   6671
# 24  SP  3528502  4339   11   6671
# 25  SP  3528502  4339   11   6671
# 26  SP  3528502  4339   11   6671
# 27  SP  3528502  4339   11   6671
# 28  SP  3528502  4339   11   6671
# 29  SP  3528502  4339   11   6671
# 30  SP  3528502  4339   11   6671
# 31  SP  3528502  4339   11   6671
# 32  SP  3528502  4339   11   6671
# 33  SP  3528502  4339   11   6671
# 34  SP  3528502  4339   11   6671
# 35  SP  3528502  4339   11   6671
# 36  SP  3528502  4339   11   6671
# 37  SP  3528502  4339   11   6671
# 38  SP  3528502  4339   11   6671
# 39  SP  3528502  4339   11   6671
# 40  SP  3528502  4339   11   6671
# 41  SP  3528502  4339   11   6671
# 42  SP  3528502  4339   11   6671
# 43  SP  3528502  4339   11   6671
# 44  SP  3528502  4339   11   6671
# 45  SP  3528502  4339   11   6671
# 46  SP  3528502  4339   11   6671
# 47  SP  3528502  4339   11   6671
# 48  SP  3528502  4339   11   6671
# 49  SP  3528502  4339   11   6671
# estrutura de colunas txt:
# Index(['cep', 'logradouro', 'bairro', 'localidade', 'uf', 'ibge', 'gia', 'ddd',
#        'siafi'],
#       dtype='object')
# =====================
# Banco de dados: /workspaces/projeto_ing/INGESTION/database/banco_cep.db
# Banco de dados criado se não existir: banco_cep.db
# Conectado!
# ====================================
# Tabela criada: tabela_cepavenidamairipora
# estrutura da tabela criada: CREATE TABLE IF NOT EXISTS tabela_cepavenidamairipora (cep string, logradouro string, bairro string, localidade string, uf string, ibge string, gia string, ddd string, siafi string)
# Valores mapeados: ['07601-345', 'Avenida Hum', "Olho D'Água", 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07613-690', 'Avenida Rubi', 'Mantiqueira', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07613-655', 'Avenida Ouro', 'Mantiqueira', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07627-160', 'Avenida Berna', 'Luiz Fagundes', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07657-210', 'Avenida Alpes', 'Mato Dentro', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07613-680', 'Avenida Safira', 'Mantiqueira', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07631-320', 'Avenida Sandra', 'Rio acima', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07634-020', 'Avenida Brasil', 'Lavras', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07617-005', 'Avenida Acesso', 'Juqueri Mirim', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07631-570', 'Avenida do Sol', 'Rio acima', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07663-080', 'Avenida Brasil', 'Jundiaizinho (Terra Preta)', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07613-705', 'Avenida Galena', 'Mantiqueira', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07601-330', 'Avenida Suécia', "Olho D'Água", 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07611-390', 'Avenida da Mata', 'Barreiro', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07613-710', 'Avenida Quartzo', 'Mantiqueira', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07619-028', 'Avenida Mariana', 'Roseira', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07613-715', 'Avenida Pérola', 'Mantiqueira', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07627-260', 'Avenida Zuriqui', 'Luiz Fagundes', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07657-205', 'Avenida Everest', 'Mato Dentro', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07613-720', 'Avenida Bauxita', 'Mantiqueira', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07602-280', 'Avenida Montreal', "Olho D'Água", 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07607-515', 'Avenida Marginal', 'São Vicente', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07612-860', 'Avenida Colônia', 'Boa Vista', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07666-180', 'Avenida Nebraska', 'Corumbá (Terra Preta)', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07632-200', 'Avenida Marginal', 'Rio acima', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07657-180', 'Avenida Himalaia', 'Mato Dentro', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07606-090', 'Avenida Marginal', 'Rio abaixo', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07664-050', 'Avenida das Rosas', 'Jundiaizinho (Terra Preta)', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07621-885', 'Avenida das Rosas', 'Caraguatá', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07663-090', 'Avenida Brasília', 'Jundiaizinho (Terra Preta)', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07604-605', 'Avenida Maranduba', 'Caceia', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07619-188', 'Avenida dos Rubis', 'Roseira', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07664-110', 'Avenida Espraiada', 'Jundiaizinho (Terra Preta)', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07613-660', 'Avenida Esmeralda', 'Mantiqueira', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07625-480', 'Avenida Cancelata', 'Luiz Fagundes', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07664-495', 'Avenida Flamboyant', 'Jundiaizinho (Terra Preta)', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07618-862', 'Avenida São Paulo', 'Roseira', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07619-200', 'Avenida dos Cedros', 'Roseira', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07619-236', 'Avenida Pau Marfim', 'Roseira', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07601-050', 'Avenida Beira Lago', "Olho D'Água", 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07619-024', 'Avenida Ouro Preto', 'Roseira', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07619-444', 'Avenida dos Bambus', 'Roseira', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07620-120', 'Avenida Caraguatá', 'Cumbari', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07620-100', 'Avenida Campo Baio', 'Cumbari', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07664-070', 'Avenida dos Cravos', 'Jundiaizinho (Terra Preta)', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07664-083', 'Avenida das Tulipas', 'Jundiaizinho (Terra Preta)', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07629-004', 'Avenida Neli Ladeia', 'Capoavinha', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07619-224', 'Avenida dos Angicos', 'Roseira', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07619-460', 'Avenida das Caviunas', 'Roseira', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Valores mapeados: ['07611-015', 'Avenida Serra Morena', 'Barreiro', 'Mairiporã', 'SP', 3528502, 4339, 11, 6671]
# SQL: INSERT INTO tabela_cepavenidamairipora (cep, logradouro, bairro, localidade, uf, ibge, gia, ddd, siafi) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# Ingestão de dados concluída com sucesso!
# ====================================
# Arquivo enviado para backup: /workspaces/projeto_ing/INGESTION/app/src/landing/resultado_cepavenidamairipora_20240711_121430.txt
# Destino: /workspaces/projeto_ing/INGESTION/app/src/backp/
# ==========================

# %%
import os
import json
import sqlite3
import pandas as pd
import shutil
from datetime import datetime

timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
data_igtao = datetime.now().strftime('%Y-%m-%d')

caminho_backup = '/workspaces/projeto_ing/INGESTION/app/src/backp/'
ctrl_ing = "/workspaces/projeto_ing/INGESTION/app/src/archiving_ctrl/arquivo_controle.txt"
landing = '/workspaces/projeto_ing/INGESTION/app/src/landing/'
layouts = '/workspaces/projeto_ing/INGESTION/app/src/layouts/'

read_landing = os.listdir(landing)
print("Conteúdos do diretório 'landing':", read_landing)
read_layouts = os.listdir(layouts)
print("Conteúdos do diretório 'layouts':", read_layouts)
print('===============================================')

try:
    for item in read_layouts:
        accept = os.path.join(layouts, item)
        if os.path.isdir(accept):
            print('========================')
            print(f'item encontrado no diretório: {item}')
            subconteudos = os.listdir(accept)
            print('========================')
            print(f'conteudo: {subconteudos}')
            
            caminho_estrutura_json = os.path.join(accept, 'estrutura.json')
            if os.path.exists(caminho_estrutura_json):
                print(f'Encontrado estrutura.json em {item}')
                
                with open(ctrl_ing, 'r+') as controle_ingestao:
                    conteudo_load = controle_ingestao.readlines()
                    print(f'Conteúdo do arquivo de controle de ingestão: {conteudo_load}')
                    
                with open(caminho_estrutura_json, 'r') as f:
                    config_estrutura = json.load(f)
                    print("Configuração estrutura:", config_estrutura)
                    print("=======================")
                    print("Iniciando ingestão:")
                    print("=======================")
                    for estr in config_estrutura:
                        nm_arq = estr['nome_arquivo']
                        key = estr['chave']['palavra_chave']
                        banco = estr['chave']['banco']
                        tabela = estr['chave']['tabela']
                        print('=======================')
                        print(estr)
                        print(nm_arq)
                        print(key)
                        print(banco)
                        print(tabela)
                        print('=======================')
                                
                        for root, dirs, lista in os.walk(landing):
                            print(f'Procurando em {root}...')
                            for nome_arquivo in lista:
                                print(f'Verificando arquivo: {nome_arquivo}')
                                if key in nome_arquivo:
                                    caminho_completo = os.path.join(root, nome_arquivo)
                                    print(f'Arquivo contendo a chave encontrado: {caminho_completo}')
                                    
                                    sav = os.path.basename(caminho_completo)
                                    print(f'Conteúdo a gravar: {sav}')
                                    
                                    if sav + '\n' not in conteudo_load:
                                        with open(ctrl_ing, 'a') as controle_ingestao:
                                            controle_ingestao.write(f"{sav}\n")
                                            print(f'nomenclatura do arquivo salvo: {sav}')
                                            print('=================================')
                                    
                                    parte_util = sav.split('_')[1]
                                    if parte_util == key:
                                        print('Chave encontrada')
                                        print(f'Separando nome do arquivo: {parte_util}')
                                        caminho_tabela_json = os.path.join(accept, f'{tabela}.json')
                                        print(f'local para criar tabela: {caminho_tabela_json}')
                                        if os.path.exists(caminho_tabela_json):
                                            with open(caminho_tabela_json, 'r') as f:     
                                                config_colunas = json.load(f)
                                            print(config_colunas)
                                            print(f'resultado configuracao colunas: {config_colunas}')
                                            print('===============================')
                                            for j in config_colunas['colunas']:
                                                print(f'iterando config: {j}')
                                            
                                            if caminho_completo.endswith('.txt'):
                                                df = pd.read_csv(caminho_completo, delimiter=';', skiprows=[0], names=[col['nome'] for col in config_colunas['colunas'] if 'nome' in col])
                                                print(f'dados a carregar:{df}')
                                                print('estrutura de colunas txt:')
                                                print(df.columns)
                                                print('=====================')
                                            elif caminho_completo.endswith('.csv'):
                                                df = pd.read_csv(caminho_completo, skiprows=[0], names=[col['nome'] for col in config_colunas['colunas'] if 'nome' in col])
                                                print(f'dados a carregar:{df}')
                                                print('estrutura de colunas csv:')
                                                print(df.columns)
                                                print('=====================')
                                            elif caminho_completo.endswith('.bin'): 
                                                pass
                                            
                                            else:
                                                raise ValueError("Formato de arquivo não suportado")
                                            
                                            for col in config_colunas['colunas']:  
                                                if 'nome' in col and 'tipo' in col:
                                                    if col['tipo'] == 'int':
                                                        df[col['nome']] = df[col['nome']].astype(int)
                                                    elif col['tipo'] == 'float':
                                                        df[col['nome']] = df[col['nome']].astype(float)
                                                    elif col['tipo'] == 'data':
                                                        df[col['nome']] = pd.to_datetime(df[col['nome']], format=col.get('formato', None))
                                                        
                                            banco_caminho = f'/workspaces/projeto_ing/INGESTION/database/{banco}'
                                            conn = sqlite3.connect(banco_caminho)
                                            print(f'Banco de dados: {banco_caminho}')
                                            print(f'Banco de dados criado se não existir: {banco}')
                                            print(f'Conectado!')
                                            print(f"====================================")
                                            
                                            cursor = conn.cursor()
                                            nm_tb = f'tabela_{parte_util}'
                                            sql_create_table = f"CREATE TABLE IF NOT EXISTS {nm_tb} ("
                                            for col in config_colunas['colunas']:
                                                if 'nome' in col and 'tipo' in col:
                                                    sql_create_table += f"{col['nome']} {col['tipo']}, "
                                            sql_create_table = sql_create_table[:-2] + ")"
                                            cursor.execute(sql_create_table)
                                            print(f'Tabela criada: {nm_tb}')
                                            print(f'estrutura da tabela criada: {sql_create_table}')
                                            
                                            for index, row in df.iterrows():
                                                mapped_values = [row.get(col['nome'], None) for col in config_colunas['colunas'] if 'nome' in col]
                                                print("Valores mapeados:", mapped_values)
                                                sql = f"INSERT INTO {nm_tb} ({', '.join([col['nome'] for col in config_colunas['colunas'] if 'nome' in col])}) VALUES ({', '.join(['?' for _ in mapped_values])})"
                                                print("SQL:", sql)
                                                cursor.execute(sql, mapped_values)
                                        
                                            conn.commit()
                                            conn.close()
                                            print("Ingestão de dados concluída com sucesso!")
                                            print("====================================")
                                            
                                        shutil.move(caminho_completo, caminho_backup)
                                        print(f'Arquivo enviado para backup: {caminho_completo}')
                                        print(f'Destino: {caminho_backup}')
                                        print('==========================')
                                    else:
                                        print('Chave não encontrada no arquivo')
                                    break
except Exception as e:
    print(f"Erro: {e}")
# Out:
# Conteúdos do diretório 'landing': ['resultado_CepAvenidaMairipora_20240711_121430.txt']
# Conteúdos do diretório 'layouts': ['teste', 'cep']
# ===============================================
# ========================
# item encontrado no diretório: teste
# ========================
# conteudo: ['estrutura.json', 'tabela_teste2.json', 'tabela_teste.json']
# Encontrado estrutura.json em teste
# Conteúdo do arquivo de controle de ingestão: ['resultado_teste2_20242306_215405.txt\n', 'resultado_teste_20242506_202032.txt\n']
# Configuração estrutura: [{'nome_arquivo': 'resultado_teste_', 'descricao': 'tabela teste', 'chave': {'palavra_chave': 'teste', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste'}}, {'nome_arquivo': 'resultado_teste2_', 'descricao': 'tabela teste 2', 'chave': {'palavra_chave': 'teste2', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste2'}}]
# =======================
# Iniciando ingestão:
# =======================
# =======================
# {'nome_arquivo': 'resultado_teste_', 'descricao': 'tabela teste', 'chave': {'palavra_chave': 'teste', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste'}}
# resultado_teste_
# teste
# banco_teste.db
# tabela_teste
# =======================
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Verificando arquivo: resultado_CepAvenidaMairipora_20240711_121430.txt
# =======================
# {'nome_arquivo': 'resultado_teste2_', 'descricao': 'tabela teste 2', 'chave': {'palavra_chave': 'teste2', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste2'}}
# resultado_teste2_
# teste2
# banco_teste.db
# tabela_teste2
# =======================
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Verificando arquivo: resultado_CepAvenidaMairipora_20240711_121430.txt
# ========================
# item encontrado no diretório: cep
# ========================
# conteudo: ['estrutura.json', 'tabela_cep.json']
# Encontrado estrutura.json em cep
# Conteúdo do arquivo de controle de ingestão: ['resultado_teste2_20242306_215405.txt\n', 'resultado_teste_20242506_202032.txt\n']
# Configuração estrutura: [{'nome_arquivo': 'resultado_CepAvenidaMairipora_', 'descricao': 'descricao do cep avenida mairipora', 'chave': {'palavra_chave': 'CepAvenidaMairipora', 'banco': 'banco_cep.db', 'tabela': 'tabela_CepAvenidaMairipora'}}]
# =======================
# Iniciando ingestão:
# =======================
# =======================
# {'nome_arquivo': 'resultado_CepAvenidaMairipora_', 'descricao': 'descricao do cep avenida mairipora', 'chave': {'palavra_chave': 'CepAvenidaMairipora', 'banco': 'banco_cep.db', 'tabela': 'tabela_CepAvenidaMairipora'}}
# resultado_CepAvenidaMairipora_
# CepAvenidaMairipora
# banco_cep.db
# tabela_CepAvenidaMairipora
# =======================
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Verificando arquivo: resultado_CepAvenidaMairipora_20240711_121430.txt
# Arquivo contendo a chave encontrado: /workspaces/projeto_ing/INGESTION/app/src/landing/resultado_CepAvenidaMairipora_20240711_121430.txt
# Conteúdo a gravar: resultado_CepAvenidaMairipora_20240711_121430.txt
# nomenclatura do arquivo salvo: resultado_CepAvenidaMairipora_20240711_121430.txt
# =================================
# Chave encontrada
# Separando nome do arquivo: CepAvenidaMairipora
# local para criar tabela: /workspaces/projeto_ing/INGESTION/app/src/layouts/cep/tabela_CepAvenidaMairipora.json
# Arquivo enviado para backup: /workspaces/projeto_ing/INGESTION/app/src/landing/resultado_CepAvenidaMairipora_20240711_121430.txt
# Destino: /workspaces/projeto_ing/INGESTION/app/src/backp/
# ==========================

# %%
import os
import json
import sqlite3
import pandas as pd
import shutil
from datetime import datetime

timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
data_igtao = datetime.now().strftime('%Y-%m-%d')

caminho_backup = '/workspaces/projeto_ing/INGESTION/app/src/backp/'
ctrl_ing = "/workspaces/projeto_ing/INGESTION/app/src/archiving_ctrl/arquivo_controle.txt"
landing = '/workspaces/projeto_ing/INGESTION/app/src/landing/'
layouts = '/workspaces/projeto_ing/INGESTION/app/src/layouts/'

read_landing = os.listdir(landing)
print("Conteúdos do diretório 'landing':", read_landing)
read_layouts = os.listdir(layouts)
print("Conteúdos do diretório 'layouts':", read_layouts)
print('===============================================')

try:
    for item in read_layouts:
        accept = os.path.join(layouts, item)
        if os.path.isdir(accept):
            print('========================')
            print(f'item encontrado no diretório: {item}')
            subconteudos = os.listdir(accept)
            print('========================')
            print(f'conteudo: {subconteudos}')
            
            caminho_estrutura_json = os.path.join(accept, 'estrutura.json')
            if os.path.exists(caminho_estrutura_json):
                print(f'Encontrado estrutura.json em {item}')
                
                with open(ctrl_ing, 'r+') as controle_ingestao:
                    conteudo_load = controle_ingestao.readlines()
                    print(f'Conteúdo do arquivo de controle de ingestão: {conteudo_load}')
                    
                with open(caminho_estrutura_json, 'r') as f:
                    config_estrutura = json.load(f)
                    print("Configuração estrutura:", config_estrutura)
                    print("=======================")
                    print("Iniciando ingestão:")
                    print("=======================")
                    for estr in config_estrutura:
                        nm_arq = estr['nome_arquivo']
                        key = estr['chave']['palavra_chave']
                        banco = estr['chave']['banco']
                        tabela = estr['chave']['tabela']
                        print('=======================')
                        print(estr)
                        print(nm_arq)
                        print(key)
                        print(banco)
                        print(tabela)
                        print('=======================')
                                
                        for root, dirs, lista in os.walk(landing):
                            print(f'Procurando em {root}...')
                            for nome_arquivo in lista:
                                print(f'Verificando arquivo: {nome_arquivo}')
                                if key in nome_arquivo:
                                    caminho_completo = os.path.join(root, nome_arquivo)
                                    print(f'Arquivo contendo a chave encontrado: {caminho_completo}')
                                    
                                    sav = os.path.basename(caminho_completo)
                                    print(f'Conteúdo a gravar: {sav}')
                                    
                                    if sav + '\n' not in conteudo_load:
                                        with open(ctrl_ing, 'a') as controle_ingestao:
                                            controle_ingestao.write(f"{sav}\n")
                                            print(f'nomenclatura do arquivo salvo: {sav}')
                                            print('=================================')
                                    
                                    parte_util = sav.split('_')[1]
                                    if parte_util == key:
                                        print('Chave encontrada')
                                        print(f'Separando nome do arquivo: {parte_util}')
                                        caminho_tabela_json = os.path.join(accept, f'{tabela}.json')
                                        print(f'local para criar tabela: {caminho_tabela_json}')
                                        if os.path.exists(caminho_tabela_json):
                                            with open(caminho_tabela_json, 'r') as f:     
                                                config_colunas = json.load(f)
                                            print(config_colunas)
                                            print(f'resultado configuracao colunas: {config_colunas}')
                                            print('===============================')
                                            for j in config_colunas['colunas']:
                                                print(f'iterando config: {j}')
                                            
                                            if caminho_completo.endswith('.txt'):
                                                df = pd.read_csv(caminho_completo, delimiter=';', skiprows=[0], names=[col['nome'] for col in config_colunas['colunas'] if 'nome' in col])
                                                print(f'dados a carregar:{df}')
                                                print('estrutura de colunas txt:')
                                                print(df.columns)
                                                print('=====================')
                                            elif caminho_completo.endswith('.csv'):
                                                df = pd.read_csv(caminho_completo, skiprows=[0], names=[col['nome'] for col in config_colunas['colunas'] if 'nome' in col])
                                                print(f'dados a carregar:{df}')
                                                print('estrutura de colunas csv:')
                                                print(df.columns)
                                                print('=====================')
                                            elif caminho_completo.endswith('.bin'): 
                                                pass
                                            
                                            else:
                                                raise ValueError("Formato de arquivo não suportado")
                                            
                                            for col in config_colunas['colunas']:  
                                                if 'nome' in col and 'tipo' in col:
                                                    if col['tipo'] == 'int':
                                                        df[col['nome']] = df[col['nome']].astype(int)
                                                    elif col['tipo'] == 'float':
                                                        df[col['nome']] = df[col['nome']].astype(float)
                                                    elif col['tipo'] == 'data':
                                                        df[col['nome']] = pd.to_datetime(df[col['nome']], format=col.get('formato', None))
                                                        
                                            banco_caminho = f'/workspaces/projeto_ing/INGESTION/database/{banco}'
                                            conn = sqlite3.connect(banco_caminho)
                                            print(f'Banco de dados: {banco_caminho}')
                                            print(f'Banco de dados criado se não existir: {banco}')
                                            print(f'Conectado!')
                                            print(f"====================================")
                                            
                                            cursor = conn.cursor()
                                            nm_tb = f'tabela_{parte_util}'
                                            sql_create_table = f"CREATE TABLE IF NOT EXISTS {nm_tb} ("
                                            for col in config_colunas['colunas']:
                                                if 'nome' in col and 'tipo' in col:
                                                    sql_create_table += f"{col['nome']} {col['tipo']}, "
                                            sql_create_table = sql_create_table[:-2] + ")"
                                            cursor.execute(sql_create_table)
                                            print(f'Tabela criada: {nm_tb}')
                                            print(f'estrutura da tabela criada: {sql_create_table}')
                                            
                                            for index, row in df.iterrows():
                                                mapped_values = [row.get(col['nome'], None) for col in config_colunas['colunas'] if 'nome' in col]
                                                print("Valores mapeados:", mapped_values)
                                                sql = f"INSERT INTO {nm_tb} ({', '.join([col['nome'] for col in config_colunas['colunas'] if 'nome' in col])}) VALUES ({', '.join(['?' for _ in mapped_values])})"
                                                print("SQL:", sql)
                                                cursor.execute(sql, mapped_values)
                                        
                                            conn.commit()
                                            conn.close()
                                            print("Ingestão de dados concluída com sucesso!")
                                        
                                        shutil.move(caminho_completo, caminho_backup)
                                        print(f'Arquivo enviado para backup: {caminho_completo}')
                                        print(f'Destino: {caminho_backup}')
                                        print('==========================')
                                    else:
                                        print('Chave não encontrada no arquivo')
                                    break
except Exception as e:
    print(f"Erro: {e}")
# Out:
# Conteúdos do diretório 'landing': ['resultado_CepAvenidaMairipora_20240711_121430.txt']
# Conteúdos do diretório 'layouts': ['teste', 'cep']
# ===============================================
# ========================
# item encontrado no diretório: teste
# ========================
# conteudo: ['estrutura.json', 'tabela_teste2.json', 'tabela_teste.json']
# Encontrado estrutura.json em teste
# Conteúdo do arquivo de controle de ingestão: ['resultado_teste2_20242306_215405.txt\n', 'resultado_teste_20242506_202032.txt\n']
# Configuração estrutura: [{'nome_arquivo': 'resultado_teste_', 'descricao': 'tabela teste', 'chave': {'palavra_chave': 'teste', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste'}}, {'nome_arquivo': 'resultado_teste2_', 'descricao': 'tabela teste 2', 'chave': {'palavra_chave': 'teste2', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste2'}}]
# =======================
# Iniciando ingestão:
# =======================
# =======================
# {'nome_arquivo': 'resultado_teste_', 'descricao': 'tabela teste', 'chave': {'palavra_chave': 'teste', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste'}}
# resultado_teste_
# teste
# banco_teste.db
# tabela_teste
# =======================
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Verificando arquivo: resultado_CepAvenidaMairipora_20240711_121430.txt
# =======================
# {'nome_arquivo': 'resultado_teste2_', 'descricao': 'tabela teste 2', 'chave': {'palavra_chave': 'teste2', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste2'}}
# resultado_teste2_
# teste2
# banco_teste.db
# tabela_teste2
# =======================
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Verificando arquivo: resultado_CepAvenidaMairipora_20240711_121430.txt
# ========================
# item encontrado no diretório: cep
# ========================
# conteudo: ['estrutura.json', 'tabela_cep.json']
# Encontrado estrutura.json em cep
# Conteúdo do arquivo de controle de ingestão: ['resultado_teste2_20242306_215405.txt\n', 'resultado_teste_20242506_202032.txt\n']
# Configuração estrutura: [{'nome_arquivo': 'resultado_CepAvenidaMairipora_', 'descricao': 'descricao do cep avenida mairipora', 'chave': {'palavra_chave': 'CepAvenidaMairipora', 'banco': 'banco_cep.db', 'tabela': 'tabela_CepAvenidaMairipora'}}]
# =======================
# Iniciando ingestão:
# =======================
# =======================
# {'nome_arquivo': 'resultado_CepAvenidaMairipora_', 'descricao': 'descricao do cep avenida mairipora', 'chave': {'palavra_chave': 'CepAvenidaMairipora', 'banco': 'banco_cep.db', 'tabela': 'tabela_CepAvenidaMairipora'}}
# resultado_CepAvenidaMairipora_
# CepAvenidaMairipora
# banco_cep.db
# tabela_CepAvenidaMairipora
# =======================
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Verificando arquivo: resultado_CepAvenidaMairipora_20240711_121430.txt
# Arquivo contendo a chave encontrado: /workspaces/projeto_ing/INGESTION/app/src/landing/resultado_CepAvenidaMairipora_20240711_121430.txt
# Conteúdo a gravar: resultado_CepAvenidaMairipora_20240711_121430.txt
# nomenclatura do arquivo salvo: resultado_CepAvenidaMairipora_20240711_121430.txt
# =================================
# Chave encontrada
# Separando nome do arquivo: CepAvenidaMairipora
# local para criar tabela: /workspaces/projeto_ing/INGESTION/app/src/layouts/cep/tabela_CepAvenidaMairipora.json
# Arquivo enviado para backup: /workspaces/projeto_ing/INGESTION/app/src/landing/resultado_CepAvenidaMairipora_20240711_121430.txt
# Destino: /workspaces/projeto_ing/INGESTION/app/src/backp/
# ==========================

# %%
import os
import json
import sqlite3
import pandas as pd
import shutil
from datetime import datetime

timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
data_igtao = datetime.now().strftime('%Y-%m-%d')

caminho_backup = '/workspaces/projeto_ing/INGESTION/app/src/backp/'
ctrl_ing = "/workspaces/projeto_ing/INGESTION/app/src/archiving_ctrl/arquivo_controle.txt"
landing = '/workspaces/projeto_ing/INGESTION/app/src/landing/'
layouts = '/workspaces/projeto_ing/INGESTION/app/src/layouts/'

read_landing = os.listdir(landing)
print("Conteúdos do diretório 'landing':", read_landing)
read_layouts = os.listdir(layouts)
print("Conteúdos do diretório 'layouts':", read_layouts)
print('===============================================')

try:
    for item in read_layouts:
        accept = os.path.join(layouts, item)
        if os.path.isdir(accept):
            print('========================')
            print(f'item encontrado no diretório: {item}')
            subconteudos = os.listdir(accept)
            print('========================')
            print(f' conteudo: {subconteudos}')
            
            caminho_estrutura_json = os.path.join(accept, 'estrutura.json')
            if os.path.exists(caminho_estrutura_json):
                print(f'Encontrado estrutura.json em {item}')
                
                with open(ctrl_ing, 'r+') as controle_ingestao:
                    conteudo_load = controle_ingestao.readlines()
                    print(f'Conteúdo do arquivo de controle de ingestão: {conteudo_load}')
                    
                with open(caminho_estrutura_json, 'r') as f:
                    config_estrutura = json.load(f)
                    print("Configuração estrutura:", config_estrutura)
                    print("=======================")
                    print("Iniciando ingestão:")
                    print("=======================")
                    for estr in config_estrutura:
                        nm_arq = estr['nome_arquivo']
                        key = estr['chave']['palavra_chave']
                        banco = estr['chave']['banco']
                        tabela = estr['chave']['tabela']
                        print('=======================')
                        print(estr)
                        print(nm_arq)
                        print(key)
                        print(banco)
                        print(tabela)
                        print('=======================')
                        
                        for root, dirs, lista in os.walk(landing):
                            print(f'Procurando em {root}...')
                            for nome_arquivo in lista:
                                print(f'Verificando arquivo: {nome_arquivo}')
                                if key in nome_arquivo:
                                    caminho_completo = os.path.join(root, nome_arquivo)
                                    print(f'Arquivo contendo a chave encontrado: {caminho_completo}')
                                    sav = os.path.basename(caminho_completo)
                                    print(f'Conteúdo a gravar: {sav}')
                                    
                                    if sav + '\n' not in conteudo_load:
                                        with open(ctrl_ing, 'a') as controle_ingestao:
                                            controle_ingestao.write(f"{sav}\n")
                                            print(f'nomenclatura do arquivo salvo: {sav}')
                                            print('=================================')
                                            
                                    parte_util = sav.split('_')[1]
                                    if parte_util == key:
                                        print('Chave encontrada')
                                        print(f'Separando nome do arquivo: {parte_util}')
                                        caminho_tabela_json = os.path.join(accept, f'{tabela}.json')
                                        print(f'local para criar tabela: {caminho_tabela_json}')
                                        if os.path.exists(caminho_tabela_json):
                                            with open(caminho_tabela_json, 'r') as f:     
                                                config_colunas = json.load(f)
                                            print(config_colunas)
                                            print(f'resultado configuracao colunas: {config_colunas}')
                                            print('===============================')
                                            for j in config_colunas['colunas']:
                                                print(f'iterando config: {j}')
                                            
                                            if caminho_completo.endswith('.txt'):
                                                df = pd.read_csv(caminho_completo, delimiter=';', skiprows=[0], names=[col['nome'] for col in config_colunas['colunas'] if 'nome' in col])
                                                print(f'dados a carregar:{df}')
                                                print('estrutura de colunas txt:')
                                                print(df.columns)
                                                print('=====================')
                                            elif caminho_completo.endswith('.csv'):
                                                df = pd.read_csv(caminho_completo, skiprows=[0], names=[col['nome'] for col in config_colunas['colunas'] if 'nome' in col])
                                                print(f'dados a carregar:{df}')
                                                print('estrutura de colunas csv:')
                                                print(df.columns)
                                                print('=====================')
                                            elif caminho_completo.endswith('.bin'): 
                                                pass
                                            
                                            else:
                                                raise ValueError("Formato de arquivo não suportado")
                                            
                                            for col in config_colunas['colunas']:  
                                                if 'nome' in col and 'tipo' in col:
                                                    if col['tipo'] == 'int':
                                                        df[col['nome']] = df[col['nome']].astype(int)
                                                    elif col['tipo'] == 'float':
                                                        df[col['nome']] = df[col['nome']].astype(float)
                                                    elif col['tipo'] == 'data':
                                                        df[col['nome']] = pd.to_datetime(df[col['nome']], format=col.get('formato', None))
                                                        
                                            banco_caminho = f'/workspaces/projeto_ing/INGESTION/database/{banco}'
                                            conn = sqlite3.connect(banco_caminho)
                                            print(f'Banco de dados: {banco_caminho}')
                                            print(f'Banco de dados criado se não existir: {banco}')
                                            print(f'Conectado!')
                                            print(f"====================================")
                                            
                                            cursor = conn.cursor()
                                            nm_tb = f'tabela_{parte_util}'
                                            sql_create_table = f"CREATE TABLE IF NOT EXISTS {nm_tb} ("
                                            for col in config_colunas['colunas']:
                                                if 'nome' in col and 'tipo' in col:
                                                    sql_create_table += f"{col['nome']} {col['tipo']}, "
                                            sql_create_table = sql_create_table[:-2] + ")"
                                            cursor.execute(sql_create_table)
                                            print(f'Tabela criada: {nm_tb}')
                                            print(f'estrutura da tabela criada: {sql_create_table}')
                                            
                                            for index, row in df.iterrows():
                                                mapped_values = [row.get(col['nome'], None) for col in config_colunas['colunas'] if 'nome' in col]
                                                print("Valores mapeados:", mapped_values)
                                                sql = f"INSERT INTO {nm_tb} ({', '.join([col['nome'] for col in config_colunas['colunas'] if 'nome' in col])}) VALUES ({', '.join(['?' for _ in mapped_values])})"
                                                print("SQL:", sql)
                                                cursor.execute(sql, mapped_values)
                                        
                                            conn.commit()
                                            conn.close()
                                            print("Ingestão de dados concluída com sucesso!")
                                        
                                        shutil.move(caminho_completo, caminho_backup)
                                        print(f'Arquivo enviado para backup: {caminho_completo}')
                                        print(f'Destino: {caminho_backup}')
                                        print('==========================')
                                    else:
                                        print('Chave não encontrada no arquivo')
except Exception as e:
    print(f"Erro: {e}")
# Out:
# Conteúdos do diretório 'landing': ['resultado_CepAvenidaMairipora_20240711_121430.txt']
# Conteúdos do diretório 'layouts': ['teste', 'cep']
# ===============================================
# ========================
# item encontrado no diretório: teste
# ========================
#  conteudo: ['estrutura.json', 'tabela_teste2.json', 'tabela_teste.json']
# Encontrado estrutura.json em teste
# Conteúdo do arquivo de controle de ingestão: ['resultado_teste2_20242306_215405.txt\n', 'resultado_teste_20242506_202032.txt\n']
# Configuração estrutura: [{'nome_arquivo': 'resultado_teste_', 'descricao': 'tabela teste', 'chave': {'palavra_chave': 'teste', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste'}}, {'nome_arquivo': 'resultado_teste2_', 'descricao': 'tabela teste 2', 'chave': {'palavra_chave': 'teste2', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste2'}}]
# =======================
# Iniciando ingestão:
# =======================
# =======================
# {'nome_arquivo': 'resultado_teste_', 'descricao': 'tabela teste', 'chave': {'palavra_chave': 'teste', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste'}}
# resultado_teste_
# teste
# banco_teste.db
# tabela_teste
# =======================
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Verificando arquivo: resultado_CepAvenidaMairipora_20240711_121430.txt
# =======================
# {'nome_arquivo': 'resultado_teste2_', 'descricao': 'tabela teste 2', 'chave': {'palavra_chave': 'teste2', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste2'}}
# resultado_teste2_
# teste2
# banco_teste.db
# tabela_teste2
# =======================
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Verificando arquivo: resultado_CepAvenidaMairipora_20240711_121430.txt
# ========================
# item encontrado no diretório: cep
# ========================
#  conteudo: ['estrutura.json', 'tabela_cep.json']
# Encontrado estrutura.json em cep
# Conteúdo do arquivo de controle de ingestão: ['resultado_teste2_20242306_215405.txt\n', 'resultado_teste_20242506_202032.txt\n']
# Configuração estrutura: [{'nome_arquivo': 'resultado_CepAvenidaMairipora_', 'descricao': 'descricao do cep avenida mairipora', 'chave': {'palavra_chave': 'CepAvenidaMairipora', 'banco': 'banco_cep.db', 'tabela': 'tabela_CepAvenidaMairipora'}}]
# =======================
# Iniciando ingestão:
# =======================
# =======================
# {'nome_arquivo': 'resultado_CepAvenidaMairipora_', 'descricao': 'descricao do cep avenida mairipora', 'chave': {'palavra_chave': 'CepAvenidaMairipora', 'banco': 'banco_cep.db', 'tabela': 'tabela_CepAvenidaMairipora'}}
# resultado_CepAvenidaMairipora_
# CepAvenidaMairipora
# banco_cep.db
# tabela_CepAvenidaMairipora
# =======================
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Verificando arquivo: resultado_CepAvenidaMairipora_20240711_121430.txt
# Arquivo contendo a chave encontrado: /workspaces/projeto_ing/INGESTION/app/src/landing/resultado_CepAvenidaMairipora_20240711_121430.txt
# Conteúdo a gravar: resultado_CepAvenidaMairipora_20240711_121430.txt
# nomenclatura do arquivo salvo: resultado_CepAvenidaMairipora_20240711_121430.txt
# =================================
# Chave encontrada
# Separando nome do arquivo: CepAvenidaMairipora
# local para criar tabela: /workspaces/projeto_ing/INGESTION/app/src/layouts/cep/tabela_CepAvenidaMairipora.json
# Arquivo enviado para backup: /workspaces/projeto_ing/INGESTION/app/src/landing/resultado_CepAvenidaMairipora_20240711_121430.txt
# Destino: /workspaces/projeto_ing/INGESTION/app/src/backp/
# ==========================

# %%
banco = 'banco_cep.db'
banco_caminho = f'/workspaces/projeto_ing/INGESTION/database/{banco}'
conn = sqlite3.connect(banco_caminho)
cursor = conn.cursor()

query = 'select * from tabela_CepAvenidaMairipora'

cursor.execute(query)

# Recuperando e imprimindo o resultado
tables = cursor.fetchall()

print("Tabelas no banco de dados:")
for table in tables:
    print(table)

# Fechando a conexão
conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[6], line 8
#       4 cursor = conn.cursor()
#       6 query = 'select * from tabela_CepAvenidaMairipora'
# ----> 8 cursor.execute(query)
#      10 # Recuperando e imprimindo o resultado
#      11 tables = cursor.fetchall()
#
# OperationalError: no such table: tabela_CepAvenidaMairipora

# %%
import os
import json
import sqlite3
import pandas as pd
import shutil
from datetime import datetime

timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
data_igtao = datetime.now().strftime('%Y-%m-%d')

caminho_backup = '/workspaces/projeto_ing/INGESTION/app/src/backp/'
ctrl_ing = "/workspaces/projeto_ing/INGESTION/app/src/archiving_ctrl/arquivo_controle.txt"
landing = '/workspaces/projeto_ing/INGESTION/app/src/landing/'
layouts = '/workspaces/projeto_ing/INGESTION/app/src/layouts/'


read_landing = os.listdir(landing)
print("Conteúdos do diretório 'landing':", read_landing)
read_layouts = os.listdir(layouts)
print("Conteúdos do diretório 'layouts':", read_layouts)
print('===============================================')

try:
    
    for item in read_layouts:
        accept = os.path.join(layouts, item)
        if os.path.isdir(accept):
            print('========================')
            print(f'item encontrado no diretório: {item}')
            subconteudos = os.listdir(accept)
            print('========================')
            print(f' conteudo: {subconteudos}')
            
            caminho_estrutura_json = os.path.join(accept, 'estrutura.json')
            if os.path.exists(caminho_estrutura_json):
                print(f'Encontrado estrutura.json em {item}')
                
                with open(ctrl_ing, 'r+') as controle_ingestao:
                    conteudo_load = controle_ingestao.readlines()
                    print(f'Conteúdo do arquivo de controle de ingestão: {conteudo_load}')
                    
                with open(caminho_estrutura_json, 'r') as f:
                        config_estrutura = json.load(f)
                        print("Configuração estrutura:", config_estrutura)
                        print("=======================")
                        print("Iniciando ingestão:")
                        print("=======================")
                        for estr in config_estrutura:
                            nm_arq = estr['nome_arquivo']
                            key = estr['chave']['palavra_chave']
                            banco = estr['chave']['banco']
                            tabela = estr['chave']['tabela']
                            print('=======================')
                            print(estr)
                            print(nm_arq)
                            print(key)
                            print(banco)
                            print(tabela)
                            print('=======================')
                            
                            
                                
                            for root, dirs, lista in os.walk(landing):
                                print(f'Procurando em {root}...')
                                for nome_arquivo in lista:
                                    print(f'Verificando arquivo: {nome_arquivo}')
                                    if key in nome_arquivo:
                                        caminho_completo = os.path.join(root, nome_arquivo)
                                        print(f'Arquivo contendo a chave encontrado: {caminho_completo}')
                                        sav = os.path.basename(caminho_completo)
                                        print(f'Conteúdo a gravar: {sav}')
                                        
                                    if sav + '\n' not in conteudo_load:
                                        with open(ctrl_ing, 'a') as controle_ingestao:
                                            controle_ingestao.write(f"{sav}\n")
                                            print(f'nomenclatura do arquivo salvo: {sav}')
                                            print('=================================')
                                    
                                            
                                    '''
                                    Se o arquivo estiver presente no "arquivo_controle.txt" 
                                    o código deve ignorar a ingestão.
                                    Talvez um break ou um for para validar as informações dentro do arquivo e comparar
                                    se existir o nome do arquivo, ele deve ignora-lo.
                                    '''
                                        
                                    parte_util = sav.split('_')[1]
                                    if parte_util == key:
                                        print('Chave encontrada')
                                        print(f'Separando nome do arquivo: {parte_util}')
                                        caminho_tabela_json = os.path.join(accept, f'{tabela}.json')
                                        print(f'local para criar tabela: {caminho_tabela_json}')
                                        if os.path.exists(caminho_tabela_json):
                                            with open(caminho_tabela_json, 'r') as f:     
                                                config_colunas = json.load(f)
                                            print(config_colunas)
                                            print(f'resultado configuracao colunas: {config_colunas}')
                                            print('===============================')
                                            for j in config_colunas['colunas']:
                                                print(f'iterando config: {j}')
                                            
                                            if caminho_completo.endswith('.txt'):
                                                df = pd.read_csv(caminho_completo, delimiter=';', skiprows=[0], names=[col['nome'] for col in config_colunas['colunas'] if 'nome' in col])
                                                print(f'dados a carregar:{df}')
                                                print('estrutura de colunas txt:')
                                                print(df.columns)
                                                print('=====================')
                                            elif caminho_completo.endswith('.csv'):
                                                df = pd.read_csv(caminho_completo, skiprows=[0], names=[col['nome'] for col in config_colunas['colunas'] if 'nome' in col])
                                                print(f'dados a carregar:{df}')
                                                print('estrutura de colunas csv:')
                                                print(df.columns)
                                                print('=====================')
                                            elif caminho_completo.endswith('.bin'): 
                                                pass
                                            
                                            else:
                                                raise ValueError("Formato de arquivo não suportado")
                                            
                                            for col in config_colunas['colunas']:  
                                                if 'nome' in col and 'tipo' in col:
                                                    if col['tipo'] == 'int':
                                                        df[col['nome']] = df[col['nome']].astype(int)
                                                    elif col['tipo'] == 'float':
                                                        df[col['nome']] = df[col['nome']].astype(float)
                                                    elif col['tipo'] == 'data':
                                                        df[col['nome']] = pd.to_datetime(df[col['nome']], format=col.get('formato', None))
                                                        
                                            banco_caminho = f'/workspaces/projeto_ing/INGESTION/database/{banco}'
                                            conn = sqlite3.connect(banco_caminho)
                                            print(f'Banco de dados: {banco_caminho}')
                                            print(f'Banco de dados criado se não existir: {banco}')
                                            print(f'Conectado!')
                                            print(f"====================================")
                                            
                                            cursor = conn.cursor()
                                            nm_tb = f'tabela_{parte_util}'
                                            sql_create_table = f"CREATE TABLE IF NOT EXISTS {nm_tb} ("
                                            for col in config_colunas['colunas']:
                                                if 'nome' in col and 'tipo' in col:
                                                    sql_create_table += f"{col['nome']} {col['tipo']}, "
                                            sql_create_table = sql_create_table[:-2] + ")"
                                            cursor.execute(sql_create_table)
                                            print(f'Tabela criada: {nm_tb}')
                                            print(f'estrutura da tabela criada: {sql_create_table}')
                                            
                                            for index, row in df.iterrows():
                                                mapped_values = [row.get(col['nome'], None) for col in config_colunas['colunas'] if 'nome' in col]
                                                print("Valores mapeados:", mapped_values)
                                                sql = f"INSERT INTO {nm_tb} ({', '.join([col['nome'] for col in config_colunas['colunas'] if 'nome' in col])}) VALUES ({', '.join(['?' for _ in mapped_values])})"
                                                print("SQL:", sql)
                                                cursor.execute(sql, mapped_values)
                                        
                                            conn.commit()
                                            conn.close()
                                            print("Ingestão de dados concluída com sucesso!")
                                        
                                        shutil.move(caminho_completo, caminho_backup)
                                        print(f'Arquivo enviado para backup: {caminho_completo}')
                                        print(f'Destino: {caminho_backup}')
                                        print('==========================')
                                        
                                        
                                    else:
                                        print('Chave não encontrada no arquivo')
except Exception as e:
    print(f"Erro: {e}")
# Out:
# Conteúdos do diretório 'landing': ['resultado_cep_20240711_111430.txt']
# Conteúdos do diretório 'layouts': ['teste', 'cep']
# ===============================================
# ========================
# item encontrado no diretório: teste
# ========================
#  conteudo: ['estrutura.json', 'tabela_teste2.json', 'tabela_teste.json']
# Encontrado estrutura.json em teste
# Conteúdo do arquivo de controle de ingestão: ['resultado_teste2_20242306_215405.txt\n', 'resultado_teste_20242506_202032.txt\n']
# Configuração estrutura: [{'nome_arquivo': 'resultado_teste_', 'descricao': 'tabela teste', 'chave': {'palavra_chave': 'teste', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste'}}, {'nome_arquivo': 'resultado_teste2_', 'descricao': 'tabela teste 2', 'chave': {'palavra_chave': 'teste2', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste2'}}]
# =======================
# Iniciando ingestão:
# =======================
# =======================
# {'nome_arquivo': 'resultado_teste_', 'descricao': 'tabela teste', 'chave': {'palavra_chave': 'teste', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste'}}
# resultado_teste_
# teste
# banco_teste.db
# tabela_teste
# =======================
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Verificando arquivo: resultado_cep_20240711_111430.txt
# Erro: name 'sav' is not defined

# %%
import os
import json
import sqlite3
import pandas as pd
import shutil
from datetime import datetime

timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
data_igtao = datetime.now().strftime('%Y-%m-%d')

caminho_backup = '/workspaces/projeto_ing/INGESTION/app/src/backp/'
ctrl_ing = "/workspaces/projeto_ing/INGESTION/app/src/archiving_ctrl/arquivo_controle.txt"
landing = '/workspaces/projeto_ing/INGESTION/app/src/landing/'
layouts = '/workspaces/projeto_ing/INGESTION/app/src/tmp/layouts/'

# %%
read_landing = os.listdir(landing)
print("Conteúdos do diretório 'landing':", read_landing)
read_layouts = os.listdir(layouts)
print("Conteúdos do diretório 'layouts':", read_layouts)
print('===============================================')
# Out:
# Conteúdos do diretório 'landing': ['resultado_teste2_20242306_215405.txt']
# Conteúdos do diretório 'layouts': ['teste']
# ===============================================

# %%
for item in read_layouts:
    accept = os.path.join(layouts, item)
    if os.path.isdir(accept):
        print('========================')
        print(f'item encontrado no diretório: {item}')
        subconteudos = os.listdir(accept)
        print('========================')
        print(f' conteudo: {subconteudos}')
        
        caminho_estrutura_json = os.path.join(accept, 'estrutura.json')
        if os.path.exists(caminho_estrutura_json):
            print(f'Encontrado estrutura.json em {item}')
            
            with open(ctrl_ing, 'r+') as controle_ingestao:
                conteudo_load = controle_ingestao.readlines()
                print(f'Conteúdo do arquivo de controle de ingestão: {conteudo_load}')
                
            with open(caminho_estrutura_json, 'r') as f:
                    config_estrutura = json.load(f)
                    print("Configuração estrutura:", config_estrutura)
                    print("=======================")
                    print("Iniciando ingestão:")
                    print("=======================")
                    for estr in config_estrutura:
                        nm_arq = estr['nome_arquivo']
                        key = estr['chave']['palavra_chave']
                        banco = estr['chave']['banco']
                        tabela = estr['chave']['tabela']
                        print('=======================')
                        print(estr)
                        print(nm_arq)
                        print(key)
                        print(banco)
                        print(tabela)
                        print('=======================')
                        
                        
                            
                        for root, dirs, lista in os.walk(landing):
                            print(f'Procurando em {root}...')
                            for nome_arquivo in lista:
                                print(f'Verificando arquivo: {nome_arquivo}')
                                if key in nome_arquivo:
                                    caminho_completo = os.path.join(root, nome_arquivo)
                                    print(f'Arquivo contendo a chave encontrado: {caminho_completo}')
                                    sav = os.path.basename(caminho_completo)
                                    print(f'Conteúdo a gravar: {sav}')
                                    
                                if sav + '\n' not in conteudo_load:
                                    with open(ctrl_ing, 'a') as controle_ingestao:
                                        controle_ingestao.write(f"{sav}\n")
                                        print(f'nomenclatura do arquivo salvo: {sav}')
                                        print('=================================')
                                
                                        
                                '''
                                Se o arquivo estiver presente no "arquivo_controle.txt" 
                                o código deve ignorar a ingestão.
                                Talvez um break ou um for para validar as informações dentro do arquivo e comparar
                                se existir o nome do arquivo, ele deve ignora-lo.
                                '''
                                    
                                parte_util = sav.split('_')[1]
                                if parte_util == key:
                                    print('Chave encontrada')
                                    print(f'Separando nome do arquivo: {parte_util}')
                                    caminho_tabela_json = os.path.join(accept, f'{tabela}.json')
                                    print(f'local para criar tabela: {caminho_tabela_json}')
                                    if os.path.exists(caminho_tabela_json):
                                        with open(caminho_tabela_json, 'r') as f:     
                                            config_colunas = json.load(f)
                                        print(config_colunas)
                                        print(f'resultado configuracao colunas: {config_colunas}')
                                        print('===============================')
                                        for j in config_colunas['colunas']:
                                            print(f'iterando config: {j}')
                                        
                                        if caminho_completo.endswith('.txt'):
                                            df = pd.read_csv(caminho_completo, delimiter=';', skiprows=[0], names=[col['nome'] for col in config_colunas['colunas'] if 'nome' in col])
                                            print(f'dados a carregar:{df}')
                                            print('estrutura de colunas txt:')
                                            print(df.columns)
                                            print('=====================')
                                        elif caminho_completo.endswith('.csv'):
                                            df = pd.read_csv(caminho_completo, skiprows=[0], names=[col['nome'] for col in config_colunas['colunas'] if 'nome' in col])
                                            print(f'dados a carregar:{df}')
                                            print('estrutura de colunas csv:')
                                            print(df.columns)
                                            print('=====================')
                                        elif caminho_completo.endswith('.bin'): 
                                            pass
                                        
                                        else:
                                            raise ValueError("Formato de arquivo não suportado")
                                        
                                        for col in config_colunas['colunas']:  
                                            if 'nome' in col and 'tipo' in col:
                                                if col['tipo'] == 'int':
                                                    df[col['nome']] = df[col['nome']].astype(int)
                                                elif col['tipo'] == 'float':
                                                    df[col['nome']] = df[col['nome']].astype(float)
                                                elif col['tipo'] == 'data':
                                                    df[col['nome']] = pd.to_datetime(df[col['nome']], format=col.get('formato', None))
                                                    
                                        banco_caminho = f'/workspaces/projeto_ing/INGESTION/database/{banco}'
                                        conn = sqlite3.connect(banco_caminho)
                                        print(f'Banco de dados: {banco_caminho}')
                                        print(f'Banco de dados criado se não existir: {banco}')
                                        print(f'Conectado!')
                                        print(f"====================================")
                                        
                                        cursor = conn.cursor()
                                        nm_tb = f'tabela_{parte_util}'
                                        sql_create_table = f"CREATE TABLE IF NOT EXISTS {nm_tb} ("
                                        for col in config_colunas['colunas']:
                                            if 'nome' in col and 'tipo' in col:
                                                sql_create_table += f"{col['nome']} {col['tipo']}, "
                                        sql_create_table = sql_create_table[:-2] + ")"
                                        cursor.execute(sql_create_table)
                                        print(f'Tabela criada: {nm_tb}')
                                        print(f'estrutura da tabela criada: {sql_create_table}')
                                        
                                        for index, row in df.iterrows():
                                            mapped_values = [row.get(col['nome'], None) for col in config_colunas['colunas'] if 'nome' in col]
                                            print("Valores mapeados:", mapped_values)
                                            sql = f"INSERT INTO {nm_tb} ({', '.join([col['nome'] for col in config_colunas['colunas'] if 'nome' in col])}) VALUES ({', '.join(['?' for _ in mapped_values])})"
                                            print("SQL:", sql)
                                            cursor.execute(sql, mapped_values)
                                    
                                        conn.commit()
                                        conn.close()
                                        print("Ingestão de dados concluída com sucesso!")
                                    
                                    shutil.move(caminho_completo, caminho_backup)
                                    print(f'Arquivo enviado para backup: {caminho_completo}')
                                    print(f'Destino: {caminho_backup}')
                                    print('==========================')
                                    
                                    
                                else:
                                    print('Chave não encontrada no arquivo')
# Out:
# ========================
# item encontrado no diretório: teste
# ========================
#  conteudo: ['estrutura.json', 'tabela_teste2.json', 'tabela_teste.json']
# Encontrado estrutura.json em teste
# Conteúdo do arquivo de controle de ingestão: ['resultado_teste2_20242306_215405.txt\n', 'resultado_teste_20242506_202032.txt\n']
# Configuração estrutura: [{'nome_arquivo': 'resultado_teste_', 'descricao': 'tabela teste', 'chave': {'palavra_chave': 'teste', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste'}}, {'nome_arquivo': 'resultado_teste2_', 'descricao': 'tabela teste 2', 'chave': {'palavra_chave': 'teste2', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste2'}}]
# =======================
# Iniciando ingestão:
# =======================
# =======================
# {'nome_arquivo': 'resultado_teste_', 'descricao': 'tabela teste', 'chave': {'palavra_chave': 'teste', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste'}}
# resultado_teste_
# teste
# banco_teste.db
# tabela_teste
# =======================
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Verificando arquivo: resultado_teste2_20242306_215405.txt
# Arquivo contendo a chave encontrado: /workspaces/projeto_ing/INGESTION/app/src/landing/resultado_teste2_20242306_215405.txt
# Conteúdo a gravar: resultado_teste2_20242306_215405.txt
# Chave não encontrada no arquivo
# Verificando arquivo: resultado_teste_20242506_202032.txt
# Arquivo contendo a chave encontrado: /workspaces/projeto_ing/INGESTION/app/src/landing/resultado_teste_20242506_202032.txt
# Conteúdo a gravar: resultado_teste_20242506_202032.txt
# Chave encontrada
# Separando nome do arquivo: teste
# local para criar tabela: /workspaces/projeto_ing/INGESTION/app/src/tmp/layouts/teste/tabela_teste.json
# {'colunas': [{'nome': 'id', 'tipo': 'string'}, {'nome': 'nome', 'tipo': 'string'}]}
# resultado configuracao colunas: {'colunas': [{'nome': 'id', 'tipo': 'string'}, {'nome': 'nome', 'tipo': 'string'}]}
# ===============================
# iterando config: {'nome': 'id', 'tipo': 'string'}
# iterando config: {'nome': 'nome', 'tipo': 'string'}
# dados a carregar:   id    nome
# 0  10    skol
# 1  11  phoebe
# estrutura de colunas txt:
# Index(['id', 'nome'], dtype='object')
# =====================
# Banco de dados: /workspaces/projeto_ing/INGESTION/database/banco_teste.db
# Banco de dados criado se não existir: banco_teste.db
# Conectado!
# ====================================
# Tabela criada: tabela_teste
# estrutura da tabela criada: CREATE TABLE IF NOT EXISTS tabela_teste (id string, nome string)
# Valores mapeados: [10, 'skol']
# SQL: INSERT INTO tabela_teste (id, nome) VALUES (?, ?)
# Valores mapeados: [11, 'phoebe']
# SQL: INSERT INTO tabela_teste (id, nome) VALUES (?, ?)
# Ingestão de dados concluída com sucesso!
# Arquivo enviado para backup: /workspaces/projeto_ing/INGESTION/app/src/landing/resultado_teste_20242506_202032.txt
# Destino: /workspaces/projeto_ing/INGESTION/app/src/backp/
# #####################################
# =======================
# {'nome_arquivo': 'resultado_teste2_', 'descricao': 'tabela teste 2', 'chave': {'palavra_chave': 'teste2', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste2'}}
# resultado_teste2_
# teste2
# banco_teste.db
# tabela_teste2
# =======================
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Verificando arquivo: resultado_teste2_20242306_215405.txt
# Arquivo contendo a chave encontrado: /workspaces/projeto_ing/INGESTION/app/src/landing/resultado_teste2_20242306_215405.txt
# Conteúdo a gravar: resultado_teste2_20242306_215405.txt
# Chave encontrada
# Separando nome do arquivo: teste2
# local para criar tabela: /workspaces/projeto_ing/INGESTION/app/src/tmp/layouts/teste/tabela_teste2.json
# {'colunas': [{'nome': 'id', 'tipo': 'string'}, {'nome': 'nome', 'tipo': 'string'}, {'nome': 'idade', 'tipo': 'string'}]}
# resultado configuracao colunas: {'colunas': [{'nome': 'id', 'tipo': 'string'}, {'nome': 'nome', 'tipo': 'string'}, {'nome': 'idade', 'tipo': 'string'}]}
# ===============================
# iterando config: {'nome': 'id', 'tipo': 'string'}
# iterando config: {'nome': 'nome', 'tipo': 'string'}
# iterando config: {'nome': 'idade', 'tipo': 'string'}
# dados a carregar:   id    nome  idade
# 0   1  rafael     30
# 1   2   joyce     28
# estrutura de colunas txt:
# Index(['id', 'nome', 'idade'], dtype='object')
# =====================
# Banco de dados: /workspaces/projeto_ing/INGESTION/database/banco_teste.db
# Banco de dados criado se não existir: banco_teste.db
# Conectado!
# ====================================
# Tabela criada: tabela_teste2
# estrutura da tabela criada: CREATE TABLE IF NOT EXISTS tabela_teste2 (id string, nome string, idade string)
# Valores mapeados: [1, 'rafael', 30]
# SQL: INSERT INTO tabela_teste2 (id, nome, idade) VALUES (?, ?, ?)
# Valores mapeados: [2, 'joyce', 28]
# SQL: INSERT INTO tabela_teste2 (id, nome, idade) VALUES (?, ?, ?)
# Ingestão de dados concluída com sucesso!
# Arquivo enviado para backup: /workspaces/projeto_ing/INGESTION/app/src/landing/resultado_teste2_20242306_215405.txt
# Destino: /workspaces/projeto_ing/INGESTION/app/src/backp/
# #####################################

# %%
banco = 'banco_teste.db'
banco_caminho = f'/workspaces/projeto_ing/INGESTION/database/{banco}'
conn = sqlite3.connect(banco_caminho)
cursor = conn.cursor()

query = 'select * from tabela_teste2'

cursor.execute(query)

# Recuperando e imprimindo o resultado
tables = cursor.fetchall()

print("Tabelas no banco de dados:")
for table in tables:
    print(table)

# Fechando a conexão
conn.close()
# Out:
# Tabelas no banco de dados:
# (1, 'rafael', 30)
# (2, 'joyce', 28)
# (1, 'rafael', 30)
# (2, 'joyce', 28)
# (1, 'rafael', 30)
# (2, 'joyce', 28)
# (1, 'rafael', 30)
# (2, 'joyce', 28)
# (1, 'rafael', 30)
# (2, 'joyce', 28)
# (1, 'rafael', 30)
# (2, 'joyce', 28)
# (1, 'rafael', 30)
# (2, 'joyce', 28)
# (1, 'rafael', 30)
# (2, 'joyce', 28)
# (1, 'rafael', 30)
# (2, 'joyce', 28)
# (1, 'rafael', 30)
# (2, 'joyce', 28)
# (1, 'rafael', 30)
# (2, 'joyce', 28)

# %%
for item in read_layouts:
    accept = os.path.join(layouts, item)
    if os.path.isdir(accept):
        print('========================')
        print(f'item encontrado no diretório: {item}')
        subconteudos = os.listdir(accept)
        print('========================')
        print(f' conteudo: {subconteudos}')
        
        caminho_estrutura_json = os.path.join(accept, 'estrutura.json')
        if os.path.exists(caminho_estrutura_json):
            print(f'Encontrado estrutura.json em {item}')
            
            with open(caminho_estrutura_json, 'r') as f:
                    config_estrutura = json.load(f)
                    print("Configuração estrutura:", config_estrutura)
                    
                    for estr in config_estrutura:
                        nm_arq = estr['nome_arquivo']
                        key = estr['chave']['palavra_chave']
                        banco = estr['chave']['banco']
                        tabela = estr['chave']['tabela']
                        print('=======================')
                        print(estr)
                        print(nm_arq)
                        print(key)
                        print(banco)
                        print(tabela)
                        print('=======================')
                        
                        for root, dirs, lista in os.walk(landing):
                            print(f'Procurando em {root}...')
                            for nome_arquivo in lista:
                                print(f'Verificando arquivo: {nome_arquivo}')
                                if key in nome_arquivo:
                                    caminho_completo = os.path.join(root, nome_arquivo)
                                    print(f'Arquivo contendo a chave encontrado: {caminho_completo}')
                                    sav = os.path.basename(caminho_completo)
                                    print(f'Conteúdo a gravar: {sav}')
                                    
                                    parte_util = sav.split('_')[1]
                                    if parte_util == key:
                                        print('Chave encontrada')
                                        print(f'Separando nome do arquivo: {parte_util}')
                                        caminho_tabela_json = os.path.join(accept, f'{tabela}.json')
                                        print(f'local para criar tabela: {caminho_tabela_json}')
                                        if os.path.exists(caminho_tabela_json):
                                            with open(caminho_tabela_json, 'r') as f:     
                                                config_colunas = json.load(f)
                                            print(config_colunas)
                                        # if os.path.exists(caminho_tabela_json):
                                        #     with open(caminho_tabela_json, 'r') as f:
                                        #         config_colunas = json.load(f)
                                        #     print('Lendo estrutura de coluna json')
                                        #     print(f'Conteúdo da config: {config_colunas}')
                                        #     print(f'Conteúdo do item: {item}')
                                        #     print('==========================')
                                        
                                        
                                    else:
                                        print('Chave não encontrada no arquivo')
# Out:
# ========================
# item encontrado no diretório: teste
# ========================
#  conteudo: ['estrutura.json', 'tabela_teste2.json', 'tabela_teste.json']
# Encontrado estrutura.json em teste
# Configuração estrutura: [{'nome_arquivo': 'resultado_teste_', 'descricao': 'tabela teste', 'chave': {'palavra_chave': 'teste', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste'}}, {'nome_arquivo': 'resultado_teste2_', 'descricao': 'tabela teste 2', 'chave': {'palavra_chave': 'teste2', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste_2'}}]
# =======================
# {'nome_arquivo': 'resultado_teste_', 'descricao': 'tabela teste', 'chave': {'palavra_chave': 'teste', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste'}}
# resultado_teste_
# teste
# banco_teste.db
# tabela_teste
# =======================
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Verificando arquivo: resultado_teste2_20242306_215405.txt
# Arquivo contendo a chave encontrado: /workspaces/projeto_ing/INGESTION/app/src/landing/resultado_teste2_20242306_215405.txt
# Conteúdo a gravar: resultado_teste2_20242306_215405.txt
# Chave não encontrada no arquivo
# =======================
# {'nome_arquivo': 'resultado_teste2_', 'descricao': 'tabela teste 2', 'chave': {'palavra_chave': 'teste2', 'banco': 'banco_teste.db', 'tabela': 'tabela_teste_2'}}
# resultado_teste2_
# teste2
# banco_teste.db
# tabela_teste_2
# =======================
# Procurando em /workspaces/projeto_ing/INGESTION/app/src/landing/...
# Verificando arquivo: resultado_teste2_20242306_215405.txt
# Arquivo contendo a chave encontrado: /workspaces/projeto_ing/INGESTION/app/src/landing/resultado_teste2_20242306_215405.txt
# Conteúdo a gravar: resultado_teste2_20242306_215405.txt
# Chave encontrada
# Separando nome do arquivo: teste2
# local para criar tabela: /workspaces/projeto_ing/INGESTION/app/src/tmp/layouts/teste/tabela_teste_2.json
