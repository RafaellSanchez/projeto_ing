# %%
import pandas as pd 
import requests

# %%
# key = 'RGoTv8Dds6IPDbfRr5zteNvJDqWKYLTM'
# url_api = f'https://calendarific.com/api/v2/holidays?&api_key={key}&country=BR&year=2024'

# response = requests.get(url_api)
# dados = response.json()
# print(dados)
# Out:
# {'meta': {'code': 200}, 'response': {'holidays': [{'name': "New Year's Day", 'description': 'New Year’s Day is the first day of the year, or January 1, in the Gregorian calendar.', 'country': {'id': 'br', 'name': 'Brazil'}, 'date': {'iso': '2024-01-01', 'datetime': {'year': 2024, 'month': 1, 'day': 1}}, 'type': ['National holiday'], 'primary_type': 'National Holiday', 'canonical_url': 'https://calendarific.com/holiday/brazil/new-year-day', 'urlid': 'brazil/new-year-day', 'locations': 'All', 'states': 'All'}, {'name': 'Carnival Friday', 'description': 'Carnival Friday is a observance in Brazil', 'country': {'id': 'br', 'name': 'Brazil'}, 'date': {'iso': '2024-02-09', 'datetime': {'year': 2024, 'month': 2, 'day': 9}}, 'type': ['Observance'], 'primary_type': 'Observance', 'canonical_url': 'https://calendarific.com/holiday/brazil/carnival-friday', 'urlid': 'brazil/carnival-friday', 'locations': 'All', 'states': 'All'}, {'name': 'Carnival Saturday', 'description': 'Carnival Saturday is a observance in Brazil', 'country': {'id': 'br', 'name': 'Brazil'}, 'date': {'iso': '2024-02-10', 'datetime': {'year': 2024, 'month': 2, 'day': 10}}, 'type': ['Observance'], 'primary_type': 'Observance', 'canonical_url': 'https://calendarific.com/holiday/brazil/carnival-saturday', 'urlid': 'brazil/carnival-saturday', 'locations': 'All', 'states': 'All'}, {'name': 'Carnival Sunday', 'description': 'Carnival Sunday is a observance in Brazil', 'country': {'id': 'br', 'name': 'Brazil'}, 'date': {'iso': '2024-02-11', 'datetime': {'year': 2024, 'month': 2, 'day': 11}}, 'type': ['Observance'], 'primary_type': 'Observance', 'canonical_url': 'https://calendarific.com/holiday/brazil/carnival-sunday', 'urlid': 'brazil/carnival-sunday', 'locations': 'All', 'states': 'All'}, {'name': 'Carnival Monday', 'description': 'Carnival Monday is a government holiday in Brazil', 'country': {'id': 'br', 'name': 'Brazil'}, 'date': {'iso': '2024-02-12', 'datetime': {'year': 2024, 'month': 2, 'day': 12}}, 'type': ['National holiday'], 'primary_type': 'Government Holiday', 'canonical_url': 'https://calendarific.com/holiday/brazil/carnival-monday', 'urlid': 'brazil/carnival-monday', 'locations': 'All', 'states': 'All'}, {'name': 'Carnival Tuesday', 'description': 'Carnival has several long-standing traditions in Brazil.', 'country': {'id': 'br', 'name': 'Brazil'}, 'date': {'iso': '2024-02-13', 'datetime': {'year': 2024, 'month': 2, 'day': 13}}, 'type': ['National holiday'], 'primary_type': 'Government Holiday', 'canonical_url': 'https://calendarific.com/holiday/brazil/carnival-tuesday', 'urlid': 'brazil/carnival-tuesday', 'locations': 'All', 'states': 'All'}, {'name': 'Carnival end (until 2pm)', 'description': 'Ash Wednesday marks the first day of Lent in western Christian churches.', 'country': {'id': 'br', 'name': 'Brazil'}, 'date': {'iso': '2024-02-14', 'datetime': {'year': 2024, 'month': 2, 'day': 14}}, 'type': ['National holiday'], 'primary_type': 'Government Holiday', 'canonical_url': 'https://calendarific.com/holiday/brazil/carnival-end', 'urlid': 'brazil/carnival-end', 'locations': 'All', 'states': 'All'}, {'name': 'March Equinox', 'description': 'March Equinox in Brazil (Brasilia)', 'country': {'id': 'br', 'name': 'Brazil'}, 'date': {'iso': '2024-03-20T00:06:28-03:00', 'datetime': {'year': 2024, 'month': 3, 'day': 20, 'hour': 0, 'minute': 6, 'second': 28}, 'timezone': {'offset': '-03:00', 'zoneabb': 'BRT', 'zoneoffset': -10800, 'zonedst': 0, 'zonetotaloffset': -10800}}, 'type': ['Season'], 'primary_type': 'Season', 'canonical_url': 'https://calendarific.com/holiday/seasons/vernal-equinox', 'urlid': 'seasons/vernal-equinox', 'locations': 'All', 'states': 'All'}, {'name': 'Good Friday', 'description': 'Good Friday is a global Christian observance two days before Easter Sunday.', 'country': {'id': 'br', 'name': 'Brazil'}, 'date': {'iso': '2024-03-29', 'datetime': {'year': 2024, 'month': 3, 'day': 29}}, 'type': ['National holiday'], 'primary_type': 'National Holiday', 'cano ...

# %%
key = 'RGoTv8Dds6IPDbfRr5zteNvJDqWKYLTM'
url_api = f'https://calendarific.com/api/v2/holidays?&api_key={key}&country=BR&year=2024'

response = requests.get(url_api)
dados = response.json()

# print(dados)

dados_list = []

if 'response' in dados and 'holidays' in dados['response']:
    feriados = dados['response']['holidays']
    
    for feriado in feriados:
        nome = feriado['name']
        descricao = feriado['description'] if 'description' in feriado else ''
        data_iso = feriado['date']['iso']
        ano = feriado['date']['datetime']['year']
        mes = feriado['date']['datetime']['month']
        dia = feriado['date']['datetime']['day']
        
        dados_list.append({
            'Nome': nome,
            'Descrição': descricao,
            'Data_ISO': data_iso,
            'Ano': ano,
            'Mês': mes,
            'Dia': dia
        })

df = pd.DataFrame(dados_list)
print(df)


file = f'feriado_calendario.txt'
location = '/workspaces/projeto_ing/tests/app/src/'

df.to_csv(f'{location}{file}', sep=';', index=False)
print(f'Arquivo salvo: {file}')
print(f'Caminho: {location}')
# Out:
#                                       Nome  \
# 0                           New Year's Day
# 1                          Carnival Friday
# 2                        Carnival Saturday
# 3                          Carnival Sunday
# 4                          Carnival Monday
# 5                         Carnival Tuesday
# 6                 Carnival end (until 2pm)
# 7                            March Equinox
# 8                              Good Friday
# 9                            Easter Sunday
# 10                          Tiradentes Day
# 11                     Labor Day / May Day
# 12                            Mother's Day
# 13                          Corpus Christi
# 14               Brazilian Valentine's Day
# 15                           June Solstice
# 16                            Father's Day
# 17                        Independence Day
# 18                       September Equinox
# 19  Our Lady of Aparecida / Children's Day
# 20                           Teacher's Day
